# %%
import shutil
import apiquery
import pandas as pd
import sys
import seaborn as sns
import os
import torch
import numpy as np
import random
DATA_PATH = '../01.Data'
shutil.copy("apiquery_pyc.py", "apiquery.pyc")
module_path = "../src"
if module_path not in sys.path:
    sys.path.append(module_path)
    
from utils.training import *
from utils.encoding import *
from utils.utils import *
from models.models import XLMRoberta
from dataset.dataset import BNPParibasText
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
import math
from collections import Counter
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
import math
import time
import matplotlib.pyplot as plt
import transformers
pd.set_option('display.max_rows',100 )

# %%
def get_embedding(data_loader, model, device):
    from tqdm.notebook import tqdm
    # Put the model in eval mode
    model.to(device)
    model.eval()
    # List for store final predictions
    final_predictions = []
    with torch.no_grad():
        tk0 = tqdm(data_loader, total=len(data_loader))
        for b_idx, data in enumerate(tk0):
            for key,value in data.items():
                data[key] = value.to(device)
            predictions = model._embeddings(data['ids'],data['mask'])
            predictions = predictions.cpu()
            final_predictions.append(predictions)
    return np.vstack(final_predictions)

# %%
MAX_LENGTH   = 16
PRETRAINED   = 'xlm-roberta-base'
SEED         = 42

# %%
# %%time
df_train     = pd.read_csv(os.path.join("../01.Data",'fold.csv'))
y_submission = pd.read_csv(os.path.join(DATA_PATH,'y_test_submission_example.tsv'), index_col='Index', encoding='utf-8', sep='\t')
# Out:
# CPU times: user 2.22 s, sys: 227 ms, total: 2.44 s
# Wall time: 2.45 s

# %%
seed_everything(SEED)

# %%
# %%time
COLUMN_NAME  = 'product_name' 
tokenizer     = transformers.XLMRobertaTokenizer.from_pretrained(PRETRAINED)
train_dataset = BNPParibasText(df_train,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = XLMRoberta(pretrained_model=PRETRAINED)
train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_train = get_embedding(train_loader, model, 'cuda')
df_train[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_train.shape[1])]] = emb_sentence_train
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3189.0), HTML(value='')))
# CPU times: user 1min 45s, sys: 14.5 s, total: 1min 59s
# Wall time: 1min 37s

# %%
COLUMN_NAME  = 'ingredients_text' 
tokenizer     = transformers.XLMRobertaTokenizer.from_pretrained(PRETRAINED)
train_dataset = BNPParibasText(df_train,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = XLMRoberta(pretrained_model=PRETRAINED)
train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_train = get_embedding(train_loader, model, 'cuda')
df_train[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_train.shape[1])]] = emb_sentence_train
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3189.0), HTML(value='')))

# %%
COLUMN_NAME  = 'brands_tags' 
tokenizer     = transformers.XLMRobertaTokenizer.from_pretrained(PRETRAINED)
train_dataset = BNPParibasText(df_train,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = XLMRoberta(pretrained_model=PRETRAINED)
train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_train = get_embedding(train_loader, model, 'cuda')
df_train[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_train.shape[1])]] = emb_sentence_train
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3189.0), HTML(value='')))

# %%
columns_modeling = ['additives_n','ingredients_from_palm_oil_n',
                    'ingredients_that_may_be_from_palm_oil_n','target',
                    'states_en_brands','states_en_categories','states_en_characteristics','states_en_expiration date',
                    'states_en_general_complete','states_en_ingredients','pnns_groups_1','pnns_groups_2',
                    'states_en_packaging','states_en_packaging-code-','states_en_photo_upload',
                    'states_en_photo_validate','states_en_product name','states_en_quantity','diff_t'] + [f'emb_product_name_{i}' for i in range(emb_sentence_train.shape[1])] + [f'emb_ingredients_text_{i}' for i in range(emb_sentence_train.shape[1])]+[f'emb_brands_tags_{i}' for i in range(emb_sentence_train.shape[1])]
columns_label = df_train[columns_modeling].select_dtypes(include=['object']).columns.to_list()
print(columns_label)
# Out:
# ['states_en_brands', 'states_en_categories', 'states_en_characteristics', 'states_en_expiration date', 'states_en_general_complete', 'states_en_ingredients', 'pnns_groups_1', 'pnns_groups_2', 'states_en_packaging', 'states_en_packaging-code-', 'states_en_photo_upload', 'states_en_photo_validate', 'states_en_product name', 'states_en_quantity']

# %%
df_train,dict_le = label_encoding(df_train,label_cols = columns_label, drop_original = True, missing_new_cat = True)
# Out:
# Mode: Missing as new category
# Label Encoding:  label_states_en_brands
# Label Encoding:  label_states_en_categories
# Label Encoding:  label_states_en_characteristics
# Label Encoding:  label_states_en_expiration date
# Label Encoding:  label_states_en_general_complete
# Label Encoding:  label_states_en_ingredients
# Label Encoding:  label_pnns_groups_1
# Label Encoding:  label_pnns_groups_2
# Label Encoding:  label_states_en_packaging
# Label Encoding:  label_states_en_packaging-code-
# Label Encoding:  label_states_en_photo_upload
# Label Encoding:  label_states_en_photo_validate
# Label Encoding:  label_states_en_product name
# Label Encoding:  label_states_en_quantity

# %%
params = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'regression',
        'metric': {'rmse'},
        'num_leaves':12,
        'learning_rate': 0.08,
        "min_child_samples": 150,
        "max_depth" : 5,
        'feature_fraction':  0.5,
        "bagging_freq": 1,
        'bagging_fraction': 0.75,
        "is_unbalance" : False,
        'force_col_wise':True,
        'num_threads':18,
        #"scale_pos_weight":5 -> Generally  is the ratio of number of negative class to the positive class.
        'bagging_seed':42,
        'lambda_l1':1.5,
        'lambda_l2':1,
        'verbose': 1

}
cat_columns = [i for i in df_train.columns.to_list() if i.startswith('label_')]
columns_modeling_last = list(set(columns_modeling)-set(columns_label)) + ['fold'] + cat_columns

# %%
results,models,importances,oof,feature_list = Training_Lightgbm(df_train[columns_modeling_last],params,fold_column = 'fold',target_column = 'target',cat_vars = cat_columns ,metric = 'RMSE',early_stopping = 200,max_boost_round = 8000)
# Out:
# Columns: ['emb_product_name_250', 'emb_product_name_41', 'emb_product_name_633', 'emb_ingredients_text_275', 'emb_brands_tags_563', 'emb_brands_tags_650', 'emb_ingredients_text_685', 'emb_ingredients_text_285', 'emb_ingredients_text_84', 'emb_ingredients_text_356', 'emb_brands_tags_494', 'emb_ingredients_text_102', 'emb_ingredients_text_71', 'emb_brands_tags_619', 'emb_ingredients_text_591', 'emb_ingredients_text_409', 'emb_product_name_550', 'emb_ingredients_text_351', 'emb_ingredients_text_122', 'emb_ingredients_text_100', 'emb_brands_tags_267', 'emb_ingredients_text_47', 'emb_brands_tags_300', 'emb_product_name_422', 'emb_brands_tags_432', 'emb_ingredients_text_761', 'emb_product_name_291', 'emb_product_name_599', 'emb_ingredients_text_211', 'emb_brands_tags_628', 'emb_ingredients_text_180', 'emb_brands_tags_324', 'emb_brands_tags_642', 'emb_ingredients_text_33', 'emb_brands_tags_537', 'emb_brands_tags_349', 'emb_product_name_125', 'emb_product_name_429', 'emb_ingredients_text_246', 'emb_product_name_105', 'emb_brands_tags_321', 'emb_ingredients_text_374', 'emb_brands_tags_766', 'emb_brands_tags_292', 'emb_ingredients_text_295', 'emb_product_name_759', 'emb_brands_tags_128', 'emb_brands_tags_375', 'emb_brands_tags_176', 'emb_product_name_667', 'emb_ingredients_text_109', 'emb_ingredients_text_105', 'emb_product_name_527', 'emb_ingredients_text_254', 'emb_product_name_328', 'emb_brands_tags_72', 'emb_ingredients_text_424', 'emb_product_name_767', 'emb_brands_tags_459', 'emb_brands_tags_633', 'emb_product_name_77', 'emb_brands_tags_151', 'emb_product_name_695', 'emb_ingredients_text_153', 'emb_ingredients_text_497', 'emb_ingredients_text_116', 'emb_brands_tags_400', 'emb_product_name_748', 'emb_product_name_464', 'emb_ingredients_text_257', 'emb_product_name_744', 'emb_product_name_189', 'emb_ingredients_text_353', 'emb_brands_tags_472', 'emb_product_name_456', 'emb_ingredients_text_661', 'emb_brands_tags_135', 'emb_brands_tags_47', 'emb_product_name_99', 'emb_brands_tags_753', 'emb_product_name_448', 'emb_product_name_645', 'emb_product_name_255', 'emb_product_name_16', 'emb_ingredients_text_82', 'emb_product_name_489', 'emb_brands_tags_109', 'emb_brands_tags_149', 'emb_brands_tags_272', 'emb_product_name_303', 'emb_product_name_445', 'emb_product_name_610', 'emb_product_name_39', 'emb_product_name_3', 'emb_ingredients_text_361', 'emb_ingredients_text_251', 'emb_brands_tags_544', 'emb_product_name_423', 'emb_product_name_447', 'emb_brands_tags_447', 'emb_ingredients_text_476', 'emb_brands_tags_661', 'emb_ingredients_text_417', 'emb_brands_tags_216', 'emb_product_name_59', 'emb_ingredients_text_316', 'emb_product_name_404', 'emb_brands_tags_751', 'emb_product_name_413', 'emb_ingredients_text_61', 'emb_brands_tags_398', 'emb_brands_tags_172', 'emb_ingredients_text_313', 'emb_brands_tags_504', 'emb_brands_tags_384', 'emb_ingredients_text_34', 'emb_ingredients_text_255', 'emb_product_name_361', 'emb_brands_tags_606', 'emb_ingredients_text_736', 'emb_product_name_505', 'emb_ingredients_text_588', 'emb_product_name_183', 'emb_ingredients_text_189', 'emb_brands_tags_728', 'emb_brands_tags_548', 'emb_product_name_719', 'emb_ingredients_text_433', 'emb_brands_tags_320', 'emb_ingredients_text_480', 'emb_brands_tags_316', 'emb_ingredients_text_689', 'emb_product_name_747', 'emb_ingredients_text_693', 'emb_brands_tags_29', 'emb_brands_tags_524', 'emb_brands_tags_665', 'emb_product_name_277', 'emb_ingredients_text_332', 'emb_product_name_1', 'emb_product_name_576', 'emb_product_name_426', 'emb_ingredients_text_95', 'emb_brands_tags_93', 'emb_brands_tags_234', 'emb_product_name_395', 'emb_ingredients_text_474', 'emb_ingredients_text_471', 'emb_product_name_587', 'emb_ingredients_text_747', 'emb_ingredients_text_589', 'emb_ingredients_text_266', 'emb_product_name_590', 'emb_ingredients_text_737', 'emb_brands_tags_584', 'emb_brands_tags_686', 'emb_product_name_115', 'emb_brands_tags_329', 'emb_brands_tags_427', 'emb_brands_tags_360', 'emb_i ...
# Cat index: [2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321]
# ---------- Training fold Nº 1 ----------
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 587901
# [LightGBM] [Info] Number of data points in the train set: 81622, number of used features: 2322
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 9.171473
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 6.91828	valid_1's rmse: 6.97418
# [100]	training's rmse: 6.51149	valid_1's rmse: 6.60104
# [150]	training's rmse: 6.2683	valid_1's rmse: 6.39501
# [200]	training's rmse: 6.09244	valid_1's rmse: 6.25838
# [250]	training's rmse: 5.94772	valid_1's rmse: 6.15288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	training's rmse: 5.82874	valid_1's rmse: 6.07191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	training's rmse: 5.72272	valid_1's rmse: 6.0028
# [400]	training's rmse: 5.62702	valid_1's rmse: 5.94577
# [450]	training's rmse: 5.54017	valid_1's rmse: 5.89683
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	training's rmse: 5.4614	valid_1's rmse: 5.85434
# [550]	training's rmse: 5.38585	valid_1's rmse: 5.81381
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	training's rmse: 5.31384	valid_1's rmse: 5.77972
# [650]	training's rmse: 5.246	valid_1's rmse: 5.75121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [700]	training's rmse: 5.18468	valid_1's rmse: 5.72624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	training's rmse: 5.1257	valid_1's rmse: 5.70504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's rmse: 5.06844	valid_1's rmse: 5.68313
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	training's rmse: 5.01162	valid_1's rmse: 5.6603
# [900]	training's rmse: 4.95725	valid_1's rmse: 5.63948
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	training's rmse: 4.9053	valid_1's rmse: 5.62146
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	training's rmse: 4.85614	valid_1's rmse: 5.60311
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1050]	training's rmse: 4.80824	valid_1's rmse: 5.588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1100]	training's rmse: 4.76162	valid_1's rmse: 5.57339
# [1150]	training's rmse: 4.71537	valid_1's rmse: 5.55949
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1200]	training's rmse: 4.67111	valid_1's rmse: 5.54805
# [1250]	training's rmse: 4.62525	valid_1's rmse: 5.53466
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1300]	training's rmse: 4.5828	valid_1's rmse: 5.52436
# [1350]	training's rmse: 4.54166	valid_1's rmse: 5.51378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1400]	training's rmse: 4.50046	valid_1's rmse: 5.50463
# [1450]	training's rmse: 4.46073	valid_1's rmse: 5.49406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1500]	training's rmse: 4.42228	valid_1's rmse: 5.48381
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1550]	training's rmse: 4.38309	valid_1's rmse: 5.47477
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1600]	training's rmse: 4.34596	valid_1's rmse: 5.46503
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1650]	training's rmse: 4.3087	valid_1's rmse: 5.45521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1700]	training's rmse: 4.27272	valid_1's rmse: 5.44727
# [1750]	training's rmse: 4.23722	valid_1's rmse: 5.43982
# [1800]	training's rmse: 4.20169	valid_1's rmse: 5.43226
# [1850]	training's rmse: 4.16709	valid_1's rmse: 5.42306
# [1900]	training's rmse: 4.13289	valid_1's rmse: 5.41603
# [1950]	training's rmse: 4.0996	valid_1's rmse: 5.41162
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	training's rmse: 4.06619	valid_1's rmse: 5.40391
# [2050]	training's rmse: 4.03364	valid_1's rmse: 5.39771
# [2100]	training's rmse: 4.00185	valid_1's rmse: 5.39133
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2150]	training's rmse: 3.97064	valid_1's rmse: 5.38583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2200]	training's rmse: 3.93926	valid_1's rmse: 5.38116
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2250]	training's rmse: 3.90962	valid_1's rmse: 5.37597
# [2300]	training's rmse: 3.87791	valid_1's rmse: 5.37051
# [2350]	training's rmse: 3.84893	valid_1's rmse: 5.36586
# [2400]	training's rmse: 3.81862	valid_1's rmse: 5.36238
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2450]	training's rmse: 3.78984	valid_1's rmse: 5.35634
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2500]	training's rmse: 3.76142	valid_1's rmse: 5.35145
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2550]	training's rmse: 3.73305	valid_1's rmse: 5.34649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2600]	training's rmse: 3.70436	valid_1's rmse: 5.34112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2650]	training's rmse: 3.67653	valid_1's rmse: 5.33607
# [2700]	training's rmse: 3.64983	valid_1's rmse: 5.33008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2750]	training's rmse: 3.62207	valid_1's rmse: 5.32541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2800]	training's rmse: 3.59597	valid_1's rmse: 5.3231
# [2850]	training's rmse: 3.56931	valid_1's rmse: 5.31951
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2900]	training's rmse: 3.5433	valid_1's rmse: 5.31567
# [2950]	training's rmse: 3.5172	valid_1's rmse: 5.31213
# [3000]	training's rmse: 3.49232	valid_1's rmse: 5.30918
# [3050]	training's rmse: 3.4666	valid_1's rmse: 5.30625
# [3100]	training's rmse: 3.44247	valid_1's rmse: 5.30229
# [3150]	training's rmse: 3.41716	valid_1's rmse: 5.29836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3200]	training's rmse: 3.39322	valid_1's rmse: 5.29645
# [3250]	training's rmse: 3.36861	valid_1's rmse: 5.29342
# [3300]	training's rmse: 3.34509	valid_1's rmse: 5.29101
# [3350]	training's rmse: 3.32129	valid_1's rmse: 5.28798
# [3400]	training's rmse: 3.29751	valid_1's rmse: 5.28624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3450]	training's rmse: 3.27446	valid_1's rmse: 5.28414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3500]	training's rmse: 3.25176	valid_1's rmse: 5.28125
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3550]	training's rmse: 3.22921	valid_1's rmse: 5.27899
# [3600]	training's rmse: 3.20669	valid_1's rmse: 5.27597
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3650]	training's rmse: 3.18515	valid_1's rmse: 5.27355
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3700]	training's rmse: 3.16429	valid_1's rmse: 5.27156
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3750]	training's rmse: 3.14277	valid_1's rmse: 5.26926
# [3800]	training's rmse: 3.12138	valid_1's rmse: 5.2669
# [3850]	training's rmse: 3.10015	valid_1's rmse: 5.26501
# [3900]	training's rmse: 3.07946	valid_1's rmse: 5.26224
# [3950]	training's rmse: 3.05883	valid_1's rmse: 5.26034
# [4000]	training's rmse: 3.0383	valid_1's rmse: 5.25789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4050]	training's rmse: 3.0189	valid_1's rmse: 5.2556
# [4100]	training's rmse: 2.9986	valid_1's rmse: 5.2534
# [4150]	training's rmse: 2.97846	valid_1's rmse: 5.25262
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4200]	training's rmse: 2.95917	valid_1's rmse: 5.25048
# [4250]	training's rmse: 2.9399	valid_1's rmse: 5.24814
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4300]	training's rmse: 2.92034	valid_1's rmse: 5.24634
# [4350]	training's rmse: 2.90058	valid_1's rmse: 5.24425
# [4400]	training's rmse: 2.88147	valid_1's rmse: 5.24169
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4450]	training's rmse: 2.8626	valid_1's rmse: 5.24034
# [4500]	training's rmse: 2.84385	valid_1's rmse: 5.23823
# [4550]	training's rmse: 2.82606	valid_1's rmse: 5.23623
# [4600]	training's rmse: 2.80801	valid_1's rmse: 5.23539
# [4650]	training's rmse: 2.78943	valid_1's rmse: 5.23326
# [4700]	training's rmse: 2.77134	valid_1's rmse: 5.23183
# [4750]	training's rmse: 2.75392	valid_1's rmse: 5.22984
# [4800]	training's rmse: 2.73594	valid_1's rmse: 5.22868
# [4850]	training's rmse: 2.7181	valid_1's rmse: 5.22599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4900]	training's rmse: 2.70081	valid_1's rmse: 5.22361
# [4950]	training's rmse: 2.68358	valid_1's rmse: 5.22105
# [5000]	training's rmse: 2.66629	valid_1's rmse: 5.22047
# [5050]	training's rmse: 2.6493	valid_1's rmse: 5.21966
# [5100]	training's rmse: 2.63214	valid_1's rmse: 5.2195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5150]	training's rmse: 2.61576	valid_1's rmse: 5.21849
# [5200]	training's rmse: 2.59982	valid_1's rmse: 5.21618
# [5250]	training's rmse: 2.58416	valid_1's rmse: 5.21447
# [5300]	training's rmse: 2.56816	valid_1's rmse: 5.21334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5350]	training's rmse: 2.5524	valid_1's rmse: 5.21232
# [5400]	training's rmse: 2.53749	valid_1's rmse: 5.21098
# [5450]	training's rmse: 2.52188	valid_1's rmse: 5.20975
# [5500]	training's rmse: 2.50614	valid_1's rmse: 5.20888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5550]	training's rmse: 2.49091	valid_1's rmse: 5.20838
# [5600]	training's rmse: 2.47486	valid_1's rmse: 5.20665
# [5650]	training's rmse: 2.46002	valid_1's rmse: 5.20505
# [5700]	training's rmse: 2.44493	valid_1's rmse: 5.20364
# [5750]	training's rmse: 2.42996	valid_1's rmse: 5.20217
# [5800]	training's rmse: 2.41527	valid_1's rmse: 5.20086
# [5850]	training's rmse: 2.40078	valid_1's rmse: 5.19998
# [5900]	training's rmse: 2.38617	valid_1's rmse: 5.1988
# [5950]	training's rmse: 2.37189	valid_1's rmse: 5.19784
# [6000]	training's rmse: 2.35747	valid_1's rmse: 5.19641
# [6050]	training's rmse: 2.34363	valid_1's rmse: 5.19557
# [6100]	training's rmse: 2.32989	valid_1's rmse: 5.19484
# [6150]	training's rmse: 2.31581	valid_1's rmse: 5.19461
# [6200]	training's rmse: 2.30203	valid_1's rmse: 5.19338
# [6250]	training's rmse: 2.28872	valid_1's rmse: 5.19352
# [6300]	training's rmse: 2.275	valid_1's rmse: 5.19207
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6350]	training's rmse: 2.2615	valid_1's rmse: 5.19152
# [6400]	training's rmse: 2.24838	valid_1's rmse: 5.1902
# [6450]	training's rmse: 2.23513	valid_1's rmse: 5.18959
# [6500]	training's rmse: 2.2223	valid_1's rmse: 5.18927
# [6550]	training's rmse: 2.20914	valid_1's rmse: 5.1882
# [6600]	training's rmse: 2.19591	valid_1's rmse: 5.18775
# [6650]	training's rmse: 2.18312	valid_1's rmse: 5.18735
# [6700]	training's rmse: 2.16967	valid_1's rmse: 5.18595
# [6750]	training's rmse: 2.15748	valid_1's rmse: 5.18497
# [6800]	training's rmse: 2.14513	valid_1's rmse: 5.18378
# [6850]	training's rmse: 2.13293	valid_1's rmse: 5.18373
# [6900]	training's rmse: 2.12086	valid_1's rmse: 5.18254
# [6950]	training's rmse: 2.10914	valid_1's rmse: 5.18168
# [7000]	training's rmse: 2.09711	valid_1's rmse: 5.18103
# [7050]	training's rmse: 2.08538	valid_1's rmse: 5.18058
# [7100]	training's rmse: 2.07319	valid_1's rmse: 5.18008
# [7150]	training's rmse: 2.0615	valid_1's rmse: 5.17931
# [7200]	training's rmse: 2.04996	valid_1's rmse: 5.17805
# [7250]	training's rmse: 2.03852	valid_1's rmse: 5.1768
# [7300]	training's rmse: 2.02696	valid_1's rmse: 5.17688
# [7350]	training's rmse: 2.01635	valid_1's rmse: 5.17604
# [7400]	training's rmse: 2.00482	valid_1's rmse: 5.17533
# [7450]	training's rmse: 1.99385	valid_1's rmse: 5.17489
# [7500]	training's rmse: 1.98294	valid_1's rmse: 5.17394
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7550]	training's rmse: 1.97237	valid_1's rmse: 5.17331
# [7600]	training's rmse: 1.96162	valid_1's rmse: 5.17198
# [7650]	training's rmse: 1.95058	valid_1's rmse: 5.17128
# [7700]	training's rmse: 1.94006	valid_1's rmse: 5.17125
# [7750]	training's rmse: 1.92935	valid_1's rmse: 5.17097
# [7800]	training's rmse: 1.91934	valid_1's rmse: 5.16975
# [7850]	training's rmse: 1.90885	valid_1's rmse: 5.16922
# [7900]	training's rmse: 1.898	valid_1's rmse: 5.16858
# [7950]	training's rmse: 1.88775	valid_1's rmse: 5.16788
# [8000]	training's rmse: 1.87779	valid_1's rmse: 5.167
# Did not meet early stopping. Best iteration is:
# [8000]	training's rmse: 1.87779	valid_1's rmse: 5.167
# Train RMSE: 1.8777925285231039        Valida RMSE: 5.167004627988776
# Columns: ['emb_product_name_250', 'emb_product_name_41', 'emb_product_name_633', 'emb_ingredients_text_275', 'emb_brands_tags_563', 'emb_brands_tags_650', 'emb_ingredients_text_685', 'emb_ingredients_text_285', 'emb_ingredients_text_84', 'emb_ingredients_text_356', 'emb_brands_tags_494', 'emb_ingredients_text_102', 'emb_ingredients_text_71', 'emb_brands_tags_619', 'emb_ingredients_text_591', 'emb_ingredients_text_409', 'emb_product_name_550', 'emb_ingredients_text_351', 'emb_ingredients_text_122', 'emb_ingredients_text_100', 'emb_brands_tags_267', 'emb_ingredients_text_47', 'emb_brands_tags_300', 'emb_product_name_422', 'emb_brands_tags_432', 'emb_ingredients_text_761', 'emb_product_name_291', 'emb_product_name_599', 'emb_ingredients_text_211', 'emb_brands_tags_628', 'emb_ingredients_text_180', 'emb_brands_tags_324', 'emb_brands_tags_642', 'emb_ingredients_text_33', 'emb_brands_tags_537', 'emb_brands_tags_349', 'emb_product_name_125', 'emb_product_name_429', 'emb_ingredients_text_246', 'emb_product_name_105', 'emb_brands_tags_321', 'emb_ingredients_text_374', 'emb_brands_tags_766', 'emb_brands_tags_292', 'emb_ingredients_text_295', 'emb_product_name_759', 'emb_brands_tags_128', 'emb_brands_tags_375', 'emb_brands_tags_176', 'emb_product_name_667', 'emb_ingredients_text_109', 'emb_ingredients_text_105', 'emb_product_name_527', 'emb_ingredients_text_254', 'emb_product_name_328', 'emb_brands_tags_72', 'emb_ingredients_text_424', 'emb_product_name_767', 'emb_brands_tags_459', 'emb_brands_tags_633', 'emb_product_name_77', 'emb_brands_tags_151', 'emb_product_name_695', 'emb_ingredients_text_153', 'emb_ingredients_text_497', 'emb_ingredients_text_116', 'emb_brands_tags_400', 'emb_product_name_748', 'emb_product_name_464', 'emb_ingredients_text_257', 'emb_product_name_744', 'emb_product_name_189', 'emb_ingredients_text_353', 'emb_brands_tags_472', 'emb_product_name_456', 'emb_ingredients_text_661', 'emb_brands_tags_135', 'emb_brands_tags_47', 'emb_product_name_99', 'emb_brands_tags_753', 'emb_product_name_448', 'emb_product_name_645', 'emb_product_name_255', 'emb_product_name_16', 'emb_ingredients_text_82', 'emb_product_name_489', 'emb_brands_tags_109', 'emb_brands_tags_149', 'emb_brands_tags_272', 'emb_product_name_303', 'emb_product_name_445', 'emb_product_name_610', 'emb_product_name_39', 'emb_product_name_3', 'emb_ingredients_text_361', 'emb_ingredients_text_251', 'emb_brands_tags_544', 'emb_product_name_423', 'emb_product_name_447', 'emb_brands_tags_447', 'emb_ingredients_text_476', 'emb_brands_tags_661', 'emb_ingredients_text_417', 'emb_brands_tags_216', 'emb_product_name_59', 'emb_ingredients_text_316', 'emb_product_name_404', 'emb_brands_tags_751', 'emb_product_name_413', 'emb_ingredients_text_61', 'emb_brands_tags_398', 'emb_brands_tags_172', 'emb_ingredients_text_313', 'emb_brands_tags_504', 'emb_brands_tags_384', 'emb_ingredients_text_34', 'emb_ingredients_text_255', 'emb_product_name_361', 'emb_brands_tags_606', 'emb_ingredients_text_736', 'emb_product_name_505', 'emb_ingredients_text_588', 'emb_product_name_183', 'emb_ingredients_text_189', 'emb_brands_tags_728', 'emb_brands_tags_548', 'emb_product_name_719', 'emb_ingredients_text_433', 'emb_brands_tags_320', 'emb_ingredients_text_480', 'emb_brands_tags_316', 'emb_ingredients_text_689', 'emb_product_name_747', 'emb_ingredients_text_693', 'emb_brands_tags_29', 'emb_brands_tags_524', 'emb_brands_tags_665', 'emb_product_name_277', 'emb_ingredients_text_332', 'emb_product_name_1', 'emb_product_name_576', 'emb_product_name_426', 'emb_ingredients_text_95', 'emb_brands_tags_93', 'emb_brands_tags_234', 'emb_product_name_395', 'emb_ingredients_text_474', 'emb_ingredients_text_471', 'emb_product_name_587', 'emb_ingredients_text_747', 'emb_ingredients_text_589', 'emb_ingredients_text_266', 'emb_product_name_590', 'emb_ingredients_text_737', 'emb_brands_tags_584', 'emb_brands_tags_686', 'emb_product_name_115', 'emb_brands_tags_329', 'emb_brands_tags_427', 'emb_brands_tags_360', 'emb_i ...
# Cat index: [2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321]
# ---------- Training fold Nº 2 ----------
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 587901
# [LightGBM] [Info] Number of data points in the train set: 81622, number of used features: 2322
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 9.169930
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 6.91068	valid_1's rmse: 6.98658
# [100]	training's rmse: 6.50595	valid_1's rmse: 6.63667
# [150]	training's rmse: 6.26724	valid_1's rmse: 6.44882
# [200]	training's rmse: 6.08576	valid_1's rmse: 6.30903
# [250]	training's rmse: 5.94276	valid_1's rmse: 6.21092
# [300]	training's rmse: 5.81841	valid_1's rmse: 6.12679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	training's rmse: 5.71041	valid_1's rmse: 6.05741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	training's rmse: 5.61615	valid_1's rmse: 6.00038
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	training's rmse: 5.52954	valid_1's rmse: 5.95351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	training's rmse: 5.45027	valid_1's rmse: 5.9097
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	training's rmse: 5.37382	valid_1's rmse: 5.87267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	training's rmse: 5.30474	valid_1's rmse: 5.83831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [650]	training's rmse: 5.23918	valid_1's rmse: 5.80824
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [700]	training's rmse: 5.17563	valid_1's rmse: 5.77955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	training's rmse: 5.11413	valid_1's rmse: 5.75179
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's rmse: 5.05788	valid_1's rmse: 5.73154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	training's rmse: 5.00271	valid_1's rmse: 5.71075
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [900]	training's rmse: 4.94835	valid_1's rmse: 5.69148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	training's rmse: 4.8974	valid_1's rmse: 5.67209
# [1000]	training's rmse: 4.84538	valid_1's rmse: 5.654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1050]	training's rmse: 4.79523	valid_1's rmse: 5.63458
# [1100]	training's rmse: 4.74892	valid_1's rmse: 5.62161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1150]	training's rmse: 4.70124	valid_1's rmse: 5.60661
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1200]	training's rmse: 4.65742	valid_1's rmse: 5.59356
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1250]	training's rmse: 4.61405	valid_1's rmse: 5.58036
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1300]	training's rmse: 4.57124	valid_1's rmse: 5.57188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1350]	training's rmse: 4.5297	valid_1's rmse: 5.55834
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1400]	training's rmse: 4.48954	valid_1's rmse: 5.54785
# [1450]	training's rmse: 4.4493	valid_1's rmse: 5.53745
# [1500]	training's rmse: 4.41063	valid_1's rmse: 5.52627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1550]	training's rmse: 4.37271	valid_1's rmse: 5.51888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1600]	training's rmse: 4.33563	valid_1's rmse: 5.50819
# [1650]	training's rmse: 4.29797	valid_1's rmse: 5.49676
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1700]	training's rmse: 4.26111	valid_1's rmse: 5.48725
# [1750]	training's rmse: 4.225	valid_1's rmse: 5.47946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	training's rmse: 4.18888	valid_1's rmse: 5.47244
# [1850]	training's rmse: 4.15447	valid_1's rmse: 5.46677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	training's rmse: 4.12007	valid_1's rmse: 5.45949
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1950]	training's rmse: 4.08648	valid_1's rmse: 5.45309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	training's rmse: 4.05415	valid_1's rmse: 5.44851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2050]	training's rmse: 4.02258	valid_1's rmse: 5.44313
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2100]	training's rmse: 3.99017	valid_1's rmse: 5.43774
# [2150]	training's rmse: 3.95873	valid_1's rmse: 5.43065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2200]	training's rmse: 3.92728	valid_1's rmse: 5.42574
# [2250]	training's rmse: 3.89712	valid_1's rmse: 5.42
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2300]	training's rmse: 3.86771	valid_1's rmse: 5.41519
# [2350]	training's rmse: 3.83789	valid_1's rmse: 5.41011
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2400]	training's rmse: 3.80969	valid_1's rmse: 5.40597
# [2450]	training's rmse: 3.78082	valid_1's rmse: 5.40031
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2500]	training's rmse: 3.75264	valid_1's rmse: 5.39573
# [2550]	training's rmse: 3.72562	valid_1's rmse: 5.39079
# [2600]	training's rmse: 3.69639	valid_1's rmse: 5.38605
# [2650]	training's rmse: 3.66948	valid_1's rmse: 5.38198
# [2700]	training's rmse: 3.64299	valid_1's rmse: 5.37854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2750]	training's rmse: 3.61704	valid_1's rmse: 5.37398
# [2800]	training's rmse: 3.59093	valid_1's rmse: 5.36741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2850]	training's rmse: 3.56494	valid_1's rmse: 5.3649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2900]	training's rmse: 3.53999	valid_1's rmse: 5.36234
# [2950]	training's rmse: 3.51476	valid_1's rmse: 5.35838
# [3000]	training's rmse: 3.48916	valid_1's rmse: 5.35433
# [3050]	training's rmse: 3.46441	valid_1's rmse: 5.35241
# [3100]	training's rmse: 3.43875	valid_1's rmse: 5.35014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3150]	training's rmse: 3.41453	valid_1's rmse: 5.34751
# [3200]	training's rmse: 3.38989	valid_1's rmse: 5.34379
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3250]	training's rmse: 3.36644	valid_1's rmse: 5.34039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3300]	training's rmse: 3.34288	valid_1's rmse: 5.33636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3350]	training's rmse: 3.31937	valid_1's rmse: 5.3328
# [3400]	training's rmse: 3.29649	valid_1's rmse: 5.33021
# [3450]	training's rmse: 3.27421	valid_1's rmse: 5.32693
# [3500]	training's rmse: 3.25174	valid_1's rmse: 5.32295
# [3550]	training's rmse: 3.22919	valid_1's rmse: 5.32031
# [3600]	training's rmse: 3.20674	valid_1's rmse: 5.31728
# [3650]	training's rmse: 3.1846	valid_1's rmse: 5.31457
# [3700]	training's rmse: 3.16319	valid_1's rmse: 5.31131
# [3750]	training's rmse: 3.14124	valid_1's rmse: 5.30849
# [3800]	training's rmse: 3.11956	valid_1's rmse: 5.30572
# [3850]	training's rmse: 3.09869	valid_1's rmse: 5.3033
# [3900]	training's rmse: 3.07675	valid_1's rmse: 5.301
# [3950]	training's rmse: 3.05543	valid_1's rmse: 5.29866
# [4000]	training's rmse: 3.0341	valid_1's rmse: 5.29726
# [4050]	training's rmse: 3.01435	valid_1's rmse: 5.29467
# [4100]	training's rmse: 2.99372	valid_1's rmse: 5.29203
# [4150]	training's rmse: 2.97301	valid_1's rmse: 5.28884
# [4200]	training's rmse: 2.95281	valid_1's rmse: 5.28571
# [4250]	training's rmse: 2.93343	valid_1's rmse: 5.28408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4300]	training's rmse: 2.91473	valid_1's rmse: 5.28371
# [4350]	training's rmse: 2.89532	valid_1's rmse: 5.28259
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4400]	training's rmse: 2.87657	valid_1's rmse: 5.2802
# [4450]	training's rmse: 2.85728	valid_1's rmse: 5.27862
# [4500]	training's rmse: 2.8388	valid_1's rmse: 5.27671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4550]	training's rmse: 2.82016	valid_1's rmse: 5.27492
# [4600]	training's rmse: 2.80127	valid_1's rmse: 5.274
# [4650]	training's rmse: 2.7842	valid_1's rmse: 5.27365
# [4700]	training's rmse: 2.7666	valid_1's rmse: 5.27121
# [4750]	training's rmse: 2.7489	valid_1's rmse: 5.26982
# [4800]	training's rmse: 2.73156	valid_1's rmse: 5.26879
# [4850]	training's rmse: 2.71383	valid_1's rmse: 5.26819
# [4900]	training's rmse: 2.69677	valid_1's rmse: 5.26642
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4950]	training's rmse: 2.68019	valid_1's rmse: 5.26478
# [5000]	training's rmse: 2.66331	valid_1's rmse: 5.26264
# [5050]	training's rmse: 2.64656	valid_1's rmse: 5.26156
# [5100]	training's rmse: 2.63	valid_1's rmse: 5.25967
# [5150]	training's rmse: 2.61354	valid_1's rmse: 5.25751
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5200]	training's rmse: 2.59704	valid_1's rmse: 5.25622
# [5250]	training's rmse: 2.58085	valid_1's rmse: 5.25478
# [5300]	training's rmse: 2.56475	valid_1's rmse: 5.25268
# [5350]	training's rmse: 2.54893	valid_1's rmse: 5.25228
# [5400]	training's rmse: 2.53338	valid_1's rmse: 5.25055
# [5450]	training's rmse: 2.51743	valid_1's rmse: 5.24812
# [5500]	training's rmse: 2.50232	valid_1's rmse: 5.24743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5550]	training's rmse: 2.48754	valid_1's rmse: 5.24627
# [5600]	training's rmse: 2.47229	valid_1's rmse: 5.24517
# [5650]	training's rmse: 2.45771	valid_1's rmse: 5.24423
# [5700]	training's rmse: 2.44259	valid_1's rmse: 5.24253
# [5750]	training's rmse: 2.42783	valid_1's rmse: 5.24163
# [5800]	training's rmse: 2.41308	valid_1's rmse: 5.24009
# [5850]	training's rmse: 2.39823	valid_1's rmse: 5.23944
# [5900]	training's rmse: 2.38341	valid_1's rmse: 5.23812
# [5950]	training's rmse: 2.36904	valid_1's rmse: 5.23718
# [6000]	training's rmse: 2.35528	valid_1's rmse: 5.23572
# [6050]	training's rmse: 2.34067	valid_1's rmse: 5.23444
# [6100]	training's rmse: 2.32674	valid_1's rmse: 5.23333
# [6150]	training's rmse: 2.31301	valid_1's rmse: 5.23233
# [6200]	training's rmse: 2.29962	valid_1's rmse: 5.23166
# [6250]	training's rmse: 2.28581	valid_1's rmse: 5.23068
# [6300]	training's rmse: 2.27298	valid_1's rmse: 5.23012
# [6350]	training's rmse: 2.25957	valid_1's rmse: 5.22914
# [6400]	training's rmse: 2.24666	valid_1's rmse: 5.2277
# [6450]	training's rmse: 2.23293	valid_1's rmse: 5.22777
# [6500]	training's rmse: 2.22033	valid_1's rmse: 5.22726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6550]	training's rmse: 2.2078	valid_1's rmse: 5.22654
# [6600]	training's rmse: 2.19477	valid_1's rmse: 5.22568
# [6650]	training's rmse: 2.18178	valid_1's rmse: 5.22473
# [6700]	training's rmse: 2.16889	valid_1's rmse: 5.2239
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6750]	training's rmse: 2.15666	valid_1's rmse: 5.22273
# [6800]	training's rmse: 2.14414	valid_1's rmse: 5.22174
# [6850]	training's rmse: 2.13254	valid_1's rmse: 5.22037
# [6900]	training's rmse: 2.12097	valid_1's rmse: 5.21949
# [6950]	training's rmse: 2.10862	valid_1's rmse: 5.21871
# [7000]	training's rmse: 2.09643	valid_1's rmse: 5.21853
# [7050]	training's rmse: 2.08519	valid_1's rmse: 5.21748
# [7100]	training's rmse: 2.07309	valid_1's rmse: 5.2167
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7150]	training's rmse: 2.06162	valid_1's rmse: 5.21578
# [7200]	training's rmse: 2.04995	valid_1's rmse: 5.21517
# [7250]	training's rmse: 2.03866	valid_1's rmse: 5.21384
# [7300]	training's rmse: 2.02739	valid_1's rmse: 5.21351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7350]	training's rmse: 2.01638	valid_1's rmse: 5.21278
# [7400]	training's rmse: 2.00551	valid_1's rmse: 5.21246
# [7450]	training's rmse: 1.99434	valid_1's rmse: 5.21176
# [7500]	training's rmse: 1.98349	valid_1's rmse: 5.21117
# [7550]	training's rmse: 1.9726	valid_1's rmse: 5.21025
# [7600]	training's rmse: 1.96112	valid_1's rmse: 5.21046
# [7650]	training's rmse: 1.95045	valid_1's rmse: 5.20951
# [7700]	training's rmse: 1.93999	valid_1's rmse: 5.20882
# [7750]	training's rmse: 1.92929	valid_1's rmse: 5.20808
# [7800]	training's rmse: 1.91848	valid_1's rmse: 5.20744
# [7850]	training's rmse: 1.9081	valid_1's rmse: 5.20651
# [7900]	training's rmse: 1.89756	valid_1's rmse: 5.20544
# [7950]	training's rmse: 1.88716	valid_1's rmse: 5.20453
# [8000]	training's rmse: 1.87668	valid_1's rmse: 5.20374
# Did not meet early stopping. Best iteration is:
# [8000]	training's rmse: 1.87668	valid_1's rmse: 5.20374
# Train RMSE: 1.876680918282477        Valida RMSE: 5.2037396396915065
# Columns: ['emb_product_name_250', 'emb_product_name_41', 'emb_product_name_633', 'emb_ingredients_text_275', 'emb_brands_tags_563', 'emb_brands_tags_650', 'emb_ingredients_text_685', 'emb_ingredients_text_285', 'emb_ingredients_text_84', 'emb_ingredients_text_356', 'emb_brands_tags_494', 'emb_ingredients_text_102', 'emb_ingredients_text_71', 'emb_brands_tags_619', 'emb_ingredients_text_591', 'emb_ingredients_text_409', 'emb_product_name_550', 'emb_ingredients_text_351', 'emb_ingredients_text_122', 'emb_ingredients_text_100', 'emb_brands_tags_267', 'emb_ingredients_text_47', 'emb_brands_tags_300', 'emb_product_name_422', 'emb_brands_tags_432', 'emb_ingredients_text_761', 'emb_product_name_291', 'emb_product_name_599', 'emb_ingredients_text_211', 'emb_brands_tags_628', 'emb_ingredients_text_180', 'emb_brands_tags_324', 'emb_brands_tags_642', 'emb_ingredients_text_33', 'emb_brands_tags_537', 'emb_brands_tags_349', 'emb_product_name_125', 'emb_product_name_429', 'emb_ingredients_text_246', 'emb_product_name_105', 'emb_brands_tags_321', 'emb_ingredients_text_374', 'emb_brands_tags_766', 'emb_brands_tags_292', 'emb_ingredients_text_295', 'emb_product_name_759', 'emb_brands_tags_128', 'emb_brands_tags_375', 'emb_brands_tags_176', 'emb_product_name_667', 'emb_ingredients_text_109', 'emb_ingredients_text_105', 'emb_product_name_527', 'emb_ingredients_text_254', 'emb_product_name_328', 'emb_brands_tags_72', 'emb_ingredients_text_424', 'emb_product_name_767', 'emb_brands_tags_459', 'emb_brands_tags_633', 'emb_product_name_77', 'emb_brands_tags_151', 'emb_product_name_695', 'emb_ingredients_text_153', 'emb_ingredients_text_497', 'emb_ingredients_text_116', 'emb_brands_tags_400', 'emb_product_name_748', 'emb_product_name_464', 'emb_ingredients_text_257', 'emb_product_name_744', 'emb_product_name_189', 'emb_ingredients_text_353', 'emb_brands_tags_472', 'emb_product_name_456', 'emb_ingredients_text_661', 'emb_brands_tags_135', 'emb_brands_tags_47', 'emb_product_name_99', 'emb_brands_tags_753', 'emb_product_name_448', 'emb_product_name_645', 'emb_product_name_255', 'emb_product_name_16', 'emb_ingredients_text_82', 'emb_product_name_489', 'emb_brands_tags_109', 'emb_brands_tags_149', 'emb_brands_tags_272', 'emb_product_name_303', 'emb_product_name_445', 'emb_product_name_610', 'emb_product_name_39', 'emb_product_name_3', 'emb_ingredients_text_361', 'emb_ingredients_text_251', 'emb_brands_tags_544', 'emb_product_name_423', 'emb_product_name_447', 'emb_brands_tags_447', 'emb_ingredients_text_476', 'emb_brands_tags_661', 'emb_ingredients_text_417', 'emb_brands_tags_216', 'emb_product_name_59', 'emb_ingredients_text_316', 'emb_product_name_404', 'emb_brands_tags_751', 'emb_product_name_413', 'emb_ingredients_text_61', 'emb_brands_tags_398', 'emb_brands_tags_172', 'emb_ingredients_text_313', 'emb_brands_tags_504', 'emb_brands_tags_384', 'emb_ingredients_text_34', 'emb_ingredients_text_255', 'emb_product_name_361', 'emb_brands_tags_606', 'emb_ingredients_text_736', 'emb_product_name_505', 'emb_ingredients_text_588', 'emb_product_name_183', 'emb_ingredients_text_189', 'emb_brands_tags_728', 'emb_brands_tags_548', 'emb_product_name_719', 'emb_ingredients_text_433', 'emb_brands_tags_320', 'emb_ingredients_text_480', 'emb_brands_tags_316', 'emb_ingredients_text_689', 'emb_product_name_747', 'emb_ingredients_text_693', 'emb_brands_tags_29', 'emb_brands_tags_524', 'emb_brands_tags_665', 'emb_product_name_277', 'emb_ingredients_text_332', 'emb_product_name_1', 'emb_product_name_576', 'emb_product_name_426', 'emb_ingredients_text_95', 'emb_brands_tags_93', 'emb_brands_tags_234', 'emb_product_name_395', 'emb_ingredients_text_474', 'emb_ingredients_text_471', 'emb_product_name_587', 'emb_ingredients_text_747', 'emb_ingredients_text_589', 'emb_ingredients_text_266', 'emb_product_name_590', 'emb_ingredients_text_737', 'emb_brands_tags_584', 'emb_brands_tags_686', 'emb_product_name_115', 'emb_brands_tags_329', 'emb_brands_tags_427', 'emb_brands_tags_360', 'emb_i ...
# Cat index: [2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321]
# ---------- Training fold Nº 3 ----------
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 587901
# [LightGBM] [Info] Number of data points in the train set: 81622, number of used features: 2322
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 9.171253
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 6.91366	valid_1's rmse: 6.95196
# [100]	training's rmse: 6.51201	valid_1's rmse: 6.60358
# [150]	training's rmse: 6.27279	valid_1's rmse: 6.41217
# [200]	training's rmse: 6.09241	valid_1's rmse: 6.27678
# [250]	training's rmse: 5.94543	valid_1's rmse: 6.17076
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	training's rmse: 5.82641	valid_1's rmse: 6.0931
# [350]	training's rmse: 5.71883	valid_1's rmse: 6.02454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	training's rmse: 5.62296	valid_1's rmse: 5.96682
# [450]	training's rmse: 5.53534	valid_1's rmse: 5.91633
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	training's rmse: 5.4527	valid_1's rmse: 5.87068
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	training's rmse: 5.37884	valid_1's rmse: 5.83476
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	training's rmse: 5.30903	valid_1's rmse: 5.80339
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [650]	training's rmse: 5.24383	valid_1's rmse: 5.77433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [700]	training's rmse: 5.18163	valid_1's rmse: 5.74628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	training's rmse: 5.12364	valid_1's rmse: 5.7227
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's rmse: 5.06656	valid_1's rmse: 5.69922
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	training's rmse: 5.01182	valid_1's rmse: 5.67724
# [900]	training's rmse: 4.95823	valid_1's rmse: 5.65646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	training's rmse: 4.90736	valid_1's rmse: 5.64
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	training's rmse: 4.85614	valid_1's rmse: 5.62198
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1050]	training's rmse: 4.80607	valid_1's rmse: 5.60495
# [1100]	training's rmse: 4.75834	valid_1's rmse: 5.58957
# [1150]	training's rmse: 4.71239	valid_1's rmse: 5.57625
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1200]	training's rmse: 4.66735	valid_1's rmse: 5.56214
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1250]	training's rmse: 4.62263	valid_1's rmse: 5.5486
# [1300]	training's rmse: 4.57919	valid_1's rmse: 5.53765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1350]	training's rmse: 4.53713	valid_1's rmse: 5.52605
# [1400]	training's rmse: 4.49618	valid_1's rmse: 5.51436
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1450]	training's rmse: 4.4565	valid_1's rmse: 5.50512
# [1500]	training's rmse: 4.41793	valid_1's rmse: 5.49568
# [1550]	training's rmse: 4.37854	valid_1's rmse: 5.48598
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1600]	training's rmse: 4.34006	valid_1's rmse: 5.47713
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1650]	training's rmse: 4.30282	valid_1's rmse: 5.46717
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1700]	training's rmse: 4.26737	valid_1's rmse: 5.45961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1750]	training's rmse: 4.23153	valid_1's rmse: 5.45267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	training's rmse: 4.19628	valid_1's rmse: 5.44471
# ...
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 9.170246
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 6.91718	valid_1's rmse: 6.98047
# [100]	training's rmse: 6.5087	valid_1's rmse: 6.62989
# [150]	training's rmse: 6.26314	valid_1's rmse: 6.43861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	training's rmse: 6.08208	valid_1's rmse: 6.30534
# [250]	training's rmse: 5.93703	valid_1's rmse: 6.20659
# [300]	training's rmse: 5.81831	valid_1's rmse: 6.12867
# [350]	training's rmse: 5.71171	valid_1's rmse: 6.06152
# [400]	training's rmse: 5.6158	valid_1's rmse: 6.00615
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	training's rmse: 5.52808	valid_1's rmse: 5.95885
# [500]	training's rmse: 5.44974	valid_1's rmse: 5.91775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	training's rmse: 5.3776	valid_1's rmse: 5.88233
# [600]	training's rmse: 5.30564	valid_1's rmse: 5.84729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [650]	training's rmse: 5.23915	valid_1's rmse: 5.81645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [700]	training's rmse: 5.17669	valid_1's rmse: 5.7912
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	training's rmse: 5.1174	valid_1's rmse: 5.76539
# [800]	training's rmse: 5.0585	valid_1's rmse: 5.74126
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	training's rmse: 5.00583	valid_1's rmse: 5.72126
# [900]	training's rmse: 4.95259	valid_1's rmse: 5.70153
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	training's rmse: 4.90263	valid_1's rmse: 5.68432
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	training's rmse: 4.85109	valid_1's rmse: 5.66667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1050]	training's rmse: 4.80272	valid_1's rmse: 5.65101
# [1100]	training's rmse: 4.75686	valid_1's rmse: 5.638
# [1150]	training's rmse: 4.71128	valid_1's rmse: 5.62544
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1200]	training's rmse: 4.66603	valid_1's rmse: 5.6122
# [1250]	training's rmse: 4.62189	valid_1's rmse: 5.59868
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1300]	training's rmse: 4.57858	valid_1's rmse: 5.58766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1350]	training's rmse: 4.53654	valid_1's rmse: 5.57653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1400]	training's rmse: 4.49528	valid_1's rmse: 5.56551
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1450]	training's rmse: 4.45416	valid_1's rmse: 5.55539
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1500]	training's rmse: 4.41544	valid_1's rmse: 5.54706
# [1550]	training's rmse: 4.37699	valid_1's rmse: 5.5384
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1600]	training's rmse: 4.3386	valid_1's rmse: 5.52911
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1650]	training's rmse: 4.30165	valid_1's rmse: 5.52136
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1700]	training's rmse: 4.26524	valid_1's rmse: 5.51456
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1750]	training's rmse: 4.22973	valid_1's rmse: 5.50497
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	training's rmse: 4.19488	valid_1's rmse: 5.49954
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1850]	training's rmse: 4.15967	valid_1's rmse: 5.49194
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	training's rmse: 4.12563	valid_1's rmse: 5.48489
# [1950]	training's rmse: 4.09229	valid_1's rmse: 5.47855
# [2000]	training's rmse: 4.0594	valid_1's rmse: 5.47304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2050]	training's rmse: 4.02709	valid_1's rmse: 5.46769
# [2100]	training's rmse: 3.99525	valid_1's rmse: 5.46296
# [2150]	training's rmse: 3.96292	valid_1's rmse: 5.45573
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2200]	training's rmse: 3.93202	valid_1's rmse: 5.44922
# [2250]	training's rmse: 3.90119	valid_1's rmse: 5.44263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2300]	training's rmse: 3.87138	valid_1's rmse: 5.43628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2350]	training's rmse: 3.84091	valid_1's rmse: 5.43094
# [2400]	training's rmse: 3.81053	valid_1's rmse: 5.42552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2450]	training's rmse: 3.78214	valid_1's rmse: 5.42088
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2500]	training's rmse: 3.7538	valid_1's rmse: 5.4158
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2550]	training's rmse: 3.72525	valid_1's rmse: 5.41163
# [2600]	training's rmse: 3.69754	valid_1's rmse: 5.40682
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2650]	training's rmse: 3.67	valid_1's rmse: 5.40218
# [2700]	training's rmse: 3.64235	valid_1's rmse: 5.39927
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2750]	training's rmse: 3.61545	valid_1's rmse: 5.39504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2800]	training's rmse: 3.58983	valid_1's rmse: 5.39092
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2850]	training's rmse: 3.56336	valid_1's rmse: 5.38798
# [2900]	training's rmse: 3.5365	valid_1's rmse: 5.3849
# [2950]	training's rmse: 3.5111	valid_1's rmse: 5.38372
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3000]	training's rmse: 3.48508	valid_1's rmse: 5.37943
# [3050]	training's rmse: 3.45926	valid_1's rmse: 5.37602
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3100]	training's rmse: 3.43554	valid_1's rmse: 5.37365
# [3150]	training's rmse: 3.41183	valid_1's rmse: 5.37046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3200]	training's rmse: 3.38755	valid_1's rmse: 5.36885
# [3250]	training's rmse: 3.36349	valid_1's rmse: 5.36616
# [3300]	training's rmse: 3.3392	valid_1's rmse: 5.36358
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3350]	training's rmse: 3.31589	valid_1's rmse: 5.36027
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3400]	training's rmse: 3.2933	valid_1's rmse: 5.35808
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3450]	training's rmse: 3.2705	valid_1's rmse: 5.35527
# [3500]	training's rmse: 3.24802	valid_1's rmse: 5.35239
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3550]	training's rmse: 3.22562	valid_1's rmse: 5.34902
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3600]	training's rmse: 3.2044	valid_1's rmse: 5.34613
# [3650]	training's rmse: 3.1824	valid_1's rmse: 5.34457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3700]	training's rmse: 3.16066	valid_1's rmse: 5.34167
# [3750]	training's rmse: 3.13834	valid_1's rmse: 5.33946
# [3800]	training's rmse: 3.11705	valid_1's rmse: 5.33579
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3850]	training's rmse: 3.09645	valid_1's rmse: 5.33228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3900]	training's rmse: 3.07585	valid_1's rmse: 5.33056
# [3950]	training's rmse: 3.05534	valid_1's rmse: 5.3287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4000]	training's rmse: 3.03485	valid_1's rmse: 5.32679
# [4050]	training's rmse: 3.01458	valid_1's rmse: 5.32445
# [4100]	training's rmse: 2.9944	valid_1's rmse: 5.32164
# [4150]	training's rmse: 2.97411	valid_1's rmse: 5.31925
# [4200]	training's rmse: 2.95477	valid_1's rmse: 5.31799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4250]	training's rmse: 2.93553	valid_1's rmse: 5.31644
# [4300]	training's rmse: 2.91614	valid_1's rmse: 5.31283
# [4350]	training's rmse: 2.89667	valid_1's rmse: 5.31069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4400]	training's rmse: 2.87767	valid_1's rmse: 5.30967
# [4450]	training's rmse: 2.85876	valid_1's rmse: 5.30876
# [4500]	training's rmse: 2.84049	valid_1's rmse: 5.30762
# [4550]	training's rmse: 2.82209	valid_1's rmse: 5.30481
# [4600]	training's rmse: 2.8038	valid_1's rmse: 5.30268
# [4650]	training's rmse: 2.7864	valid_1's rmse: 5.30085
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4700]	training's rmse: 2.7686	valid_1's rmse: 5.29892
# [4750]	training's rmse: 2.75038	valid_1's rmse: 5.29777
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4800]	training's rmse: 2.73324	valid_1's rmse: 5.29547
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4850]	training's rmse: 2.71558	valid_1's rmse: 5.29414
# [4900]	training's rmse: 2.6983	valid_1's rmse: 5.2932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4950]	training's rmse: 2.68207	valid_1's rmse: 5.29136
# [5000]	training's rmse: 2.66498	valid_1's rmse: 5.28988
# [5050]	training's rmse: 2.64845	valid_1's rmse: 5.28849
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5100]	training's rmse: 2.6319	valid_1's rmse: 5.28758
# [5150]	training's rmse: 2.61572	valid_1's rmse: 5.28604
# [5200]	training's rmse: 2.59962	valid_1's rmse: 5.28501
# [5250]	training's rmse: 2.58373	valid_1's rmse: 5.28344
# [5300]	training's rmse: 2.56779	valid_1's rmse: 5.28222
# [5350]	training's rmse: 2.55175	valid_1's rmse: 5.28121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5400]	training's rmse: 2.53576	valid_1's rmse: 5.27987
# [5450]	training's rmse: 2.52026	valid_1's rmse: 5.2792
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5500]	training's rmse: 2.50506	valid_1's rmse: 5.27748
# [5550]	training's rmse: 2.48943	valid_1's rmse: 5.2766
# [5600]	training's rmse: 2.47391	valid_1's rmse: 5.27557
# [5650]	training's rmse: 2.45833	valid_1's rmse: 5.27413
# [5700]	training's rmse: 2.44288	valid_1's rmse: 5.27308
# [5750]	training's rmse: 2.42825	valid_1's rmse: 5.27148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5800]	training's rmse: 2.4133	valid_1's rmse: 5.2705
# [5850]	training's rmse: 2.3989	valid_1's rmse: 5.26962
# [5900]	training's rmse: 2.38467	valid_1's rmse: 5.26805
# [5950]	training's rmse: 2.371	valid_1's rmse: 5.26733
# [6000]	training's rmse: 2.35715	valid_1's rmse: 5.26633
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6050]	training's rmse: 2.34286	valid_1's rmse: 5.26504
# [6100]	training's rmse: 2.32814	valid_1's rmse: 5.26337
# [6150]	training's rmse: 2.31429	valid_1's rmse: 5.26156
# [6200]	training's rmse: 2.30027	valid_1's rmse: 5.26062
# [6250]	training's rmse: 2.28706	valid_1's rmse: 5.26023
# [6300]	training's rmse: 2.27326	valid_1's rmse: 5.25994
# [6350]	training's rmse: 2.25973	valid_1's rmse: 5.25822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6400]	training's rmse: 2.24649	valid_1's rmse: 5.2567
# [6450]	training's rmse: 2.23325	valid_1's rmse: 5.25663
# [6500]	training's rmse: 2.2204	valid_1's rmse: 5.25615
# [6550]	training's rmse: 2.20758	valid_1's rmse: 5.25498
# [6600]	training's rmse: 2.19453	valid_1's rmse: 5.25353
# [6650]	training's rmse: 2.18173	valid_1's rmse: 5.25244
# [6700]	training's rmse: 2.16892	valid_1's rmse: 5.25157
# [6750]	training's rmse: 2.15695	valid_1's rmse: 5.25051
# [6800]	training's rmse: 2.14425	valid_1's rmse: 5.25037
# [6850]	training's rmse: 2.13168	valid_1's rmse: 5.2499
# [6900]	training's rmse: 2.1194	valid_1's rmse: 5.24963
# [6950]	training's rmse: 2.10764	valid_1's rmse: 5.24883
# [7000]	training's rmse: 2.09567	valid_1's rmse: 5.24866
# [7050]	training's rmse: 2.08339	valid_1's rmse: 5.24832
# [7100]	training's rmse: 2.07148	valid_1's rmse: 5.24763
# [7150]	training's rmse: 2.0592	valid_1's rmse: 5.24653
# [7200]	training's rmse: 2.0474	valid_1's rmse: 5.24573
# [7250]	training's rmse: 2.03582	valid_1's rmse: 5.245
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7300]	training's rmse: 2.02434	valid_1's rmse: 5.24403
# [7350]	training's rmse: 2.01269	valid_1's rmse: 5.2435
# [7400]	training's rmse: 2.00122	valid_1's rmse: 5.24308
# [7450]	training's rmse: 1.99009	valid_1's rmse: 5.24195
# [7500]	training's rmse: 1.97921	valid_1's rmse: 5.24106
# [7550]	training's rmse: 1.96828	valid_1's rmse: 5.24043
# [7600]	training's rmse: 1.95702	valid_1's rmse: 5.24066
# [7650]	training's rmse: 1.94616	valid_1's rmse: 5.24018
# [7700]	training's rmse: 1.93607	valid_1's rmse: 5.24008
# [7750]	training's rmse: 1.92524	valid_1's rmse: 5.23896
# [7800]	training's rmse: 1.91475	valid_1's rmse: 5.23868
# [7850]	training's rmse: 1.9042	valid_1's rmse: 5.2374
# [7900]	training's rmse: 1.89398	valid_1's rmse: 5.23701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7950]	training's rmse: 1.88338	valid_1's rmse: 5.23522
# [8000]	training's rmse: 1.87365	valid_1's rmse: 5.23469
# Did not meet early stopping. Best iteration is:
# [8000]	training's rmse: 1.87365	valid_1's rmse: 5.23469
# Train RMSE: 1.8736499314048347        Valida RMSE: 5.234689852204284
# OOF RMSE: 5.202462203011981

# %% [markdown]
# ## Evaluando

# %%
df_test      = pd.read_csv(os.path.join(DATA_PATH,'test_preprocessed.csv'))
df_test['target'] = -1

COLUMN_NAME  = 'product_name' 

test_dataset = BNPParibasText(df_test,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = XLMRoberta(pretrained_model=PRETRAINED)
test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_test = get_embedding(test_loader, model, 'cuda')
df_test[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_test.shape[1])]] = emb_sentence_test


COLUMN_NAME  = 'ingredients_text' 

test_dataset = BNPParibasText(df_test,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = XLMRoberta(pretrained_model=PRETRAINED)
test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_test = get_embedding(test_loader, model, 'cuda')
df_test[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_test.shape[1])]] = emb_sentence_test

COLUMN_NAME  = 'brands_tags' 

test_dataset = BNPParibasText(df_test,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = XLMRoberta(pretrained_model=PRETRAINED)
test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_test = get_embedding(test_loader, model, 'cuda')
df_test[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_test.shape[1])]] = emb_sentence_test

df_test = apply_label_encoder(df_test,dict_le,drop_original = True, missing_new_cat = True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=798.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=798.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=798.0), HTML(value='')))
# Mode: Missing as new category
# Applying Label Encoding:  label_states_en_brands
# Applying Label Encoding:  label_states_en_categories
# Applying Label Encoding:  label_states_en_characteristics
# Applying Label Encoding:  label_states_en_expiration date
# Applying Label Encoding:  label_states_en_general_complete
# Applying Label Encoding:  label_states_en_ingredients
# Applying Label Encoding:  label_pnns_groups_1
# Applying Label Encoding:  label_pnns_groups_2
# Applying Label Encoding:  label_states_en_packaging
# Applying Label Encoding:  label_states_en_packaging-code-
# Applying Label Encoding:  label_states_en_photo_upload
# Applying Label Encoding:  label_states_en_photo_validate
# Applying Label Encoding:  label_states_en_product name
# Applying Label Encoding:  label_states_en_quantity

# %%
probs = 0
for i in models:
    probs = probs + (i.predict(df_test[feature_list]))
    print('fin_predict')
y_test_pred = probs/5.0
print(f'Real: ',math.sqrt(mean_squared_error(y_test_pred,df_test['Target'].values)))
# Out:
# fin_predict
# fin_predict
# fin_predict
# fin_predict
# fin_predict
# Real:  5.029986946556404

# %%
print(f'Real: ',math.sqrt(mean_squared_error(df_test['preds'],df_test['Target'].values)))
# Out:
# Real:  4.949090622538854

# %%
y_submission['target'] = df_test['preds'].values
y_submission.head()
# Out:
#         target
# Index
# 37320     14.0
# 3913      23.0
# 112180     8.0
# 128820    12.0
# 16037     22.0

# %%
#Enviar los resultados
apiquery.submit_api(y_submission,
       competition_name='food',
        subname='test_v8', # Pueden cambiar esto sin problemas, poner el nombre que quieran.
        holdout_key='None',
        update_ldb=True,
        username="Insight ML - DD" # Poner el nombre de su equipo como un string. 
                                  # El mejor de los resultados dentro de sus envios es el que aparecera en la tabla de posiciones.
)
# Out:
# requests number 1
# 200
# {'Date': 'Thu, 20 May 2021 01:12:51 GMT', 'Content-Type': 'application/json', 'Content-Length': '496', 'Connection': 'keep-alive', 'X-Request-ID': '38TKR5SBNUC2OIEL', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'POST', 'Access-Control-Allow-Headers': 'authorization,content-type'}
# {'competition_name': 'food',
#  'file_path': 'none',
#  'message': 'Submission validated.',
#  'name': 'Insight ML - DD',
#  'result_csv_file': 'test_v8',
#  'score': 4.949135680861754,
#  'score2': None,
#  'score3': None,
#  'sub_name': 'test_v8',
#  'sub_uid': '3c742345-a4bd-4d05-9512-1c905b235010',
#  'submission_time': '2021/05/20, 01:12:51'}
