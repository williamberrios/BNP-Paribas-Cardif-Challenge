# %%
import shutil
import apiquery
import pandas as pd
import sys
import seaborn as sns
import os
import torch
import numpy as np
import random
DATA_PATH = '../01.Data'
shutil.copy("apiquery_pyc.py", "apiquery.pyc")
module_path = "../src"
if module_path not in sys.path:
    sys.path.append(module_path)
    
from utils.training import *
from utils.encoding import *
from utils.utils import *
from models.models import Roberta_Model
from dataset.dataset import BNPParibasText
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
import math
from collections import Counter
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
import math
import time
import matplotlib.pyplot as plt
import transformers
pd.set_option('display.max_rows',100 )

# %%
def get_embedding(data_loader, model, device):
    from tqdm.notebook import tqdm
    # Put the model in eval mode
    model.to(device)
    model.eval()
    # List for store final predictions
    final_predictions = []
    with torch.no_grad():
        tk0 = tqdm(data_loader, total=len(data_loader))
        for b_idx, data in enumerate(tk0):
            for key,value in data.items():
                data[key] = value.to(device)
            predictions = model._embeddings(data['ids'],data['mask'])
            predictions = predictions.cpu()
            final_predictions.append(predictions)
    return np.vstack(final_predictions)

# %%
MAX_LENGTH   = 16
PRETRAINED   = 'roberta-base'
SEED         = 42

# %%
# %%time
df_train     = pd.read_csv(os.path.join("../01.Data",'fold.csv'))
y_submission = pd.read_csv(os.path.join(DATA_PATH,'y_test_submission_example.tsv'), index_col='Index', encoding='utf-8', sep='\t')
# Out:
# CPU times: user 2.42 s, sys: 237 ms, total: 2.65 s
# Wall time: 2.65 s

# %%
seed_everything(SEED)

# %%
# %%time
COLUMN_NAME  = 'product_name' 
tokenizer     = transformers.RobertaTokenizer.from_pretrained(PRETRAINED)
train_dataset = BNPParibasText(df_train,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = Roberta_Model(pretrained_model=PRETRAINED)
train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_train = get_embedding(train_loader, model, 'cuda')
df_train[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_train.shape[1])]] = emb_sentence_train
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3189.0), HTML(value='')))
# CPU times: user 1min 29s, sys: 14.1 s, total: 1min 43s
# Wall time: 1min 34s

# %%
COLUMN_NAME  = 'ingredients_text' 
tokenizer     = transformers.RobertaTokenizer.from_pretrained(PRETRAINED)
train_dataset = BNPParibasText(df_train,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = Roberta_Model(pretrained_model=PRETRAINED)
train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_train = get_embedding(train_loader, model, 'cuda')
df_train[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_train.shape[1])]] = emb_sentence_train
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3189.0), HTML(value='')))

# %%
COLUMN_NAME  = 'brands_tags' 
tokenizer     = transformers.RobertaTokenizer.from_pretrained(PRETRAINED)
train_dataset = BNPParibasText(df_train,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = Roberta_Model(pretrained_model=PRETRAINED)
train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_train = get_embedding(train_loader, model, 'cuda')
df_train[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_train.shape[1])]] = emb_sentence_train
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3189.0), HTML(value='')))

# %%
columns_modeling = ['additives_n','ingredients_from_palm_oil_n',
                    'ingredients_that_may_be_from_palm_oil_n','target',
                    'states_en_brands','states_en_categories','states_en_characteristics','states_en_expiration date',
                    'states_en_general_complete','states_en_ingredients','pnns_groups_1','pnns_groups_2',
                    'states_en_packaging','states_en_packaging-code-','states_en_photo_upload',
                    'states_en_photo_validate','states_en_product name','states_en_quantity','diff_t'] + [f'emb_product_name_{i}' for i in range(emb_sentence_train.shape[1])] + [f'emb_ingredients_text_{i}' for i in range(emb_sentence_train.shape[1])]+[f'emb_brands_tags_{i}' for i in range(emb_sentence_train.shape[1])]
columns_label = df_train[columns_modeling].select_dtypes(include=['object']).columns.to_list()
print(columns_label)
# Out:
# ['states_en_brands', 'states_en_categories', 'states_en_characteristics', 'states_en_expiration date', 'states_en_general_complete', 'states_en_ingredients', 'pnns_groups_1', 'pnns_groups_2', 'states_en_packaging', 'states_en_packaging-code-', 'states_en_photo_upload', 'states_en_photo_validate', 'states_en_product name', 'states_en_quantity']

# %%
df_train,dict_le = label_encoding(df_train,label_cols = columns_label, drop_original = True, missing_new_cat = True)
# Out:
# Mode: Missing as new category
# Label Encoding:  label_states_en_brands
# Label Encoding:  label_states_en_categories
# Label Encoding:  label_states_en_characteristics
# Label Encoding:  label_states_en_expiration date
# Label Encoding:  label_states_en_general_complete
# Label Encoding:  label_states_en_ingredients
# Label Encoding:  label_pnns_groups_1
# Label Encoding:  label_pnns_groups_2
# Label Encoding:  label_states_en_packaging
# Label Encoding:  label_states_en_packaging-code-
# Label Encoding:  label_states_en_photo_upload
# Label Encoding:  label_states_en_photo_validate
# Label Encoding:  label_states_en_product name
# Label Encoding:  label_states_en_quantity

# %%
params = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'regression',
        'metric': {'rmse'},
        'num_leaves':12,
        'learning_rate': 0.08,
        "min_child_samples": 150,
        "max_depth" : 5,
        'feature_fraction':  0.5,
        "bagging_freq": 1,
        'bagging_fraction': 0.75,
        "is_unbalance" : False,
        'force_col_wise':True,
        'num_threads':18,
        #"scale_pos_weight":5 -> Generally  is the ratio of number of negative class to the positive class.
        'bagging_seed':42,
        'lambda_l1':1.5,
        'lambda_l2':1,
        'verbose': 1

}
cat_columns = [i for i in df_train.columns.to_list() if i.startswith('label_')]
columns_modeling_last = list(set(columns_modeling)-set(columns_label)) + ['fold'] + cat_columns

# %%
results,models,importances,oof,feature_list = Training_Lightgbm(df_train[columns_modeling_last],params,fold_column = 'fold',target_column = 'target',cat_vars = cat_columns ,metric = 'RMSE',early_stopping = 200,max_boost_round = 8000)
# Out:
# Columns: ['emb_product_name_516', 'emb_ingredients_text_444', 'emb_ingredients_text_648', 'emb_ingredients_text_157', 'emb_product_name_295', 'emb_ingredients_text_126', 'emb_ingredients_text_634', 'emb_ingredients_text_740', 'emb_brands_tags_27', 'emb_brands_tags_292', 'emb_brands_tags_764', 'emb_product_name_40', 'emb_ingredients_text_621', 'emb_product_name_616', 'emb_product_name_721', 'emb_ingredients_text_22', 'emb_brands_tags_738', 'emb_brands_tags_452', 'emb_ingredients_text_490', 'emb_ingredients_text_223', 'emb_product_name_369', 'emb_ingredients_text_5', 'emb_brands_tags_295', 'emb_ingredients_text_677', 'emb_product_name_493', 'emb_product_name_525', 'emb_product_name_655', 'emb_product_name_500', 'emb_product_name_704', 'emb_product_name_731', 'emb_brands_tags_264', 'emb_brands_tags_468', 'emb_product_name_558', 'emb_ingredients_text_315', 'emb_product_name_735', 'emb_brands_tags_178', 'emb_ingredients_text_512', 'emb_ingredients_text_556', 'emb_brands_tags_347', 'emb_product_name_336', 'emb_product_name_496', 'emb_product_name_24', 'emb_brands_tags_87', 'emb_product_name_198', 'emb_brands_tags_579', 'emb_product_name_528', 'emb_product_name_653', 'emb_ingredients_text_119', 'emb_brands_tags_727', 'emb_product_name_304', 'emb_brands_tags_668', 'emb_ingredients_text_179', 'emb_ingredients_text_513', 'emb_ingredients_text_165', 'emb_product_name_541', 'emb_ingredients_text_397', 'emb_ingredients_text_311', 'emb_ingredients_text_263', 'emb_ingredients_text_361', 'emb_ingredients_text_195', 'emb_ingredients_text_105', 'emb_ingredients_text_44', 'emb_brands_tags_485', 'emb_product_name_672', 'emb_brands_tags_83', 'emb_product_name_691', 'emb_ingredients_text_231', 'emb_product_name_152', 'emb_brands_tags_505', 'emb_product_name_287', 'emb_ingredients_text_276', 'emb_ingredients_text_603', 'emb_product_name_312', 'emb_ingredients_text_191', 'emb_ingredients_text_118', 'emb_brands_tags_362', 'emb_ingredients_text_363', 'emb_ingredients_text_108', 'emb_ingredients_text_549', 'emb_brands_tags_525', 'emb_product_name_87', 'emb_ingredients_text_164', 'emb_ingredients_text_37', 'emb_product_name_267', 'emb_brands_tags_229', 'emb_product_name_271', 'emb_product_name_566', 'emb_ingredients_text_12', 'emb_ingredients_text_174', 'emb_brands_tags_55', 'emb_product_name_711', 'emb_product_name_14', 'emb_ingredients_text_343', 'emb_product_name_741', 'emb_brands_tags_257', 'emb_ingredients_text_23', 'emb_ingredients_text_428', 'emb_brands_tags_28', 'emb_product_name_53', 'emb_ingredients_text_550', 'emb_brands_tags_406', 'emb_brands_tags_633', 'emb_ingredients_text_443', 'emb_product_name_755', 'emb_ingredients_text_63', 'emb_brands_tags_291', 'emb_brands_tags_636', 'emb_ingredients_text_127', 'emb_product_name_501', 'emb_brands_tags_238', 'emb_ingredients_text_497', 'emb_product_name_492', 'emb_ingredients_text_715', 'emb_ingredients_text_129', 'emb_product_name_465', 'emb_product_name_654', 'emb_product_name_236', 'emb_ingredients_text_294', 'emb_ingredients_text_381', 'emb_product_name_160', 'emb_ingredients_text_206', 'emb_product_name_708', 'emb_product_name_9', 'emb_brands_tags_616', 'emb_product_name_124', 'emb_ingredients_text_502', 'emb_product_name_497', 'emb_product_name_738', 'emb_brands_tags_453', 'emb_product_name_529', 'emb_ingredients_text_125', 'emb_product_name_403', 'emb_ingredients_text_741', 'emb_product_name_590', 'emb_brands_tags_124', 'emb_product_name_728', 'emb_brands_tags_0', 'emb_brands_tags_234', 'emb_ingredients_text_580', 'emb_product_name_727', 'emb_ingredients_text_289', 'emb_brands_tags_488', 'emb_ingredients_text_667', 'emb_brands_tags_203', 'emb_brands_tags_185', 'emb_brands_tags_437', 'emb_ingredients_text_586', 'emb_ingredients_text_393', 'emb_product_name_580', 'emb_ingredients_text_322', 'emb_ingredients_text_681', 'emb_brands_tags_413', 'emb_ingredients_text_658', 'emb_brands_tags_528', 'emb_ingredients_text_535', 'emb_product_name_362', 'emb_brands_tags_352', 'emb_ingredients_text_659', 'emb ...
# Cat index: [2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321]
# ---------- Training fold Nº 1 ----------
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 587900
# [LightGBM] [Info] Number of data points in the train set: 81622, number of used features: 2322
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 9.171473
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 6.7291	valid_1's rmse: 6.775
# [100]	training's rmse: 6.31221	valid_1's rmse: 6.39453
# [150]	training's rmse: 6.08458	valid_1's rmse: 6.20699
# [200]	training's rmse: 5.91025	valid_1's rmse: 6.0778
# [250]	training's rmse: 5.77522	valid_1's rmse: 5.98731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	training's rmse: 5.66109	valid_1's rmse: 5.91398
# [350]	training's rmse: 5.55914	valid_1's rmse: 5.85182
# [400]	training's rmse: 5.46682	valid_1's rmse: 5.79701
# [450]	training's rmse: 5.38092	valid_1's rmse: 5.75234
# [500]	training's rmse: 5.30334	valid_1's rmse: 5.71681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	training's rmse: 5.23249	valid_1's rmse: 5.68058
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	training's rmse: 5.16433	valid_1's rmse: 5.64823
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [650]	training's rmse: 5.09986	valid_1's rmse: 5.61827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [700]	training's rmse: 5.03835	valid_1's rmse: 5.5915
# [750]	training's rmse: 4.98063	valid_1's rmse: 5.56835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's rmse: 4.9239	valid_1's rmse: 5.54487
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	training's rmse: 4.8688	valid_1's rmse: 5.52286
# [900]	training's rmse: 4.81705	valid_1's rmse: 5.50683
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	training's rmse: 4.76726	valid_1's rmse: 5.49125
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	training's rmse: 4.71924	valid_1's rmse: 5.47444
# [1050]	training's rmse: 4.67334	valid_1's rmse: 5.4609
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1100]	training's rmse: 4.62744	valid_1's rmse: 5.44809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1150]	training's rmse: 4.58361	valid_1's rmse: 5.43475
# [1200]	training's rmse: 4.54045	valid_1's rmse: 5.42343
# [1250]	training's rmse: 4.49795	valid_1's rmse: 5.41325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1300]	training's rmse: 4.4561	valid_1's rmse: 5.40294
# [1350]	training's rmse: 4.41548	valid_1's rmse: 5.39203
# [1400]	training's rmse: 4.37609	valid_1's rmse: 5.38195
# [1450]	training's rmse: 4.33668	valid_1's rmse: 5.37145
# [1500]	training's rmse: 4.29835	valid_1's rmse: 5.36202
# [1550]	training's rmse: 4.26226	valid_1's rmse: 5.35202
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1600]	training's rmse: 4.22584	valid_1's rmse: 5.34382
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1650]	training's rmse: 4.18811	valid_1's rmse: 5.33668
# [1700]	training's rmse: 4.1532	valid_1's rmse: 5.33034
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1750]	training's rmse: 4.11884	valid_1's rmse: 5.32406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	training's rmse: 4.08591	valid_1's rmse: 5.31696
# [1850]	training's rmse: 4.05187	valid_1's rmse: 5.31011
# [1900]	training's rmse: 4.02007	valid_1's rmse: 5.30333
# [1950]	training's rmse: 3.98751	valid_1's rmse: 5.29724
# [2000]	training's rmse: 3.9545	valid_1's rmse: 5.28909
# [2050]	training's rmse: 3.92167	valid_1's rmse: 5.28291
# [2100]	training's rmse: 3.89038	valid_1's rmse: 5.27745
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2150]	training's rmse: 3.86055	valid_1's rmse: 5.27236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2200]	training's rmse: 3.83084	valid_1's rmse: 5.2679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2250]	training's rmse: 3.80135	valid_1's rmse: 5.26209
# [2300]	training's rmse: 3.77198	valid_1's rmse: 5.25649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2350]	training's rmse: 3.7439	valid_1's rmse: 5.25254
# [2400]	training's rmse: 3.71542	valid_1's rmse: 5.24749
# [2450]	training's rmse: 3.68669	valid_1's rmse: 5.24378
# [2500]	training's rmse: 3.65827	valid_1's rmse: 5.23901
# [2550]	training's rmse: 3.63089	valid_1's rmse: 5.23605
# [2600]	training's rmse: 3.60271	valid_1's rmse: 5.2301
# [2650]	training's rmse: 3.57629	valid_1's rmse: 5.22656
# [2700]	training's rmse: 3.54943	valid_1's rmse: 5.22365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2750]	training's rmse: 3.52315	valid_1's rmse: 5.21759
# [2800]	training's rmse: 3.4967	valid_1's rmse: 5.21324
# [2850]	training's rmse: 3.4703	valid_1's rmse: 5.20892
# [2900]	training's rmse: 3.44514	valid_1's rmse: 5.20575
# [2950]	training's rmse: 3.42062	valid_1's rmse: 5.20293
# [3000]	training's rmse: 3.39665	valid_1's rmse: 5.19905
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3050]	training's rmse: 3.37264	valid_1's rmse: 5.19506
# [3100]	training's rmse: 3.34925	valid_1's rmse: 5.19228
# [3150]	training's rmse: 3.32502	valid_1's rmse: 5.1892
# [3200]	training's rmse: 3.30131	valid_1's rmse: 5.18592
# [3250]	training's rmse: 3.27755	valid_1's rmse: 5.18253
# [3300]	training's rmse: 3.25535	valid_1's rmse: 5.18038
# [3350]	training's rmse: 3.23235	valid_1's rmse: 5.17842
# [3400]	training's rmse: 3.211	valid_1's rmse: 5.17542
# [3450]	training's rmse: 3.18848	valid_1's rmse: 5.17292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3500]	training's rmse: 3.16645	valid_1's rmse: 5.16862
# [3550]	training's rmse: 3.14479	valid_1's rmse: 5.16622
# [3600]	training's rmse: 3.1227	valid_1's rmse: 5.16438
# [3650]	training's rmse: 3.10185	valid_1's rmse: 5.16263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3700]	training's rmse: 3.08151	valid_1's rmse: 5.16087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3750]	training's rmse: 3.06098	valid_1's rmse: 5.15907
# [3800]	training's rmse: 3.04102	valid_1's rmse: 5.15735
# [3850]	training's rmse: 3.02058	valid_1's rmse: 5.15518
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3900]	training's rmse: 3.00007	valid_1's rmse: 5.15385
# [3950]	training's rmse: 2.98006	valid_1's rmse: 5.15201
# [4000]	training's rmse: 2.96033	valid_1's rmse: 5.14891
# [4050]	training's rmse: 2.94127	valid_1's rmse: 5.14602
# [4100]	training's rmse: 2.92186	valid_1's rmse: 5.14426
# [4150]	training's rmse: 2.90224	valid_1's rmse: 5.14144
# [4200]	training's rmse: 2.88326	valid_1's rmse: 5.13828
# [4250]	training's rmse: 2.86465	valid_1's rmse: 5.13637
# [4300]	training's rmse: 2.84591	valid_1's rmse: 5.13508
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4350]	training's rmse: 2.82746	valid_1's rmse: 5.13296
# [4400]	training's rmse: 2.80874	valid_1's rmse: 5.13125
# [4450]	training's rmse: 2.7906	valid_1's rmse: 5.12859
# [4500]	training's rmse: 2.77284	valid_1's rmse: 5.12739
# [4550]	training's rmse: 2.75497	valid_1's rmse: 5.12506
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4600]	training's rmse: 2.73744	valid_1's rmse: 5.12357
# [4650]	training's rmse: 2.71962	valid_1's rmse: 5.12208
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4700]	training's rmse: 2.7019	valid_1's rmse: 5.12039
# [4750]	training's rmse: 2.68476	valid_1's rmse: 5.11876
# [4800]	training's rmse: 2.66863	valid_1's rmse: 5.11734
# [4850]	training's rmse: 2.65151	valid_1's rmse: 5.11706
# [4900]	training's rmse: 2.63506	valid_1's rmse: 5.11553
# [4950]	training's rmse: 2.61863	valid_1's rmse: 5.11401
# [5000]	training's rmse: 2.60177	valid_1's rmse: 5.11201
# [5050]	training's rmse: 2.58548	valid_1's rmse: 5.11108
# [5100]	training's rmse: 2.56936	valid_1's rmse: 5.10957
# [5150]	training's rmse: 2.55416	valid_1's rmse: 5.10768
# [5200]	training's rmse: 2.5382	valid_1's rmse: 5.10566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5250]	training's rmse: 2.52265	valid_1's rmse: 5.1049
# [5300]	training's rmse: 2.50675	valid_1's rmse: 5.10397
# [5350]	training's rmse: 2.49125	valid_1's rmse: 5.10271
# [5400]	training's rmse: 2.47593	valid_1's rmse: 5.10139
# [5450]	training's rmse: 2.46077	valid_1's rmse: 5.09982
# [5500]	training's rmse: 2.44581	valid_1's rmse: 5.09868
# [5550]	training's rmse: 2.43082	valid_1's rmse: 5.09815
# [5600]	training's rmse: 2.41599	valid_1's rmse: 5.09707
# [5650]	training's rmse: 2.401	valid_1's rmse: 5.09596
# [5700]	training's rmse: 2.38624	valid_1's rmse: 5.0952
# [5750]	training's rmse: 2.3716	valid_1's rmse: 5.09308
# [5800]	training's rmse: 2.35724	valid_1's rmse: 5.09269
# [5850]	training's rmse: 2.34294	valid_1's rmse: 5.09149
# [5900]	training's rmse: 2.32915	valid_1's rmse: 5.09035
# [5950]	training's rmse: 2.31535	valid_1's rmse: 5.08911
# [6000]	training's rmse: 2.30086	valid_1's rmse: 5.08786
# [6050]	training's rmse: 2.28703	valid_1's rmse: 5.08699
# [6100]	training's rmse: 2.27303	valid_1's rmse: 5.08563
# [6150]	training's rmse: 2.26004	valid_1's rmse: 5.0852
# [6200]	training's rmse: 2.24684	valid_1's rmse: 5.08423
# [6250]	training's rmse: 2.23383	valid_1's rmse: 5.08268
# [6300]	training's rmse: 2.22057	valid_1's rmse: 5.08253
# [6350]	training's rmse: 2.20786	valid_1's rmse: 5.08205
# [6400]	training's rmse: 2.19534	valid_1's rmse: 5.08158
# [6450]	training's rmse: 2.18258	valid_1's rmse: 5.08104
# [6500]	training's rmse: 2.16985	valid_1's rmse: 5.08042
# [6550]	training's rmse: 2.15745	valid_1's rmse: 5.07935
# [6600]	training's rmse: 2.14477	valid_1's rmse: 5.07921
# [6650]	training's rmse: 2.13238	valid_1's rmse: 5.07705
# [6700]	training's rmse: 2.11968	valid_1's rmse: 5.07574
# [6750]	training's rmse: 2.10761	valid_1's rmse: 5.07377
# [6800]	training's rmse: 2.0958	valid_1's rmse: 5.07328
# [6850]	training's rmse: 2.08417	valid_1's rmse: 5.07198
# [6900]	training's rmse: 2.07178	valid_1's rmse: 5.07172
# [6950]	training's rmse: 2.06033	valid_1's rmse: 5.07099
# [7000]	training's rmse: 2.04878	valid_1's rmse: 5.0702
# [7050]	training's rmse: 2.03718	valid_1's rmse: 5.0695
# [7100]	training's rmse: 2.02549	valid_1's rmse: 5.0682
# [7150]	training's rmse: 2.01372	valid_1's rmse: 5.06743
# [7200]	training's rmse: 2.00282	valid_1's rmse: 5.06663
# [7250]	training's rmse: 1.99164	valid_1's rmse: 5.06574
# [7300]	training's rmse: 1.98063	valid_1's rmse: 5.06524
# [7350]	training's rmse: 1.97014	valid_1's rmse: 5.06457
# [7400]	training's rmse: 1.959	valid_1's rmse: 5.06422
# [7450]	training's rmse: 1.94826	valid_1's rmse: 5.06316
# [7500]	training's rmse: 1.93786	valid_1's rmse: 5.06337
# [7550]	training's rmse: 1.92756	valid_1's rmse: 5.06226
# [7600]	training's rmse: 1.91726	valid_1's rmse: 5.06092
# [7650]	training's rmse: 1.90687	valid_1's rmse: 5.06082
# [7700]	training's rmse: 1.89666	valid_1's rmse: 5.0606
# [7750]	training's rmse: 1.88665	valid_1's rmse: 5.06025
# [7800]	training's rmse: 1.8769	valid_1's rmse: 5.06015
# [7850]	training's rmse: 1.86695	valid_1's rmse: 5.05949
# [7900]	training's rmse: 1.857	valid_1's rmse: 5.05871
# [7950]	training's rmse: 1.84671	valid_1's rmse: 5.05798
# [8000]	training's rmse: 1.83694	valid_1's rmse: 5.05783
# Did not meet early stopping. Best iteration is:
# [8000]	training's rmse: 1.83694	valid_1's rmse: 5.05783
# Train RMSE: 1.8369440300172266        Valida RMSE: 5.0578258013021635
# Columns: ['emb_product_name_516', 'emb_ingredients_text_444', 'emb_ingredients_text_648', 'emb_ingredients_text_157', 'emb_product_name_295', 'emb_ingredients_text_126', 'emb_ingredients_text_634', 'emb_ingredients_text_740', 'emb_brands_tags_27', 'emb_brands_tags_292', 'emb_brands_tags_764', 'emb_product_name_40', 'emb_ingredients_text_621', 'emb_product_name_616', 'emb_product_name_721', 'emb_ingredients_text_22', 'emb_brands_tags_738', 'emb_brands_tags_452', 'emb_ingredients_text_490', 'emb_ingredients_text_223', 'emb_product_name_369', 'emb_ingredients_text_5', 'emb_brands_tags_295', 'emb_ingredients_text_677', 'emb_product_name_493', 'emb_product_name_525', 'emb_product_name_655', 'emb_product_name_500', 'emb_product_name_704', 'emb_product_name_731', 'emb_brands_tags_264', 'emb_brands_tags_468', 'emb_product_name_558', 'emb_ingredients_text_315', 'emb_product_name_735', 'emb_brands_tags_178', 'emb_ingredients_text_512', 'emb_ingredients_text_556', 'emb_brands_tags_347', 'emb_product_name_336', 'emb_product_name_496', 'emb_product_name_24', 'emb_brands_tags_87', 'emb_product_name_198', 'emb_brands_tags_579', 'emb_product_name_528', 'emb_product_name_653', 'emb_ingredients_text_119', 'emb_brands_tags_727', 'emb_product_name_304', 'emb_brands_tags_668', 'emb_ingredients_text_179', 'emb_ingredients_text_513', 'emb_ingredients_text_165', 'emb_product_name_541', 'emb_ingredients_text_397', 'emb_ingredients_text_311', 'emb_ingredients_text_263', 'emb_ingredients_text_361', 'emb_ingredients_text_195', 'emb_ingredients_text_105', 'emb_ingredients_text_44', 'emb_brands_tags_485', 'emb_product_name_672', 'emb_brands_tags_83', 'emb_product_name_691', 'emb_ingredients_text_231', 'emb_product_name_152', 'emb_brands_tags_505', 'emb_product_name_287', 'emb_ingredients_text_276', 'emb_ingredients_text_603', 'emb_product_name_312', 'emb_ingredients_text_191', 'emb_ingredients_text_118', 'emb_brands_tags_362', 'emb_ingredients_text_363', 'emb_ingredients_text_108', 'emb_ingredients_text_549', 'emb_brands_tags_525', 'emb_product_name_87', 'emb_ingredients_text_164', 'emb_ingredients_text_37', 'emb_product_name_267', 'emb_brands_tags_229', 'emb_product_name_271', 'emb_product_name_566', 'emb_ingredients_text_12', 'emb_ingredients_text_174', 'emb_brands_tags_55', 'emb_product_name_711', 'emb_product_name_14', 'emb_ingredients_text_343', 'emb_product_name_741', 'emb_brands_tags_257', 'emb_ingredients_text_23', 'emb_ingredients_text_428', 'emb_brands_tags_28', 'emb_product_name_53', 'emb_ingredients_text_550', 'emb_brands_tags_406', 'emb_brands_tags_633', 'emb_ingredients_text_443', 'emb_product_name_755', 'emb_ingredients_text_63', 'emb_brands_tags_291', 'emb_brands_tags_636', 'emb_ingredients_text_127', 'emb_product_name_501', 'emb_brands_tags_238', 'emb_ingredients_text_497', 'emb_product_name_492', 'emb_ingredients_text_715', 'emb_ingredients_text_129', 'emb_product_name_465', 'emb_product_name_654', 'emb_product_name_236', 'emb_ingredients_text_294', 'emb_ingredients_text_381', 'emb_product_name_160', 'emb_ingredients_text_206', 'emb_product_name_708', 'emb_product_name_9', 'emb_brands_tags_616', 'emb_product_name_124', 'emb_ingredients_text_502', 'emb_product_name_497', 'emb_product_name_738', 'emb_brands_tags_453', 'emb_product_name_529', 'emb_ingredients_text_125', 'emb_product_name_403', 'emb_ingredients_text_741', 'emb_product_name_590', 'emb_brands_tags_124', 'emb_product_name_728', 'emb_brands_tags_0', 'emb_brands_tags_234', 'emb_ingredients_text_580', 'emb_product_name_727', 'emb_ingredients_text_289', 'emb_brands_tags_488', 'emb_ingredients_text_667', 'emb_brands_tags_203', 'emb_brands_tags_185', 'emb_brands_tags_437', 'emb_ingredients_text_586', 'emb_ingredients_text_393', 'emb_product_name_580', 'emb_ingredients_text_322', 'emb_ingredients_text_681', 'emb_brands_tags_413', 'emb_ingredients_text_658', 'emb_brands_tags_528', 'emb_ingredients_text_535', 'emb_product_name_362', 'emb_brands_tags_352', 'emb_ingredients_text_659', 'emb ...
# Cat index: [2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321]
# ---------- Training fold Nº 2 ----------
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 587901
# [LightGBM] [Info] Number of data points in the train set: 81622, number of used features: 2322
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 9.169930
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 6.72702	valid_1's rmse: 6.79657
# [100]	training's rmse: 6.30906	valid_1's rmse: 6.43716
# [150]	training's rmse: 6.07297	valid_1's rmse: 6.24592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	training's rmse: 5.90535	valid_1's rmse: 6.12289
# [250]	training's rmse: 5.76952	valid_1's rmse: 6.02479
# [300]	training's rmse: 5.64995	valid_1's rmse: 5.94357
# [350]	training's rmse: 5.54855	valid_1's rmse: 5.88061
# [400]	training's rmse: 5.45708	valid_1's rmse: 5.82661
# [450]	training's rmse: 5.37225	valid_1's rmse: 5.77986
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	training's rmse: 5.2975	valid_1's rmse: 5.74139
# [550]	training's rmse: 5.22522	valid_1's rmse: 5.70423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	training's rmse: 5.15611	valid_1's rmse: 5.67158
# [650]	training's rmse: 5.09178	valid_1's rmse: 5.63917
# [700]	training's rmse: 5.02925	valid_1's rmse: 5.6134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	training's rmse: 4.97144	valid_1's rmse: 5.59148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's rmse: 4.91682	valid_1's rmse: 5.57179
# [850]	training's rmse: 4.86159	valid_1's rmse: 5.55016
# [900]	training's rmse: 4.80777	valid_1's rmse: 5.53054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	training's rmse: 4.75951	valid_1's rmse: 5.51376
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	training's rmse: 4.71197	valid_1's rmse: 5.49839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1050]	training's rmse: 4.66677	valid_1's rmse: 5.48335
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1100]	training's rmse: 4.62093	valid_1's rmse: 5.46861
# [1150]	training's rmse: 4.57563	valid_1's rmse: 5.45276
# [1200]	training's rmse: 4.53219	valid_1's rmse: 5.44149
# [1250]	training's rmse: 4.48868	valid_1's rmse: 5.42776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1300]	training's rmse: 4.44642	valid_1's rmse: 5.41639
# [1350]	training's rmse: 4.4057	valid_1's rmse: 5.40585
# [1400]	training's rmse: 4.36629	valid_1's rmse: 5.39555
# [1450]	training's rmse: 4.32786	valid_1's rmse: 5.38714
# [1500]	training's rmse: 4.28948	valid_1's rmse: 5.37919
# [1550]	training's rmse: 4.25108	valid_1's rmse: 5.36993
# [1600]	training's rmse: 4.21386	valid_1's rmse: 5.36168
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1650]	training's rmse: 4.17845	valid_1's rmse: 5.35361
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1700]	training's rmse: 4.14384	valid_1's rmse: 5.34627
# [1750]	training's rmse: 4.10834	valid_1's rmse: 5.33772
# [1800]	training's rmse: 4.0741	valid_1's rmse: 5.32905
# [1850]	training's rmse: 4.04096	valid_1's rmse: 5.32248
# [1900]	training's rmse: 4.00842	valid_1's rmse: 5.31512
# [1950]	training's rmse: 3.9763	valid_1's rmse: 5.30706
# [2000]	training's rmse: 3.94367	valid_1's rmse: 5.30213
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2050]	training's rmse: 3.91208	valid_1's rmse: 5.29618
# [2100]	training's rmse: 3.88078	valid_1's rmse: 5.29148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2150]	training's rmse: 3.85122	valid_1's rmse: 5.28612
# [2200]	training's rmse: 3.8204	valid_1's rmse: 5.28294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2250]	training's rmse: 3.79045	valid_1's rmse: 5.27843
# [2300]	training's rmse: 3.76088	valid_1's rmse: 5.27319
# [2350]	training's rmse: 3.73228	valid_1's rmse: 5.26911
# [2400]	training's rmse: 3.70427	valid_1's rmse: 5.2647
# [2450]	training's rmse: 3.67613	valid_1's rmse: 5.26033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2500]	training's rmse: 3.64863	valid_1's rmse: 5.25632
# [2550]	training's rmse: 3.62235	valid_1's rmse: 5.25135
# [2600]	training's rmse: 3.59412	valid_1's rmse: 5.24684
# [2650]	training's rmse: 3.56694	valid_1's rmse: 5.24212
# [2700]	training's rmse: 3.54101	valid_1's rmse: 5.23781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2750]	training's rmse: 3.51559	valid_1's rmse: 5.23364
# [2800]	training's rmse: 3.48992	valid_1's rmse: 5.22913
# [2850]	training's rmse: 3.46479	valid_1's rmse: 5.22582
# [2900]	training's rmse: 3.43909	valid_1's rmse: 5.22152
# [2950]	training's rmse: 3.41441	valid_1's rmse: 5.2182
# [3000]	training's rmse: 3.38971	valid_1's rmse: 5.21497
# [3050]	training's rmse: 3.36503	valid_1's rmse: 5.21195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3100]	training's rmse: 3.34117	valid_1's rmse: 5.20796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3150]	training's rmse: 3.31758	valid_1's rmse: 5.20455
# [3200]	training's rmse: 3.29461	valid_1's rmse: 5.20102
# [3250]	training's rmse: 3.2714	valid_1's rmse: 5.19737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3300]	training's rmse: 3.24882	valid_1's rmse: 5.19385
# [3350]	training's rmse: 3.22607	valid_1's rmse: 5.19095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3400]	training's rmse: 3.20395	valid_1's rmse: 5.18791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3450]	training's rmse: 3.18233	valid_1's rmse: 5.18447
# [3500]	training's rmse: 3.16007	valid_1's rmse: 5.18077
# [3550]	training's rmse: 3.13818	valid_1's rmse: 5.17823
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3600]	training's rmse: 3.11652	valid_1's rmse: 5.17519
# [3650]	training's rmse: 3.09465	valid_1's rmse: 5.1728
# [3700]	training's rmse: 3.07401	valid_1's rmse: 5.17043
# [3750]	training's rmse: 3.05342	valid_1's rmse: 5.16703
# [3800]	training's rmse: 3.03308	valid_1's rmse: 5.16438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3850]	training's rmse: 3.01277	valid_1's rmse: 5.16136
# [3900]	training's rmse: 2.99314	valid_1's rmse: 5.15898
# [3950]	training's rmse: 2.97333	valid_1's rmse: 5.15674
# [4000]	training's rmse: 2.95391	valid_1's rmse: 5.15368
# [4050]	training's rmse: 2.93421	valid_1's rmse: 5.15138
# [4100]	training's rmse: 2.91473	valid_1's rmse: 5.14899
# [4150]	training's rmse: 2.89516	valid_1's rmse: 5.14681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4200]	training's rmse: 2.87583	valid_1's rmse: 5.14456
# [4250]	training's rmse: 2.85694	valid_1's rmse: 5.14318
# [4300]	training's rmse: 2.83789	valid_1's rmse: 5.14091
# [4350]	training's rmse: 2.81936	valid_1's rmse: 5.13992
# [4400]	training's rmse: 2.80153	valid_1's rmse: 5.13763
# [4450]	training's rmse: 2.78347	valid_1's rmse: 5.13593
# [4500]	training's rmse: 2.76592	valid_1's rmse: 5.13361
# [4550]	training's rmse: 2.74781	valid_1's rmse: 5.13292
# [4600]	training's rmse: 2.73056	valid_1's rmse: 5.13133
# [4650]	training's rmse: 2.71332	valid_1's rmse: 5.12945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4700]	training's rmse: 2.69617	valid_1's rmse: 5.12745
# [4750]	training's rmse: 2.67901	valid_1's rmse: 5.12587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4800]	training's rmse: 2.6624	valid_1's rmse: 5.12423
# [4850]	training's rmse: 2.64551	valid_1's rmse: 5.12214
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4900]	training's rmse: 2.62872	valid_1's rmse: 5.12064
# [4950]	training's rmse: 2.61273	valid_1's rmse: 5.11875
# [5000]	training's rmse: 2.59634	valid_1's rmse: 5.11736
# [5050]	training's rmse: 2.58043	valid_1's rmse: 5.11547
# [5100]	training's rmse: 2.56451	valid_1's rmse: 5.11415
# [5150]	training's rmse: 2.54874	valid_1's rmse: 5.11298
# [5200]	training's rmse: 2.53261	valid_1's rmse: 5.11233
# [5250]	training's rmse: 2.5166	valid_1's rmse: 5.11108
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5300]	training's rmse: 2.50075	valid_1's rmse: 5.1092
# [5350]	training's rmse: 2.4854	valid_1's rmse: 5.10839
# [5400]	training's rmse: 2.47005	valid_1's rmse: 5.10779
# [5450]	training's rmse: 2.45485	valid_1's rmse: 5.10636
# [5500]	training's rmse: 2.44021	valid_1's rmse: 5.10471
# [5550]	training's rmse: 2.42473	valid_1's rmse: 5.1033
# [5600]	training's rmse: 2.40994	valid_1's rmse: 5.10211
# [5650]	training's rmse: 2.39553	valid_1's rmse: 5.10098
# [5700]	training's rmse: 2.38076	valid_1's rmse: 5.09925
# [5750]	training's rmse: 2.36607	valid_1's rmse: 5.09771
# [5800]	training's rmse: 2.35203	valid_1's rmse: 5.09662
# [5850]	training's rmse: 2.33777	valid_1's rmse: 5.09477
# [5900]	training's rmse: 2.32368	valid_1's rmse: 5.09396
# [5950]	training's rmse: 2.30997	valid_1's rmse: 5.0929
# [6000]	training's rmse: 2.29598	valid_1's rmse: 5.09145
# [6050]	training's rmse: 2.28224	valid_1's rmse: 5.08998
# [6100]	training's rmse: 2.2688	valid_1's rmse: 5.09014
# [6150]	training's rmse: 2.25552	valid_1's rmse: 5.08969
# [6200]	training's rmse: 2.24229	valid_1's rmse: 5.08988
# [6250]	training's rmse: 2.22929	valid_1's rmse: 5.08944
# [6300]	training's rmse: 2.21669	valid_1's rmse: 5.08851
# [6350]	training's rmse: 2.20372	valid_1's rmse: 5.08741
# [6400]	training's rmse: 2.19067	valid_1's rmse: 5.08579
# [6450]	training's rmse: 2.17817	valid_1's rmse: 5.08479
# [6500]	training's rmse: 2.16571	valid_1's rmse: 5.08362
# [6550]	training's rmse: 2.15263	valid_1's rmse: 5.08301
# [6600]	training's rmse: 2.1408	valid_1's rmse: 5.08185
# [6650]	training's rmse: 2.12845	valid_1's rmse: 5.08104
# [6700]	training's rmse: 2.11629	valid_1's rmse: 5.08031
# [6750]	training's rmse: 2.10446	valid_1's rmse: 5.07938
# [6800]	training's rmse: 2.092	valid_1's rmse: 5.07846
# [6850]	training's rmse: 2.08015	valid_1's rmse: 5.0778
# [6900]	training's rmse: 2.06761	valid_1's rmse: 5.07753
# [6950]	training's rmse: 2.0559	valid_1's rmse: 5.07586
# [7000]	training's rmse: 2.04471	valid_1's rmse: 5.07548
# [7050]	training's rmse: 2.03321	valid_1's rmse: 5.07475
# [7100]	training's rmse: 2.02168	valid_1's rmse: 5.07401
# [7150]	training's rmse: 2.01013	valid_1's rmse: 5.07347
# [7200]	training's rmse: 1.99851	valid_1's rmse: 5.07308
# [7250]	training's rmse: 1.98757	valid_1's rmse: 5.07241
# [7300]	training's rmse: 1.97672	valid_1's rmse: 5.07143
# [7350]	training's rmse: 1.96536	valid_1's rmse: 5.07087
# [7400]	training's rmse: 1.95458	valid_1's rmse: 5.06937
# [7450]	training's rmse: 1.944	valid_1's rmse: 5.06869
# [7500]	training's rmse: 1.9335	valid_1's rmse: 5.06835
# [7550]	training's rmse: 1.923	valid_1's rmse: 5.06762
# [7600]	training's rmse: 1.91275	valid_1's rmse: 5.06675
# [7650]	training's rmse: 1.90288	valid_1's rmse: 5.06561
# [7700]	training's rmse: 1.89237	valid_1's rmse: 5.06481
# [7750]	training's rmse: 1.88199	valid_1's rmse: 5.06482
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7800]	training's rmse: 1.87196	valid_1's rmse: 5.06414
# [7850]	training's rmse: 1.86224	valid_1's rmse: 5.06329
# [7900]	training's rmse: 1.85198	valid_1's rmse: 5.06212
# [7950]	training's rmse: 1.84187	valid_1's rmse: 5.06214
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8000]	training's rmse: 1.83241	valid_1's rmse: 5.06155
# Did not meet early stopping. Best iteration is:
# [8000]	training's rmse: 1.83241	valid_1's rmse: 5.06155
# Train RMSE: 1.8324107391620967        Valida RMSE: 5.0615474424238975
# Columns: ['emb_product_name_516', 'emb_ingredients_text_444', 'emb_ingredients_text_648', 'emb_ingredients_text_157', 'emb_product_name_295', 'emb_ingredients_text_126', 'emb_ingredients_text_634', 'emb_ingredients_text_740', 'emb_brands_tags_27', 'emb_brands_tags_292', 'emb_brands_tags_764', 'emb_product_name_40', 'emb_ingredients_text_621', 'emb_product_name_616', 'emb_product_name_721', 'emb_ingredients_text_22', 'emb_brands_tags_738', 'emb_brands_tags_452', 'emb_ingredients_text_490', 'emb_ingredients_text_223', 'emb_product_name_369', 'emb_ingredients_text_5', 'emb_brands_tags_295', 'emb_ingredients_text_677', 'emb_product_name_493', 'emb_product_name_525', 'emb_product_name_655', 'emb_product_name_500', 'emb_product_name_704', 'emb_product_name_731', 'emb_brands_tags_264', 'emb_brands_tags_468', 'emb_product_name_558', 'emb_ingredients_text_315', 'emb_product_name_735', 'emb_brands_tags_178', 'emb_ingredients_text_512', 'emb_ingredients_text_556', 'emb_brands_tags_347', 'emb_product_name_336', 'emb_product_name_496', 'emb_product_name_24', 'emb_brands_tags_87', 'emb_product_name_198', 'emb_brands_tags_579', 'emb_product_name_528', 'emb_product_name_653', 'emb_ingredients_text_119', 'emb_brands_tags_727', 'emb_product_name_304', 'emb_brands_tags_668', 'emb_ingredients_text_179', 'emb_ingredients_text_513', 'emb_ingredients_text_165', 'emb_product_name_541', 'emb_ingredients_text_397', 'emb_ingredients_text_311', 'emb_ingredients_text_263', 'emb_ingredients_text_361', 'emb_ingredients_text_195', 'emb_ingredients_text_105', 'emb_ingredients_text_44', 'emb_brands_tags_485', 'emb_product_name_672', 'emb_brands_tags_83', 'emb_product_name_691', 'emb_ingredients_text_231', 'emb_product_name_152', 'emb_brands_tags_505', 'emb_product_name_287', 'emb_ingredients_text_276', 'emb_ingredients_text_603', 'emb_product_name_312', 'emb_ingredients_text_191', 'emb_ingredients_text_118', 'emb_brands_tags_362', 'emb_ingredients_text_363', 'emb_ingredients_text_108', 'emb_ingredients_text_549', 'emb_brands_tags_525', 'emb_product_name_87', 'emb_ingredients_text_164', 'emb_ingredients_text_37', 'emb_product_name_267', 'emb_brands_tags_229', 'emb_product_name_271', 'emb_product_name_566', 'emb_ingredients_text_12', 'emb_ingredients_text_174', 'emb_brands_tags_55', 'emb_product_name_711', 'emb_product_name_14', 'emb_ingredients_text_343', 'emb_product_name_741', 'emb_brands_tags_257', 'emb_ingredients_text_23', 'emb_ingredients_text_428', 'emb_brands_tags_28', 'emb_product_name_53', 'emb_ingredients_text_550', 'emb_brands_tags_406', 'emb_brands_tags_633', 'emb_ingredients_text_443', 'emb_product_name_755', 'emb_ingredients_text_63', 'emb_brands_tags_291', 'emb_brands_tags_636', 'emb_ingredients_text_127', 'emb_product_name_501', 'emb_brands_tags_238', 'emb_ingredients_text_497', 'emb_product_name_492', 'emb_ingredients_text_715', 'emb_ingredients_text_129', 'emb_product_name_465', 'emb_product_name_654', 'emb_product_name_236', 'emb_ingredients_text_294', 'emb_ingredients_text_381', 'emb_product_name_160', 'emb_ingredients_text_206', 'emb_product_name_708', 'emb_product_name_9', 'emb_brands_tags_616', 'emb_product_name_124', 'emb_ingredients_text_502', 'emb_product_name_497', 'emb_product_name_738', 'emb_brands_tags_453', 'emb_product_name_529', 'emb_ingredients_text_125', 'emb_product_name_403', 'emb_ingredients_text_741', 'emb_product_name_590', 'emb_brands_tags_124', 'emb_product_name_728', 'emb_brands_tags_0', 'emb_brands_tags_234', 'emb_ingredients_text_580', 'emb_product_name_727', 'emb_ingredients_text_289', 'emb_brands_tags_488', 'emb_ingredients_text_667', 'emb_brands_tags_203', 'emb_brands_tags_185', 'emb_brands_tags_437', 'emb_ingredients_text_586', 'emb_ingredients_text_393', 'emb_product_name_580', 'emb_ingredients_text_322', 'emb_ingredients_text_681', 'emb_brands_tags_413', 'emb_ingredients_text_658', 'emb_brands_tags_528', 'emb_ingredients_text_535', 'emb_product_name_362', 'emb_brands_tags_352', 'emb_ingredients_text_659', 'emb ...
# Cat index: [2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321]
# ---------- Training fold Nº 3 ----------
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 587900
# [LightGBM] [Info] Number of data points in the train set: 81622, number of used features: 2322
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 9.171253
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 6.73842	valid_1's rmse: 6.78689
# [100]	training's rmse: 6.31725	valid_1's rmse: 6.40454
# [150]	training's rmse: 6.08207	valid_1's rmse: 6.20498
# [200]	training's rmse: 5.91475	valid_1's rmse: 6.07667
# [250]	training's rmse: 5.78007	valid_1's rmse: 5.97895
# [300]	training's rmse: 5.66232	valid_1's rmse: 5.90099
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	training's rmse: 5.55818	valid_1's rmse: 5.8349
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	training's rmse: 5.46537	valid_1's rmse: 5.78118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	training's rmse: 5.38343	valid_1's rmse: 5.73701
# [500]	training's rmse: 5.30389	valid_1's rmse: 5.69577
# [550]	training's rmse: 5.23032	valid_1's rmse: 5.6595
# [600]	training's rmse: 5.16482	valid_1's rmse: 5.62944
# [650]	training's rmse: 5.10282	valid_1's rmse: 5.60563
# [700]	training's rmse: 5.04123	valid_1's rmse: 5.58123
# [750]	training's rmse: 4.98214	valid_1's rmse: 5.55687
# [800]	training's rmse: 4.926	valid_1's rmse: 5.53771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	training's rmse: 4.87259	valid_1's rmse: 5.51746
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [900]	training's rmse: 4.82176	valid_1's rmse: 5.49719
# [950]	training's rmse: 4.77176	valid_1's rmse: 5.48103
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	training's rmse: 4.72236	valid_1's rmse: 5.46383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1050]	training's rmse: 4.67536	valid_1's rmse: 5.44813
# [1100]	training's rmse: 4.62893	valid_1's rmse: 5.43494
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1150]	training's rmse: 4.58394	valid_1's rmse: 5.42083
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1200]	training's rmse: 4.53895	valid_1's rmse: 5.4092
# [1250]	training's rmse: 4.49611	valid_1's rmse: 5.39501
# [1300]	training's rmse: 4.45356	valid_1's rmse: 5.38434
# [1350]	training's rmse: 4.41231	valid_1's rmse: 5.37296
# [1400]	training's rmse: 4.37271	valid_1's rmse: 5.36253
# [1450]	training's rmse: 4.33366	valid_1's rmse: 5.3541
# [1500]	training's rmse: 4.29579	valid_1's rmse: 5.34636
# [1550]	training's rmse: 4.25835	valid_1's rmse: 5.33782
# [1600]	training's rmse: 4.22029	valid_1's rmse: 5.3277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1650]	training's rmse: 4.18471	valid_1's rmse: 5.32049
# [1700]	training's rmse: 4.14951	valid_1's rmse: 5.31163
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1750]	training's rmse: 4.11625	valid_1's rmse: 5.30721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	training's rmse: 4.08329	valid_1's rmse: 5.30143
# [1850]	training's rmse: 4.05008	valid_1's rmse: 5.29538
# [1900]	training's rmse: 4.01749	valid_1's rmse: 5.28766
# [1950]	training's rmse: 3.98546	valid_1's rmse: 5.2797
# [2000]	training's rmse: 3.95374	valid_1's rmse: 5.27422
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2050]	training's rmse: 3.92256	valid_1's rmse: 5.2677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2100]	training's rmse: 3.89191	valid_1's rmse: 5.2616
# [2150]	training's rmse: 3.86032	valid_1's rmse: 5.25533
# [2200]	training's rmse: 3.8298	valid_1's rmse: 5.24984
# [2250]	training's rmse: 3.8001	valid_1's rmse: 5.24565
# [2300]	training's rmse: 3.77091	valid_1's rmse: 5.24164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2350]	training's rmse: 3.74161	valid_1's rmse: 5.23741
# [2400]	training's rmse: 3.71268	valid_1's rmse: 5.23089
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2450]	training's rmse: 3.68383	valid_1's rmse: 5.22576
# [2500]	training's rmse: 3.65631	valid_1's rmse: 5.22118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2550]	training's rmse: 3.6292	valid_1's rmse: 5.21738
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2600]	training's rmse: 3.60249	valid_1's rmse: 5.2125
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2650]	training's rmse: 3.57538	valid_1's rmse: 5.20866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2700]	training's rmse: 3.54854	valid_1's rmse: 5.20479
# [2750]	training's rmse: 3.52287	valid_1's rmse: 5.20132
# [2800]	training's rmse: 3.49772	valid_1's rmse: 5.19773
# [2850]	training's rmse: 3.47211	valid_1's rmse: 5.19409
# [2900]	training's rmse: 3.44625	valid_1's rmse: 5.19074
# [2950]	training's rmse: 3.41986	valid_1's rmse: 5.18695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3000]	training's rmse: 3.39601	valid_1's rmse: 5.18487
# [3050]	training's rmse: 3.37105	valid_1's rmse: 5.18177
# [3100]	training's rmse: 3.34712	valid_1's rmse: 5.17852
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3150]	training's rmse: 3.32285	valid_1's rmse: 5.17611
# [3200]	training's rmse: 3.29883	valid_1's rmse: 5.17258
# [3250]	training's rmse: 3.27572	valid_1's rmse: 5.16965
# [3300]	training's rmse: 3.25295	valid_1's rmse: 5.16638
# [3350]	training's rmse: 3.22929	valid_1's rmse: 5.16297
# [3400]	training's rmse: 3.20634	valid_1's rmse: 5.16014
# [3450]	training's rmse: 3.18376	valid_1's rmse: 5.15721
# [3500]	training's rmse: 3.16177	valid_1's rmse: 5.15488
# [3550]	training's rmse: 3.13986	valid_1's rmse: 5.15233
# [3600]	training's rmse: 3.11778	valid_1's rmse: 5.14972
# [3650]	training's rmse: 3.09628	valid_1's rmse: 5.1467
# [3700]	training's rmse: 3.07495	valid_1's rmse: 5.14433
# [3750]	training's rmse: 3.0539	valid_1's rmse: 5.14165
# [3800]	training's rmse: 3.03301	valid_1's rmse: 5.13996
# [3850]	training's rmse: 3.01224	valid_1's rmse: 5.13896
# [3900]	training's rmse: 2.99154	valid_1's rmse: 5.13585
# [3950]	training's rmse: 2.97144	valid_1's rmse: 5.13358
# [4000]	training's rmse: 2.95164	valid_1's rmse: 5.13145
# [4050]	training's rmse: 2.93204	valid_1's rmse: 5.129
# [4100]	training's rmse: 2.91269	valid_1's rmse: 5.12638
# [4150]	training's rmse: 2.894	valid_1's rmse: 5.12455
# [4200]	training's rmse: 2.87514	valid_1's rmse: 5.12275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4250]	training's rmse: 2.85583	valid_1's rmse: 5.12144
# [4300]	training's rmse: 2.83738	valid_1's rmse: 5.1201
# [4350]	training's rmse: 2.81922	valid_1's rmse: 5.11745
# [4400]	training's rmse: 2.80147	valid_1's rmse: 5.11566
# [4450]	training's rmse: 2.78379	valid_1's rmse: 5.11379
# [4500]	training's rmse: 2.76554	valid_1's rmse: 5.1117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4550]	training's rmse: 2.74747	valid_1's rmse: 5.11015
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4600]	training's rmse: 2.72949	valid_1's rmse: 5.10786
# [4650]	training's rmse: 2.71196	valid_1's rmse: 5.10594
# [4700]	training's rmse: 2.69482	valid_1's rmse: 5.10467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4750]	training's rmse: 2.67787	valid_1's rmse: 5.10351
# [4800]	training's rmse: 2.66198	valid_1's rmse: 5.10146
# [4850]	training's rmse: 2.64556	valid_1's rmse: 5.10029
# [4900]	training's rmse: 2.62882	valid_1's rmse: 5.09872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4950]	training's rmse: 2.61213	valid_1's rmse: 5.09696
# [5000]	training's rmse: 2.59532	valid_1's rmse: 5.09532
# [5050]	training's rmse: 2.57955	valid_1's rmse: 5.09398
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5100]	training's rmse: 2.56322	valid_1's rmse: 5.09331
# [5150]	training's rmse: 2.54765	valid_1's rmse: 5.09201
# [5200]	training's rmse: 2.53181	valid_1's rmse: 5.09092
# [5250]	training's rmse: 2.51625	valid_1's rmse: 5.08929
# [5300]	training's rmse: 2.50066	valid_1's rmse: 5.08888
# [5350]	training's rmse: 2.48479	valid_1's rmse: 5.08772
# [5400]	training's rmse: 2.47009	valid_1's rmse: 5.08648
# [5450]	training's rmse: 2.45543	valid_1's rmse: 5.08494
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5500]	training's rmse: 2.44057	valid_1's rmse: 5.08327
# [5550]	training's rmse: 2.42539	valid_1's rmse: 5.08217
# [5600]	training's rmse: 2.41035	valid_1's rmse: 5.08099
# [5650]	training's rmse: 2.39567	valid_1's rmse: 5.08055
# [5700]	training's rmse: 2.38147	valid_1's rmse: 5.07981
# [5750]	training's rmse: 2.36689	valid_1's rmse: 5.07869
# [5800]	training's rmse: 2.35255	valid_1's rmse: 5.07806
# [5850]	training's rmse: 2.33847	valid_1's rmse: 5.07635
# ...
# Cat index: [2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321]
# ---------- Training fold Nº 5 ----------
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 587900
# [LightGBM] [Info] Number of data points in the train set: 81623, number of used features: 2322
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 9.170246
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 6.72462	valid_1's rmse: 6.79045
# [100]	training's rmse: 6.30185	valid_1's rmse: 6.4218
# [150]	training's rmse: 6.07236	valid_1's rmse: 6.24132
# [200]	training's rmse: 5.90084	valid_1's rmse: 6.11684
# [250]	training's rmse: 5.76869	valid_1's rmse: 6.02659
# [300]	training's rmse: 5.65007	valid_1's rmse: 5.94831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	training's rmse: 5.54811	valid_1's rmse: 5.88641
# [400]	training's rmse: 5.45708	valid_1's rmse: 5.83218
# [450]	training's rmse: 5.374	valid_1's rmse: 5.78432
# [500]	training's rmse: 5.29536	valid_1's rmse: 5.74357
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	training's rmse: 5.22584	valid_1's rmse: 5.71142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	training's rmse: 5.15648	valid_1's rmse: 5.67745
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [650]	training's rmse: 5.09267	valid_1's rmse: 5.64971
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [700]	training's rmse: 5.0311	valid_1's rmse: 5.62134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	training's rmse: 4.97422	valid_1's rmse: 5.59729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's rmse: 4.91944	valid_1's rmse: 5.57486
# [850]	training's rmse: 4.86378	valid_1's rmse: 5.55331
# [900]	training's rmse: 4.8124	valid_1's rmse: 5.53822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	training's rmse: 4.76297	valid_1's rmse: 5.52295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	training's rmse: 4.71321	valid_1's rmse: 5.50806
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1050]	training's rmse: 4.66599	valid_1's rmse: 5.49416
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1100]	training's rmse: 4.62124	valid_1's rmse: 5.48171
# [1150]	training's rmse: 4.57604	valid_1's rmse: 5.4691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1200]	training's rmse: 4.53214	valid_1's rmse: 5.45614
# [1250]	training's rmse: 4.48934	valid_1's rmse: 5.44331
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1300]	training's rmse: 4.44829	valid_1's rmse: 5.43316
# [1350]	training's rmse: 4.40763	valid_1's rmse: 5.42133
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1400]	training's rmse: 4.36771	valid_1's rmse: 5.41201
# [1450]	training's rmse: 4.32929	valid_1's rmse: 5.40408
# [1500]	training's rmse: 4.2908	valid_1's rmse: 5.39453
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1550]	training's rmse: 4.25336	valid_1's rmse: 5.38412
# [1600]	training's rmse: 4.21709	valid_1's rmse: 5.37635
# [1650]	training's rmse: 4.1808	valid_1's rmse: 5.367
# [1700]	training's rmse: 4.14599	valid_1's rmse: 5.36047
# [1750]	training's rmse: 4.11233	valid_1's rmse: 5.35272
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	training's rmse: 4.07862	valid_1's rmse: 5.34647
# [1850]	training's rmse: 4.04538	valid_1's rmse: 5.34006
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	training's rmse: 4.01294	valid_1's rmse: 5.33297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1950]	training's rmse: 3.98146	valid_1's rmse: 5.32787
# [2000]	training's rmse: 3.94973	valid_1's rmse: 5.32258
# [2050]	training's rmse: 3.91793	valid_1's rmse: 5.31757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2100]	training's rmse: 3.88725	valid_1's rmse: 5.31205
# [2150]	training's rmse: 3.85518	valid_1's rmse: 5.30594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2200]	training's rmse: 3.82507	valid_1's rmse: 5.30165
# [2250]	training's rmse: 3.79423	valid_1's rmse: 5.29714
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2300]	training's rmse: 3.76406	valid_1's rmse: 5.29182
# [2350]	training's rmse: 3.73485	valid_1's rmse: 5.28639
# [2400]	training's rmse: 3.70678	valid_1's rmse: 5.28162
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2450]	training's rmse: 3.67923	valid_1's rmse: 5.27679
# [2500]	training's rmse: 3.65166	valid_1's rmse: 5.27172
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2550]	training's rmse: 3.62434	valid_1's rmse: 5.26672
# [2600]	training's rmse: 3.59772	valid_1's rmse: 5.26314
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2650]	training's rmse: 3.57072	valid_1's rmse: 5.25771
# [2700]	training's rmse: 3.54433	valid_1's rmse: 5.2518
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2750]	training's rmse: 3.51862	valid_1's rmse: 5.24718
# [2800]	training's rmse: 3.49277	valid_1's rmse: 5.24364
# [2850]	training's rmse: 3.46692	valid_1's rmse: 5.23968
# [2900]	training's rmse: 3.44204	valid_1's rmse: 5.23488
# [2950]	training's rmse: 3.41716	valid_1's rmse: 5.23131
# [3000]	training's rmse: 3.39237	valid_1's rmse: 5.22698
# [3050]	training's rmse: 3.36868	valid_1's rmse: 5.22457
# [3100]	training's rmse: 3.34371	valid_1's rmse: 5.22156
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3150]	training's rmse: 3.32046	valid_1's rmse: 5.21845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3200]	training's rmse: 3.29717	valid_1's rmse: 5.21468
# [3250]	training's rmse: 3.27351	valid_1's rmse: 5.21137
# [3300]	training's rmse: 3.25045	valid_1's rmse: 5.20759
# [3350]	training's rmse: 3.22778	valid_1's rmse: 5.20423
# [3400]	training's rmse: 3.20538	valid_1's rmse: 5.20183
# [3450]	training's rmse: 3.18346	valid_1's rmse: 5.20025
# [3500]	training's rmse: 3.16199	valid_1's rmse: 5.1986
# [3550]	training's rmse: 3.14067	valid_1's rmse: 5.19656
# [3600]	training's rmse: 3.11877	valid_1's rmse: 5.195
# [3650]	training's rmse: 3.09763	valid_1's rmse: 5.19154
# [3700]	training's rmse: 3.0767	valid_1's rmse: 5.18884
# [3750]	training's rmse: 3.05563	valid_1's rmse: 5.18492
# [3800]	training's rmse: 3.03414	valid_1's rmse: 5.18236
# [3850]	training's rmse: 3.01391	valid_1's rmse: 5.18019
# [3900]	training's rmse: 2.99303	valid_1's rmse: 5.17759
# [3950]	training's rmse: 2.97236	valid_1's rmse: 5.17639
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4000]	training's rmse: 2.95291	valid_1's rmse: 5.1741
# [4050]	training's rmse: 2.93339	valid_1's rmse: 5.17254
# [4100]	training's rmse: 2.91415	valid_1's rmse: 5.17035
# [4150]	training's rmse: 2.89496	valid_1's rmse: 5.16743
# [4200]	training's rmse: 2.87575	valid_1's rmse: 5.16549
# [4250]	training's rmse: 2.85725	valid_1's rmse: 5.16407
# [4300]	training's rmse: 2.83848	valid_1's rmse: 5.16301
# [4350]	training's rmse: 2.82027	valid_1's rmse: 5.16091
# [4400]	training's rmse: 2.80138	valid_1's rmse: 5.15913
# [4450]	training's rmse: 2.78312	valid_1's rmse: 5.15803
# [4500]	training's rmse: 2.76446	valid_1's rmse: 5.15661
# [4550]	training's rmse: 2.74687	valid_1's rmse: 5.15475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4600]	training's rmse: 2.7296	valid_1's rmse: 5.15275
# [4650]	training's rmse: 2.71268	valid_1's rmse: 5.15086
# [4700]	training's rmse: 2.69522	valid_1's rmse: 5.14862
# [4750]	training's rmse: 2.67861	valid_1's rmse: 5.14743
# [4800]	training's rmse: 2.66183	valid_1's rmse: 5.14467
# [4850]	training's rmse: 2.64514	valid_1's rmse: 5.14325
# [4900]	training's rmse: 2.62871	valid_1's rmse: 5.14139
# [4950]	training's rmse: 2.61176	valid_1's rmse: 5.13956
# [5000]	training's rmse: 2.59531	valid_1's rmse: 5.13804
# [5050]	training's rmse: 2.57951	valid_1's rmse: 5.13628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5100]	training's rmse: 2.56345	valid_1's rmse: 5.13557
# [5150]	training's rmse: 2.54731	valid_1's rmse: 5.13331
# [5200]	training's rmse: 2.53161	valid_1's rmse: 5.13183
# [5250]	training's rmse: 2.51559	valid_1's rmse: 5.12888
# [5300]	training's rmse: 2.49997	valid_1's rmse: 5.12689
# [5350]	training's rmse: 2.48495	valid_1's rmse: 5.12495
# [5400]	training's rmse: 2.46943	valid_1's rmse: 5.12367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5450]	training's rmse: 2.45447	valid_1's rmse: 5.12328
# [5500]	training's rmse: 2.43937	valid_1's rmse: 5.1224
# [5550]	training's rmse: 2.42451	valid_1's rmse: 5.12173
# [5600]	training's rmse: 2.4101	valid_1's rmse: 5.12019
# [5650]	training's rmse: 2.39527	valid_1's rmse: 5.11845
# [5700]	training's rmse: 2.3804	valid_1's rmse: 5.11728
# [5750]	training's rmse: 2.3659	valid_1's rmse: 5.11576
# [5800]	training's rmse: 2.35211	valid_1's rmse: 5.11466
# [5850]	training's rmse: 2.33771	valid_1's rmse: 5.11281
# [5900]	training's rmse: 2.32382	valid_1's rmse: 5.11243
# [5950]	training's rmse: 2.30991	valid_1's rmse: 5.11136
# [6000]	training's rmse: 2.29583	valid_1's rmse: 5.11101
# [6050]	training's rmse: 2.28211	valid_1's rmse: 5.10929
# [6100]	training's rmse: 2.26868	valid_1's rmse: 5.10898
# [6150]	training's rmse: 2.25524	valid_1's rmse: 5.10765
# [6200]	training's rmse: 2.24168	valid_1's rmse: 5.10663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6250]	training's rmse: 2.22845	valid_1's rmse: 5.1055
# [6300]	training's rmse: 2.21508	valid_1's rmse: 5.10449
# [6350]	training's rmse: 2.20178	valid_1's rmse: 5.10447
# [6400]	training's rmse: 2.18891	valid_1's rmse: 5.10382
# [6450]	training's rmse: 2.17577	valid_1's rmse: 5.10271
# [6500]	training's rmse: 2.16277	valid_1's rmse: 5.10198
# [6550]	training's rmse: 2.15056	valid_1's rmse: 5.10098
# [6600]	training's rmse: 2.13839	valid_1's rmse: 5.10055
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6650]	training's rmse: 2.12656	valid_1's rmse: 5.10129
# [6700]	training's rmse: 2.11456	valid_1's rmse: 5.10084
# [6750]	training's rmse: 2.10275	valid_1's rmse: 5.10019
# [6800]	training's rmse: 2.09005	valid_1's rmse: 5.09935
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6850]	training's rmse: 2.0784	valid_1's rmse: 5.09861
# [6900]	training's rmse: 2.06623	valid_1's rmse: 5.098
# [6950]	training's rmse: 2.05472	valid_1's rmse: 5.09697
# [7000]	training's rmse: 2.04289	valid_1's rmse: 5.09649
# [7050]	training's rmse: 2.03121	valid_1's rmse: 5.0958
# [7100]	training's rmse: 2.01981	valid_1's rmse: 5.09516
# [7150]	training's rmse: 2.00872	valid_1's rmse: 5.09437
# [7200]	training's rmse: 1.99731	valid_1's rmse: 5.09308
# [7250]	training's rmse: 1.9864	valid_1's rmse: 5.09257
# [7300]	training's rmse: 1.9756	valid_1's rmse: 5.09144
# [7350]	training's rmse: 1.96475	valid_1's rmse: 5.09102
# [7400]	training's rmse: 1.9534	valid_1's rmse: 5.09075
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7450]	training's rmse: 1.94275	valid_1's rmse: 5.08964
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7500]	training's rmse: 1.93234	valid_1's rmse: 5.08907
# [7550]	training's rmse: 1.92175	valid_1's rmse: 5.08818
# [7600]	training's rmse: 1.91129	valid_1's rmse: 5.08743
# [7650]	training's rmse: 1.90066	valid_1's rmse: 5.08656
# [7700]	training's rmse: 1.89036	valid_1's rmse: 5.08517
# [7750]	training's rmse: 1.88026	valid_1's rmse: 5.08478
# [7800]	training's rmse: 1.87011	valid_1's rmse: 5.08336
# [7850]	training's rmse: 1.86004	valid_1's rmse: 5.08299
# [7900]	training's rmse: 1.85047	valid_1's rmse: 5.08223
# [7950]	training's rmse: 1.84076	valid_1's rmse: 5.0818
# [8000]	training's rmse: 1.83085	valid_1's rmse: 5.08171
# Did not meet early stopping. Best iteration is:
# [8000]	training's rmse: 1.83085	valid_1's rmse: 5.08171
# Train RMSE: 1.830845480513579        Valida RMSE: 5.08171432908585
# OOF RMSE: 5.0683644820836395

# %% [markdown]
# ## Evaluando

# %%
df_test      = pd.read_csv(os.path.join(DATA_PATH,'test_preprocessed.csv'))
df_test['target'] = -1

COLUMN_NAME  = 'product_name' 

test_dataset = BNPParibasText(df_test,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = Roberta_Model(pretrained_model=PRETRAINED)
test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_test = get_embedding(test_loader, model, 'cuda')
df_test[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_test.shape[1])]] = emb_sentence_test


COLUMN_NAME  = 'ingredients_text' 

test_dataset = BNPParibasText(df_test,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = Roberta_Model(pretrained_model=PRETRAINED)
test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_test = get_embedding(test_loader, model, 'cuda')
df_test[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_test.shape[1])]] = emb_sentence_test

COLUMN_NAME  = 'brands_tags' 

test_dataset = BNPParibasText(df_test,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = Roberta_Model(pretrained_model=PRETRAINED)
test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_test = get_embedding(test_loader, model, 'cuda')
df_test[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_test.shape[1])]] = emb_sentence_test

df_test = apply_label_encoder(df_test,dict_le,drop_original = True, missing_new_cat = True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=798.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=798.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=798.0), HTML(value='')))
# Mode: Missing as new category
# Applying Label Encoding:  label_states_en_brands
# Applying Label Encoding:  label_states_en_categories
# Applying Label Encoding:  label_states_en_characteristics
# Applying Label Encoding:  label_states_en_expiration date
# Applying Label Encoding:  label_states_en_general_complete
# Applying Label Encoding:  label_states_en_ingredients
# Applying Label Encoding:  label_pnns_groups_1
# Applying Label Encoding:  label_pnns_groups_2
# Applying Label Encoding:  label_states_en_packaging
# Applying Label Encoding:  label_states_en_packaging-code-
# Applying Label Encoding:  label_states_en_photo_upload
# Applying Label Encoding:  label_states_en_photo_validate
# Applying Label Encoding:  label_states_en_product name
# Applying Label Encoding:  label_states_en_quantity

# %%
probs = 0
for i in models:
    probs = probs + (i.predict(df_test[feature_list]))
    print('fin_predict')
y_test_pred = probs/5.0
print(f'Real: ',math.sqrt(mean_squared_error(y_test_pred+1.5,df_test['Target'].values)))
# Out:
# fin_predict
# fin_predict
# fin_predict
# fin_predict
# fin_predict
# Real:  5.128065432170818

# %%
y_submission['target'] = y_test_pred +1.5
y_submission.head()
# Out:
#            target
# Index
# 37320   17.005029
# 3913    23.107371
# 112180   7.631445
# 128820  12.213423
# 16037   16.837885

# %%
#Enviar los resultados
apiquery.submit_api(y_submission,
       competition_name='food',
        subname='test_v2', # Pueden cambiar esto sin problemas, poner el nombre que quieran.
        holdout_key='None',
        update_ldb=True,
        username="Insight ML - DD" # Poner el nombre de su equipo como un string. 
                                  # El mejor de los resultados dentro de sus envios es el que aparecera en la tabla de posiciones.
)
# Out:
# requests number 1
# 200
# {'Date': 'Wed, 19 May 2021 22:00:13 GMT', 'Content-Type': 'application/json', 'Content-Length': '494', 'Connection': 'keep-alive', 'X-Request-ID': 'IDBT87NQAGLW4CJZ', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'POST', 'Access-Control-Allow-Headers': 'authorization,content-type'}
# {'competition_name': 'food',
#  'file_path': 'none',
#  'message': 'Submission validated.',
#  'name': 'Insight ML - DD',
#  'result_csv_file': 'test_v2',
#  'score': 5.128393060997395,
#  'score2': None,
#  'score3': None,
#  'sub_name': 'test_v2',
#  'sub_uid': '42e680e8-dd05-42a0-aef0-125b417d4977',
#  'submission_time': '2021/05/19, 22:00:12'}
