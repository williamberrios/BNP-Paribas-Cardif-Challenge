# %%
import shutil
import apiquery
import pandas as pd
import sys
import seaborn as sns
import os
import torch
import numpy as np
import random
DATA_PATH = '../01.Data'
shutil.copy("apiquery_pyc.py", "apiquery.pyc")
module_path = "../src"
if module_path not in sys.path:
    sys.path.append(module_path)
    
from utils.training import *
from utils.encoding import *
from utils.utils import *
from models.models import Roberta_Model
from dataset.dataset import BNPParibasText
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
import math
from collections import Counter
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
import math
import time
import matplotlib.pyplot as plt
import transformers
pd.set_option('display.max_rows',100 )

# %%
def get_embedding(data_loader, model, device):
    from tqdm.notebook import tqdm
    # Put the model in eval mode
    model.to(device)
    model.eval()
    # List for store final predictions
    final_predictions = []
    with torch.no_grad():
        tk0 = tqdm(data_loader, total=len(data_loader))
        for b_idx, data in enumerate(tk0):
            for key,value in data.items():
                data[key] = value.to(device)
            predictions = model._embeddings(data['ids'],data['mask'])
            predictions = predictions.cpu()
            final_predictions.append(predictions)
    return np.vstack(final_predictions)

# %%
MAX_LENGTH   = 16
PRETRAINED   = 'roberta-base'
SEED         = 42

# %%
# %%time
df_train     = pd.read_csv(os.path.join("../01.Data",'fold.csv'))
y_submission = pd.read_csv(os.path.join(DATA_PATH,'y_test_submission_example.tsv'), index_col='Index', encoding='utf-8', sep='\t')
# Out:
# CPU times: user 2.34 s, sys: 214 ms, total: 2.56 s
# Wall time: 2.56 s

# %%
seed_everything(SEED)

# %%
# %%time
COLUMN_NAME  = 'product_name' 
tokenizer     = transformers.RobertaTokenizer.from_pretrained(PRETRAINED)
train_dataset = BNPParibasText(df_train,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = Roberta_Model(pretrained_model=PRETRAINED)
train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_train = get_embedding(train_loader, model, 'cuda')
df_train[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_train.shape[1])]] = emb_sentence_train
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3189.0), HTML(value='')))
# CPU times: user 1min 8s, sys: 17.7 s, total: 1min 25s
# Wall time: 1min 25s

# %%
COLUMN_NAME  = 'ingredients_text' 
tokenizer     = transformers.RobertaTokenizer.from_pretrained(PRETRAINED)
train_dataset = BNPParibasText(df_train,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = Roberta_Model(pretrained_model=PRETRAINED)
train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_train = get_embedding(train_loader, model, 'cuda')
df_train[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_train.shape[1])]] = emb_sentence_train
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3189.0), HTML(value='')))

# %%
COLUMN_NAME  = 'countries_en' 
tokenizer     = transformers.RobertaTokenizer.from_pretrained(PRETRAINED)
train_dataset = BNPParibasText(df_train,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = Roberta_Model(pretrained_model=PRETRAINED)
train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_train = get_embedding(train_loader, model, 'cuda')
df_train[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_train.shape[1])]] = emb_sentence_train
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3189.0), HTML(value='')))

# %%
columns_modeling = ['additives_n','ingredients_from_palm_oil_n',
                    'ingredients_that_may_be_from_palm_oil_n','target',
                    'states_en_brands','states_en_categories','states_en_characteristics','states_en_expiration date',
                    'states_en_general_complete','states_en_ingredients','pnns_groups_1','pnns_groups_2',
                    'states_en_packaging','states_en_packaging-code-','states_en_photo_upload',
                    'states_en_photo_validate','states_en_product name','states_en_quantity','diff_t'] + [f'emb_product_name_{i}' for i in range(emb_sentence_train.shape[1])] + [f'emb_ingredients_text_{i}' for i in range(emb_sentence_train.shape[1])]+[f'emb_countries_en_{i}' for i in range(emb_sentence_train.shape[1])]
columns_label = df_train[columns_modeling].select_dtypes(include=['object']).columns.to_list()
print(columns_label)
# Out:
# ['states_en_brands', 'states_en_categories', 'states_en_characteristics', 'states_en_expiration date', 'states_en_general_complete', 'states_en_ingredients', 'pnns_groups_1', 'pnns_groups_2', 'states_en_packaging', 'states_en_packaging-code-', 'states_en_photo_upload', 'states_en_photo_validate', 'states_en_product name', 'states_en_quantity']

# %%
df_train,dict_le = label_encoding(df_train,label_cols = columns_label, drop_original = True, missing_new_cat = True)
# Out:
# Mode: Missing as new category
# Label Encoding:  label_states_en_brands
# Label Encoding:  label_states_en_categories
# Label Encoding:  label_states_en_characteristics
# Label Encoding:  label_states_en_expiration date
# Label Encoding:  label_states_en_general_complete
# Label Encoding:  label_states_en_ingredients
# Label Encoding:  label_pnns_groups_1
# Label Encoding:  label_pnns_groups_2
# Label Encoding:  label_states_en_packaging
# Label Encoding:  label_states_en_packaging-code-
# Label Encoding:  label_states_en_photo_upload
# Label Encoding:  label_states_en_photo_validate
# Label Encoding:  label_states_en_product name
# Label Encoding:  label_states_en_quantity

# %%
params = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'regression',
        'metric': {'rmse'},
        'num_leaves':12,
        'learning_rate': 0.08,
        "min_child_samples": 150,
        "max_depth" : 5,
        'feature_fraction':  0.5,
        "bagging_freq": 1,
        'bagging_fraction': 0.75,
        "is_unbalance" : False,
        'force_col_wise':True,
        'num_threads':18,
        #"scale_pos_weight":5 -> Generally  is the ratio of number of negative class to the positive class.
        'bagging_seed':42,
        'lambda_l1':1.5,
        'lambda_l2':1,
        'verbose': 1

}
cat_columns = [i for i in df_train.columns.to_list() if i.startswith('label_')]
columns_modeling_last = list(set(columns_modeling)-set(columns_label)) + ['fold'] + cat_columns

# %%
results,models,importances,oof,feature_list = Training_Lightgbm(df_train[columns_modeling_last],params,fold_column = 'fold',target_column = 'target',cat_vars = cat_columns ,metric = 'RMSE',early_stopping = 200,max_boost_round = 8000)
# Out:
# Columns: ['emb_ingredients_text_456', 'emb_product_name_287', 'emb_ingredients_text_67', 'emb_product_name_525', 'emb_ingredients_text_511', 'emb_product_name_39', 'emb_countries_en_523', 'emb_ingredients_text_559', 'emb_ingredients_text_431', 'emb_countries_en_738', 'emb_product_name_718', 'emb_countries_en_225', 'emb_product_name_270', 'emb_countries_en_365', 'emb_product_name_155', 'emb_product_name_715', 'emb_countries_en_545', 'emb_countries_en_181', 'emb_product_name_103', 'emb_countries_en_367', 'emb_product_name_164', 'emb_ingredients_text_373', 'emb_ingredients_text_185', 'emb_product_name_83', 'emb_ingredients_text_65', 'emb_countries_en_63', 'emb_countries_en_139', 'emb_product_name_246', 'emb_ingredients_text_45', 'emb_ingredients_text_425', 'emb_countries_en_536', 'emb_product_name_162', 'emb_ingredients_text_368', 'emb_countries_en_322', 'emb_product_name_632', 'emb_product_name_315', 'emb_countries_en_54', 'emb_countries_en_102', 'emb_ingredients_text_556', 'emb_ingredients_text_432', 'emb_product_name_585', 'emb_product_name_378', 'emb_product_name_579', 'emb_product_name_681', 'emb_product_name_286', 'emb_countries_en_101', 'emb_countries_en_748', 'emb_countries_en_257', 'emb_countries_en_109', 'emb_ingredients_text_719', 'emb_countries_en_99', 'emb_countries_en_213', 'emb_ingredients_text_8', 'emb_product_name_137', 'emb_ingredients_text_766', 'emb_countries_en_602', 'emb_product_name_163', 'emb_product_name_352', 'emb_countries_en_466', 'emb_countries_en_238', 'emb_ingredients_text_489', 'emb_countries_en_743', 'emb_countries_en_170', 'emb_ingredients_text_359', 'emb_countries_en_64', 'emb_ingredients_text_372', 'emb_ingredients_text_254', 'emb_countries_en_100', 'emb_countries_en_492', 'emb_product_name_705', 'emb_product_name_93', 'emb_product_name_599', 'emb_ingredients_text_18', 'emb_ingredients_text_274', 'emb_countries_en_295', 'emb_product_name_543', 'emb_ingredients_text_406', 'emb_countries_en_605', 'emb_countries_en_70', 'emb_ingredients_text_446', 'emb_product_name_310', 'emb_countries_en_369', 'emb_countries_en_739', 'emb_ingredients_text_218', 'emb_product_name_483', 'emb_product_name_676', 'emb_product_name_584', 'emb_product_name_573', 'emb_ingredients_text_227', 'emb_ingredients_text_217', 'emb_product_name_586', 'emb_countries_en_438', 'emb_countries_en_152', 'emb_product_name_231', 'emb_product_name_400', 'emb_countries_en_551', 'emb_ingredients_text_578', 'emb_countries_en_702', 'emb_ingredients_text_621', 'emb_countries_en_98', 'emb_ingredients_text_604', 'emb_product_name_355', 'emb_countries_en_241', 'emb_product_name_755', 'emb_ingredients_text_207', 'emb_countries_en_308', 'emb_product_name_753', 'emb_ingredients_text_549', 'emb_countries_en_66', 'emb_ingredients_text_598', 'emb_product_name_359', 'emb_countries_en_67', 'emb_product_name_733', 'emb_ingredients_text_318', 'emb_countries_en_767', 'emb_product_name_704', 'emb_ingredients_text_680', 'emb_countries_en_687', 'emb_countries_en_123', 'emb_countries_en_669', 'emb_product_name_332', 'emb_countries_en_211', 'emb_countries_en_159', 'emb_product_name_710', 'emb_product_name_19', 'emb_product_name_326', 'emb_ingredients_text_31', 'emb_ingredients_text_146', 'emb_countries_en_499', 'emb_countries_en_637', 'emb_ingredients_text_419', 'emb_ingredients_text_540', 'emb_product_name_687', 'emb_countries_en_505', 'emb_product_name_565', 'emb_countries_en_433', 'emb_product_name_75', 'emb_product_name_664', 'emb_countries_en_52', 'emb_ingredients_text_481', 'emb_ingredients_text_422', 'emb_countries_en_496', 'emb_countries_en_501', 'emb_ingredients_text_707', 'emb_product_name_653', 'emb_product_name_354', 'emb_ingredients_text_156', 'emb_ingredients_text_752', 'emb_countries_en_279', 'emb_product_name_496', 'emb_product_name_375', 'emb_countries_en_40', 'emb_countries_en_325', 'emb_countries_en_609', 'emb_product_name_711', 'emb_ingredients_text_603', 'emb_countries_en_197', 'emb_product_name_377', 'emb_product_name_235', 'emb_countries_e ...
# Cat index: [2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321]
# ---------- Training fold Nº 1 ----------
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 494507
# [LightGBM] [Info] Number of data points in the train set: 81622, number of used features: 2322
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 9.171473
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 6.72899	valid_1's rmse: 6.76435
# [100]	training's rmse: 6.31385	valid_1's rmse: 6.3863
# [150]	training's rmse: 6.08837	valid_1's rmse: 6.20117
# [200]	training's rmse: 5.92679	valid_1's rmse: 6.08004
# [250]	training's rmse: 5.79935	valid_1's rmse: 5.99347
# [300]	training's rmse: 5.69055	valid_1's rmse: 5.92113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	training's rmse: 5.59584	valid_1's rmse: 5.86334
# [400]	training's rmse: 5.50879	valid_1's rmse: 5.81379
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	training's rmse: 5.43124	valid_1's rmse: 5.77359
# [500]	training's rmse: 5.35987	valid_1's rmse: 5.74011
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	training's rmse: 5.29092	valid_1's rmse: 5.70713
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	training's rmse: 5.22481	valid_1's rmse: 5.67737
# [650]	training's rmse: 5.16425	valid_1's rmse: 5.65098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [700]	training's rmse: 5.10682	valid_1's rmse: 5.63053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	training's rmse: 5.05203	valid_1's rmse: 5.61211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's rmse: 4.99894	valid_1's rmse: 5.5945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	training's rmse: 4.94899	valid_1's rmse: 5.5771
# [900]	training's rmse: 4.89814	valid_1's rmse: 5.55835
# [950]	training's rmse: 4.85092	valid_1's rmse: 5.5451
# [1000]	training's rmse: 4.80458	valid_1's rmse: 5.53047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1050]	training's rmse: 4.75941	valid_1's rmse: 5.5186
# [1100]	training's rmse: 4.71449	valid_1's rmse: 5.50708
# [1150]	training's rmse: 4.67259	valid_1's rmse: 5.4975
# [1200]	training's rmse: 4.63153	valid_1's rmse: 5.48523
# [1250]	training's rmse: 4.59054	valid_1's rmse: 5.475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1300]	training's rmse: 4.55173	valid_1's rmse: 5.46572
# [1350]	training's rmse: 4.51209	valid_1's rmse: 5.45567
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1400]	training's rmse: 4.47507	valid_1's rmse: 5.44731
# [1450]	training's rmse: 4.43814	valid_1's rmse: 5.43695
# [1500]	training's rmse: 4.40136	valid_1's rmse: 5.42793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1550]	training's rmse: 4.36539	valid_1's rmse: 5.42103
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1600]	training's rmse: 4.33162	valid_1's rmse: 5.4147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1650]	training's rmse: 4.29684	valid_1's rmse: 5.40845
# [1700]	training's rmse: 4.26282	valid_1's rmse: 5.40242
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1750]	training's rmse: 4.22975	valid_1's rmse: 5.39646
# [1800]	training's rmse: 4.19704	valid_1's rmse: 5.38981
# [1850]	training's rmse: 4.16428	valid_1's rmse: 5.38351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	training's rmse: 4.1328	valid_1's rmse: 5.37734
# [1950]	training's rmse: 4.10111	valid_1's rmse: 5.37072
# [2000]	training's rmse: 4.0698	valid_1's rmse: 5.36352
# [2050]	training's rmse: 4.04026	valid_1's rmse: 5.35908
# [2100]	training's rmse: 4.01112	valid_1's rmse: 5.35411
# [2150]	training's rmse: 3.98205	valid_1's rmse: 5.34811
# [2200]	training's rmse: 3.95329	valid_1's rmse: 5.34292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2250]	training's rmse: 3.92472	valid_1's rmse: 5.33856
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2300]	training's rmse: 3.89645	valid_1's rmse: 5.33308
# [2350]	training's rmse: 3.87026	valid_1's rmse: 5.32883
# [2400]	training's rmse: 3.84382	valid_1's rmse: 5.32386
# [2450]	training's rmse: 3.81695	valid_1's rmse: 5.31867
# [2500]	training's rmse: 3.79068	valid_1's rmse: 5.31404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2550]	training's rmse: 3.76396	valid_1's rmse: 5.3101
# [2600]	training's rmse: 3.73746	valid_1's rmse: 5.305
# [2650]	training's rmse: 3.71163	valid_1's rmse: 5.30013
# [2700]	training's rmse: 3.68658	valid_1's rmse: 5.29764
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2750]	training's rmse: 3.66139	valid_1's rmse: 5.29424
# [2800]	training's rmse: 3.63577	valid_1's rmse: 5.28979
# [2850]	training's rmse: 3.61104	valid_1's rmse: 5.2852
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2900]	training's rmse: 3.58576	valid_1's rmse: 5.28212
# [2950]	training's rmse: 3.56295	valid_1's rmse: 5.27862
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3000]	training's rmse: 3.5396	valid_1's rmse: 5.27592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3050]	training's rmse: 3.51594	valid_1's rmse: 5.27332
# [3100]	training's rmse: 3.49343	valid_1's rmse: 5.2712
# [3150]	training's rmse: 3.47069	valid_1's rmse: 5.26869
# [3200]	training's rmse: 3.44641	valid_1's rmse: 5.26492
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3250]	training's rmse: 3.42478	valid_1's rmse: 5.26237
# [3300]	training's rmse: 3.40269	valid_1's rmse: 5.25923
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3350]	training's rmse: 3.38149	valid_1's rmse: 5.25622
# [3400]	training's rmse: 3.35954	valid_1's rmse: 5.25385
# [3450]	training's rmse: 3.33712	valid_1's rmse: 5.25166
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3500]	training's rmse: 3.31601	valid_1's rmse: 5.24935
# [3550]	training's rmse: 3.29467	valid_1's rmse: 5.24675
# [3600]	training's rmse: 3.27365	valid_1's rmse: 5.24502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3650]	training's rmse: 3.25342	valid_1's rmse: 5.24301
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3700]	training's rmse: 3.23314	valid_1's rmse: 5.24062
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3750]	training's rmse: 3.21351	valid_1's rmse: 5.23895
# [3800]	training's rmse: 3.19451	valid_1's rmse: 5.23713
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3850]	training's rmse: 3.17454	valid_1's rmse: 5.23525
# [3900]	training's rmse: 3.15414	valid_1's rmse: 5.23284
# [3950]	training's rmse: 3.13464	valid_1's rmse: 5.23087
# [4000]	training's rmse: 3.11526	valid_1's rmse: 5.22807
# [4050]	training's rmse: 3.09619	valid_1's rmse: 5.22583
# [4100]	training's rmse: 3.07764	valid_1's rmse: 5.2241
# [4150]	training's rmse: 3.05884	valid_1's rmse: 5.22237
# [4200]	training's rmse: 3.04045	valid_1's rmse: 5.22129
# [4250]	training's rmse: 3.02234	valid_1's rmse: 5.21958
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4300]	training's rmse: 3.00411	valid_1's rmse: 5.21777
# [4350]	training's rmse: 2.98577	valid_1's rmse: 5.21621
# [4400]	training's rmse: 2.96762	valid_1's rmse: 5.2136
# [4450]	training's rmse: 2.95011	valid_1's rmse: 5.21178
# [4500]	training's rmse: 2.93305	valid_1's rmse: 5.20976
# [4550]	training's rmse: 2.91594	valid_1's rmse: 5.20874
# [4600]	training's rmse: 2.89901	valid_1's rmse: 5.20772
# [4650]	training's rmse: 2.88221	valid_1's rmse: 5.20732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4700]	training's rmse: 2.86565	valid_1's rmse: 5.20557
# [4750]	training's rmse: 2.84922	valid_1's rmse: 5.20461
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4800]	training's rmse: 2.83328	valid_1's rmse: 5.20299
# [4850]	training's rmse: 2.81673	valid_1's rmse: 5.20094
# [4900]	training's rmse: 2.80043	valid_1's rmse: 5.20038
# [4950]	training's rmse: 2.78465	valid_1's rmse: 5.19956
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5000]	training's rmse: 2.76879	valid_1's rmse: 5.1976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5050]	training's rmse: 2.75347	valid_1's rmse: 5.19685
# [5100]	training's rmse: 2.73802	valid_1's rmse: 5.19484
# [5150]	training's rmse: 2.7226	valid_1's rmse: 5.19333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5200]	training's rmse: 2.70803	valid_1's rmse: 5.19159
# [5250]	training's rmse: 2.69304	valid_1's rmse: 5.19029
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5300]	training's rmse: 2.67805	valid_1's rmse: 5.18889
# [5350]	training's rmse: 2.6626	valid_1's rmse: 5.18787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5400]	training's rmse: 2.64763	valid_1's rmse: 5.18676
# [5450]	training's rmse: 2.63327	valid_1's rmse: 5.18578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5500]	training's rmse: 2.61917	valid_1's rmse: 5.18468
# [5550]	training's rmse: 2.60479	valid_1's rmse: 5.18427
# [5600]	training's rmse: 2.59042	valid_1's rmse: 5.18351
# [5650]	training's rmse: 2.57638	valid_1's rmse: 5.18167
# [5700]	training's rmse: 2.56252	valid_1's rmse: 5.18108
# [5750]	training's rmse: 2.54841	valid_1's rmse: 5.17903
# [5800]	training's rmse: 2.53503	valid_1's rmse: 5.17835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5850]	training's rmse: 2.52118	valid_1's rmse: 5.17606
# [5900]	training's rmse: 2.50777	valid_1's rmse: 5.17508
# [5950]	training's rmse: 2.49437	valid_1's rmse: 5.17398
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6000]	training's rmse: 2.48069	valid_1's rmse: 5.17308
# [6050]	training's rmse: 2.46729	valid_1's rmse: 5.17245
# [6100]	training's rmse: 2.45468	valid_1's rmse: 5.1715
# [6150]	training's rmse: 2.44146	valid_1's rmse: 5.17071
# [6200]	training's rmse: 2.42855	valid_1's rmse: 5.16951
# [6250]	training's rmse: 2.41617	valid_1's rmse: 5.16895
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6300]	training's rmse: 2.40372	valid_1's rmse: 5.168
# [6350]	training's rmse: 2.39093	valid_1's rmse: 5.16699
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6400]	training's rmse: 2.37917	valid_1's rmse: 5.16617
# [6450]	training's rmse: 2.36678	valid_1's rmse: 5.16507
# [6500]	training's rmse: 2.35445	valid_1's rmse: 5.1648
# [6550]	training's rmse: 2.34259	valid_1's rmse: 5.16374
# [6600]	training's rmse: 2.33019	valid_1's rmse: 5.16294
# [6650]	training's rmse: 2.31811	valid_1's rmse: 5.16177
# [6700]	training's rmse: 2.30625	valid_1's rmse: 5.16091
# [6750]	training's rmse: 2.29459	valid_1's rmse: 5.1604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6800]	training's rmse: 2.28307	valid_1's rmse: 5.15954
# [6850]	training's rmse: 2.27156	valid_1's rmse: 5.15845
# [6900]	training's rmse: 2.26034	valid_1's rmse: 5.15803
# [6950]	training's rmse: 2.24919	valid_1's rmse: 5.15739
# [7000]	training's rmse: 2.23799	valid_1's rmse: 5.15646
# [7050]	training's rmse: 2.22681	valid_1's rmse: 5.15674
# [7100]	training's rmse: 2.21571	valid_1's rmse: 5.15588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7150]	training's rmse: 2.20488	valid_1's rmse: 5.1555
# [7200]	training's rmse: 2.19395	valid_1's rmse: 5.1541
# [7250]	training's rmse: 2.18316	valid_1's rmse: 5.15389
# [7300]	training's rmse: 2.17314	valid_1's rmse: 5.15321
# [7350]	training's rmse: 2.16294	valid_1's rmse: 5.1534
# [7400]	training's rmse: 2.1521	valid_1's rmse: 5.15317
# [7450]	training's rmse: 2.14189	valid_1's rmse: 5.15192
# [7500]	training's rmse: 2.13119	valid_1's rmse: 5.1519
# [7550]	training's rmse: 2.12125	valid_1's rmse: 5.15087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7600]	training's rmse: 2.11149	valid_1's rmse: 5.14959
# [7650]	training's rmse: 2.10142	valid_1's rmse: 5.14947
# [7700]	training's rmse: 2.09138	valid_1's rmse: 5.1487
# [7750]	training's rmse: 2.08161	valid_1's rmse: 5.14801
# [7800]	training's rmse: 2.07146	valid_1's rmse: 5.14742
# [7850]	training's rmse: 2.06144	valid_1's rmse: 5.14615
# [7900]	training's rmse: 2.05148	valid_1's rmse: 5.14586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7950]	training's rmse: 2.04168	valid_1's rmse: 5.14537
# [8000]	training's rmse: 2.0318	valid_1's rmse: 5.14525
# Did not meet early stopping. Best iteration is:
# [8000]	training's rmse: 2.0318	valid_1's rmse: 5.14525
# Train RMSE: 2.0317975380913853        Valida RMSE: 5.145250150654279
# Columns: ['emb_ingredients_text_456', 'emb_product_name_287', 'emb_ingredients_text_67', 'emb_product_name_525', 'emb_ingredients_text_511', 'emb_product_name_39', 'emb_countries_en_523', 'emb_ingredients_text_559', 'emb_ingredients_text_431', 'emb_countries_en_738', 'emb_product_name_718', 'emb_countries_en_225', 'emb_product_name_270', 'emb_countries_en_365', 'emb_product_name_155', 'emb_product_name_715', 'emb_countries_en_545', 'emb_countries_en_181', 'emb_product_name_103', 'emb_countries_en_367', 'emb_product_name_164', 'emb_ingredients_text_373', 'emb_ingredients_text_185', 'emb_product_name_83', 'emb_ingredients_text_65', 'emb_countries_en_63', 'emb_countries_en_139', 'emb_product_name_246', 'emb_ingredients_text_45', 'emb_ingredients_text_425', 'emb_countries_en_536', 'emb_product_name_162', 'emb_ingredients_text_368', 'emb_countries_en_322', 'emb_product_name_632', 'emb_product_name_315', 'emb_countries_en_54', 'emb_countries_en_102', 'emb_ingredients_text_556', 'emb_ingredients_text_432', 'emb_product_name_585', 'emb_product_name_378', 'emb_product_name_579', 'emb_product_name_681', 'emb_product_name_286', 'emb_countries_en_101', 'emb_countries_en_748', 'emb_countries_en_257', 'emb_countries_en_109', 'emb_ingredients_text_719', 'emb_countries_en_99', 'emb_countries_en_213', 'emb_ingredients_text_8', 'emb_product_name_137', 'emb_ingredients_text_766', 'emb_countries_en_602', 'emb_product_name_163', 'emb_product_name_352', 'emb_countries_en_466', 'emb_countries_en_238', 'emb_ingredients_text_489', 'emb_countries_en_743', 'emb_countries_en_170', 'emb_ingredients_text_359', 'emb_countries_en_64', 'emb_ingredients_text_372', 'emb_ingredients_text_254', 'emb_countries_en_100', 'emb_countries_en_492', 'emb_product_name_705', 'emb_product_name_93', 'emb_product_name_599', 'emb_ingredients_text_18', 'emb_ingredients_text_274', 'emb_countries_en_295', 'emb_product_name_543', 'emb_ingredients_text_406', 'emb_countries_en_605', 'emb_countries_en_70', 'emb_ingredients_text_446', 'emb_product_name_310', 'emb_countries_en_369', 'emb_countries_en_739', 'emb_ingredients_text_218', 'emb_product_name_483', 'emb_product_name_676', 'emb_product_name_584', 'emb_product_name_573', 'emb_ingredients_text_227', 'emb_ingredients_text_217', 'emb_product_name_586', 'emb_countries_en_438', 'emb_countries_en_152', 'emb_product_name_231', 'emb_product_name_400', 'emb_countries_en_551', 'emb_ingredients_text_578', 'emb_countries_en_702', 'emb_ingredients_text_621', 'emb_countries_en_98', 'emb_ingredients_text_604', 'emb_product_name_355', 'emb_countries_en_241', 'emb_product_name_755', 'emb_ingredients_text_207', 'emb_countries_en_308', 'emb_product_name_753', 'emb_ingredients_text_549', 'emb_countries_en_66', 'emb_ingredients_text_598', 'emb_product_name_359', 'emb_countries_en_67', 'emb_product_name_733', 'emb_ingredients_text_318', 'emb_countries_en_767', 'emb_product_name_704', 'emb_ingredients_text_680', 'emb_countries_en_687', 'emb_countries_en_123', 'emb_countries_en_669', 'emb_product_name_332', 'emb_countries_en_211', 'emb_countries_en_159', 'emb_product_name_710', 'emb_product_name_19', 'emb_product_name_326', 'emb_ingredients_text_31', 'emb_ingredients_text_146', 'emb_countries_en_499', 'emb_countries_en_637', 'emb_ingredients_text_419', 'emb_ingredients_text_540', 'emb_product_name_687', 'emb_countries_en_505', 'emb_product_name_565', 'emb_countries_en_433', 'emb_product_name_75', 'emb_product_name_664', 'emb_countries_en_52', 'emb_ingredients_text_481', 'emb_ingredients_text_422', 'emb_countries_en_496', 'emb_countries_en_501', 'emb_ingredients_text_707', 'emb_product_name_653', 'emb_product_name_354', 'emb_ingredients_text_156', 'emb_ingredients_text_752', 'emb_countries_en_279', 'emb_product_name_496', 'emb_product_name_375', 'emb_countries_en_40', 'emb_countries_en_325', 'emb_countries_en_609', 'emb_product_name_711', 'emb_ingredients_text_603', 'emb_countries_en_197', 'emb_product_name_377', 'emb_product_name_235', 'emb_countries_e ...
# Cat index: [2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321]
# ---------- Training fold Nº 2 ----------
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 495441
# [LightGBM] [Info] Number of data points in the train set: 81622, number of used features: 2322
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 9.169930
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 6.72035	valid_1's rmse: 6.7885
# [100]	training's rmse: 6.30565	valid_1's rmse: 6.42523
# [150]	training's rmse: 6.0789	valid_1's rmse: 6.24508
# [200]	training's rmse: 5.92195	valid_1's rmse: 6.12965
# [250]	training's rmse: 5.79573	valid_1's rmse: 6.04434
# [300]	training's rmse: 5.68342	valid_1's rmse: 5.96743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	training's rmse: 5.59008	valid_1's rmse: 5.91412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	training's rmse: 5.50527	valid_1's rmse: 5.86611
# [450]	training's rmse: 5.42573	valid_1's rmse: 5.82416
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	training's rmse: 5.35422	valid_1's rmse: 5.78806
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	training's rmse: 5.2865	valid_1's rmse: 5.75925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	training's rmse: 5.22193	valid_1's rmse: 5.72949
# [650]	training's rmse: 5.16126	valid_1's rmse: 5.70336
# [700]	training's rmse: 5.1043	valid_1's rmse: 5.67758
# [750]	training's rmse: 5.04766	valid_1's rmse: 5.6548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's rmse: 4.99446	valid_1's rmse: 5.63369
# [850]	training's rmse: 4.94262	valid_1's rmse: 5.61696
# [900]	training's rmse: 4.89264	valid_1's rmse: 5.59872
# [950]	training's rmse: 4.84538	valid_1's rmse: 5.58502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	training's rmse: 4.79943	valid_1's rmse: 5.57076
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1050]	training's rmse: 4.75417	valid_1's rmse: 5.55867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1100]	training's rmse: 4.70854	valid_1's rmse: 5.54446
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1150]	training's rmse: 4.66572	valid_1's rmse: 5.53098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1200]	training's rmse: 4.62413	valid_1's rmse: 5.51997
# [1250]	training's rmse: 4.58329	valid_1's rmse: 5.50761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1300]	training's rmse: 4.54288	valid_1's rmse: 5.49545
# [1350]	training's rmse: 4.50538	valid_1's rmse: 5.48706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1400]	training's rmse: 4.46711	valid_1's rmse: 5.47639
# [1450]	training's rmse: 4.43032	valid_1's rmse: 5.46601
# [1500]	training's rmse: 4.39349	valid_1's rmse: 5.45911
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1550]	training's rmse: 4.358	valid_1's rmse: 5.45088
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1600]	training's rmse: 4.32436	valid_1's rmse: 5.4436
# [1650]	training's rmse: 4.29077	valid_1's rmse: 5.43576
# [1700]	training's rmse: 4.25747	valid_1's rmse: 5.42995
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1750]	training's rmse: 4.2233	valid_1's rmse: 5.42291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	training's rmse: 4.19114	valid_1's rmse: 5.4175
# [1850]	training's rmse: 4.15943	valid_1's rmse: 5.41094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	training's rmse: 4.12837	valid_1's rmse: 5.40429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1950]	training's rmse: 4.09676	valid_1's rmse: 5.39671
# [2000]	training's rmse: 4.06676	valid_1's rmse: 5.38991
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2050]	training's rmse: 4.03661	valid_1's rmse: 5.38481
# [2100]	training's rmse: 4.00705	valid_1's rmse: 5.38001
# [2150]	training's rmse: 3.97703	valid_1's rmse: 5.37431
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2200]	training's rmse: 3.94869	valid_1's rmse: 5.36942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2250]	training's rmse: 3.9207	valid_1's rmse: 5.36374
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2300]	training's rmse: 3.89175	valid_1's rmse: 5.35838
# [2350]	training's rmse: 3.86489	valid_1's rmse: 5.35604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2400]	training's rmse: 3.83861	valid_1's rmse: 5.35174
# [2450]	training's rmse: 3.81178	valid_1's rmse: 5.34809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2500]	training's rmse: 3.78506	valid_1's rmse: 5.34098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2550]	training's rmse: 3.75894	valid_1's rmse: 5.33669
# [2600]	training's rmse: 3.7319	valid_1's rmse: 5.33216
# [2650]	training's rmse: 3.70493	valid_1's rmse: 5.32798
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2700]	training's rmse: 3.68056	valid_1's rmse: 5.32325
# [2750]	training's rmse: 3.65523	valid_1's rmse: 5.31745
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2800]	training's rmse: 3.63079	valid_1's rmse: 5.3138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2850]	training's rmse: 3.60684	valid_1's rmse: 5.30934
# [2900]	training's rmse: 3.58315	valid_1's rmse: 5.30668
# [2950]	training's rmse: 3.55833	valid_1's rmse: 5.30473
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3000]	training's rmse: 3.53495	valid_1's rmse: 5.30079
# [3050]	training's rmse: 3.51169	valid_1's rmse: 5.29785
# [3100]	training's rmse: 3.4887	valid_1's rmse: 5.29629
# [3150]	training's rmse: 3.46536	valid_1's rmse: 5.2944
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3200]	training's rmse: 3.44352	valid_1's rmse: 5.29197
# [3250]	training's rmse: 3.42108	valid_1's rmse: 5.28765
# [3300]	training's rmse: 3.39742	valid_1's rmse: 5.28454
# [3350]	training's rmse: 3.37598	valid_1's rmse: 5.28101
# [3400]	training's rmse: 3.35422	valid_1's rmse: 5.27792
# [3450]	training's rmse: 3.33322	valid_1's rmse: 5.27611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3500]	training's rmse: 3.31206	valid_1's rmse: 5.27325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3550]	training's rmse: 3.29125	valid_1's rmse: 5.27009
# [3600]	training's rmse: 3.27174	valid_1's rmse: 5.26737
# [3650]	training's rmse: 3.25095	valid_1's rmse: 5.26496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3700]	training's rmse: 3.23067	valid_1's rmse: 5.26214
# [3750]	training's rmse: 3.2107	valid_1's rmse: 5.26056
# [3800]	training's rmse: 3.19121	valid_1's rmse: 5.25858
# [3850]	training's rmse: 3.17119	valid_1's rmse: 5.25579
# [3900]	training's rmse: 3.15156	valid_1's rmse: 5.25268
# [3950]	training's rmse: 3.13205	valid_1's rmse: 5.25029
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4000]	training's rmse: 3.11374	valid_1's rmse: 5.24833
# [4050]	training's rmse: 3.09497	valid_1's rmse: 5.24644
# [4100]	training's rmse: 3.07633	valid_1's rmse: 5.24441
# [4150]	training's rmse: 3.05827	valid_1's rmse: 5.24204
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4200]	training's rmse: 3.03992	valid_1's rmse: 5.23957
# [4250]	training's rmse: 3.0211	valid_1's rmse: 5.23706
# [4300]	training's rmse: 3.003	valid_1's rmse: 5.23457
# [4350]	training's rmse: 2.98466	valid_1's rmse: 5.2321
# [4400]	training's rmse: 2.96714	valid_1's rmse: 5.23009
# [4450]	training's rmse: 2.94901	valid_1's rmse: 5.2287
# [4500]	training's rmse: 2.93188	valid_1's rmse: 5.22733
# [4550]	training's rmse: 2.91465	valid_1's rmse: 5.22517
# [4600]	training's rmse: 2.89765	valid_1's rmse: 5.22359
# [4650]	training's rmse: 2.88095	valid_1's rmse: 5.22165
# [4700]	training's rmse: 2.86485	valid_1's rmse: 5.22016
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4750]	training's rmse: 2.84845	valid_1's rmse: 5.21727
# [4800]	training's rmse: 2.83239	valid_1's rmse: 5.2165
# [4850]	training's rmse: 2.81616	valid_1's rmse: 5.21428
# [4900]	training's rmse: 2.80024	valid_1's rmse: 5.21204
# [4950]	training's rmse: 2.78385	valid_1's rmse: 5.21007
# [5000]	training's rmse: 2.76791	valid_1's rmse: 5.2088
# [5050]	training's rmse: 2.75235	valid_1's rmse: 5.20817
# [5100]	training's rmse: 2.7368	valid_1's rmse: 5.20731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5150]	training's rmse: 2.7213	valid_1's rmse: 5.20532
# [5200]	training's rmse: 2.70637	valid_1's rmse: 5.20439
# [5250]	training's rmse: 2.69154	valid_1's rmse: 5.20341
# [5300]	training's rmse: 2.6767	valid_1's rmse: 5.20252
# [5350]	training's rmse: 2.66207	valid_1's rmse: 5.20145
# [5400]	training's rmse: 2.6473	valid_1's rmse: 5.20059
# [5450]	training's rmse: 2.63211	valid_1's rmse: 5.19972
# [5500]	training's rmse: 2.618	valid_1's rmse: 5.19748
# [5550]	training's rmse: 2.60344	valid_1's rmse: 5.19651
# [5600]	training's rmse: 2.58809	valid_1's rmse: 5.19637
# [5650]	training's rmse: 2.57384	valid_1's rmse: 5.19487
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5700]	training's rmse: 2.5609	valid_1's rmse: 5.19383
# [5750]	training's rmse: 2.54686	valid_1's rmse: 5.19299
# [5800]	training's rmse: 2.5326	valid_1's rmse: 5.19195
# [5850]	training's rmse: 2.51913	valid_1's rmse: 5.19102
# [5900]	training's rmse: 2.50511	valid_1's rmse: 5.18928
# [5950]	training's rmse: 2.49131	valid_1's rmse: 5.18814
# [6000]	training's rmse: 2.47804	valid_1's rmse: 5.18705
# [6050]	training's rmse: 2.46513	valid_1's rmse: 5.18666
# [6100]	training's rmse: 2.45216	valid_1's rmse: 5.18632
# [6150]	training's rmse: 2.4401	valid_1's rmse: 5.18545
# [6200]	training's rmse: 2.42737	valid_1's rmse: 5.18398
# [6250]	training's rmse: 2.41489	valid_1's rmse: 5.18314
# [6300]	training's rmse: 2.40282	valid_1's rmse: 5.18245
# [6350]	training's rmse: 2.39001	valid_1's rmse: 5.18182
# [6400]	training's rmse: 2.37769	valid_1's rmse: 5.18125
# [6450]	training's rmse: 2.36522	valid_1's rmse: 5.17972
# [6500]	training's rmse: 2.35349	valid_1's rmse: 5.17884
# [6550]	training's rmse: 2.34075	valid_1's rmse: 5.1774
# [6600]	training's rmse: 2.32811	valid_1's rmse: 5.177
# [6650]	training's rmse: 2.31631	valid_1's rmse: 5.17654
# [6700]	training's rmse: 2.30459	valid_1's rmse: 5.17581
# [6750]	training's rmse: 2.29277	valid_1's rmse: 5.17448
# [6800]	training's rmse: 2.2813	valid_1's rmse: 5.17335
# [6850]	training's rmse: 2.2694	valid_1's rmse: 5.17244
# [6900]	training's rmse: 2.2579	valid_1's rmse: 5.17158
# [6950]	training's rmse: 2.24679	valid_1's rmse: 5.17096
# [7000]	training's rmse: 2.23523	valid_1's rmse: 5.17015
# [7050]	training's rmse: 2.22445	valid_1's rmse: 5.1695
# [7100]	training's rmse: 2.21333	valid_1's rmse: 5.16851
# [7150]	training's rmse: 2.20219	valid_1's rmse: 5.16782
# [7200]	training's rmse: 2.19154	valid_1's rmse: 5.16747
# [7250]	training's rmse: 2.18048	valid_1's rmse: 5.16636
# [7300]	training's rmse: 2.1697	valid_1's rmse: 5.16485
# [7350]	training's rmse: 2.15922	valid_1's rmse: 5.16451
# [7400]	training's rmse: 2.14846	valid_1's rmse: 5.16311
# [7450]	training's rmse: 2.13806	valid_1's rmse: 5.16342
# [7500]	training's rmse: 2.12822	valid_1's rmse: 5.16249
# [7550]	training's rmse: 2.11742	valid_1's rmse: 5.16206
# [7600]	training's rmse: 2.10738	valid_1's rmse: 5.16173
# [7650]	training's rmse: 2.09719	valid_1's rmse: 5.16108
# [7700]	training's rmse: 2.08752	valid_1's rmse: 5.16092
# [7750]	training's rmse: 2.07744	valid_1's rmse: 5.16024
# [7800]	training's rmse: 2.06743	valid_1's rmse: 5.16018
# [7850]	training's rmse: 2.05715	valid_1's rmse: 5.15913
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7900]	training's rmse: 2.04737	valid_1's rmse: 5.15842
# [7950]	training's rmse: 2.03768	valid_1's rmse: 5.15748
# [8000]	training's rmse: 2.02814	valid_1's rmse: 5.15714
# Did not meet early stopping. Best iteration is:
# [8000]	training's rmse: 2.02814	valid_1's rmse: 5.15714
# Train RMSE: 2.0281365263753353        Valida RMSE: 5.157143276311787
# Columns: ['emb_ingredients_text_456', 'emb_product_name_287', 'emb_ingredients_text_67', 'emb_product_name_525', 'emb_ingredients_text_511', 'emb_product_name_39', 'emb_countries_en_523', 'emb_ingredients_text_559', 'emb_ingredients_text_431', 'emb_countries_en_738', 'emb_product_name_718', 'emb_countries_en_225', 'emb_product_name_270', 'emb_countries_en_365', 'emb_product_name_155', 'emb_product_name_715', 'emb_countries_en_545', 'emb_countries_en_181', 'emb_product_name_103', 'emb_countries_en_367', 'emb_product_name_164', 'emb_ingredients_text_373', 'emb_ingredients_text_185', 'emb_product_name_83', 'emb_ingredients_text_65', 'emb_countries_en_63', 'emb_countries_en_139', 'emb_product_name_246', 'emb_ingredients_text_45', 'emb_ingredients_text_425', 'emb_countries_en_536', 'emb_product_name_162', 'emb_ingredients_text_368', 'emb_countries_en_322', 'emb_product_name_632', 'emb_product_name_315', 'emb_countries_en_54', 'emb_countries_en_102', 'emb_ingredients_text_556', 'emb_ingredients_text_432', 'emb_product_name_585', 'emb_product_name_378', 'emb_product_name_579', 'emb_product_name_681', 'emb_product_name_286', 'emb_countries_en_101', 'emb_countries_en_748', 'emb_countries_en_257', 'emb_countries_en_109', 'emb_ingredients_text_719', 'emb_countries_en_99', 'emb_countries_en_213', 'emb_ingredients_text_8', 'emb_product_name_137', 'emb_ingredients_text_766', 'emb_countries_en_602', 'emb_product_name_163', 'emb_product_name_352', 'emb_countries_en_466', 'emb_countries_en_238', 'emb_ingredients_text_489', 'emb_countries_en_743', 'emb_countries_en_170', 'emb_ingredients_text_359', 'emb_countries_en_64', 'emb_ingredients_text_372', 'emb_ingredients_text_254', 'emb_countries_en_100', 'emb_countries_en_492', 'emb_product_name_705', 'emb_product_name_93', 'emb_product_name_599', 'emb_ingredients_text_18', 'emb_ingredients_text_274', 'emb_countries_en_295', 'emb_product_name_543', 'emb_ingredients_text_406', 'emb_countries_en_605', 'emb_countries_en_70', 'emb_ingredients_text_446', 'emb_product_name_310', 'emb_countries_en_369', 'emb_countries_en_739', 'emb_ingredients_text_218', 'emb_product_name_483', 'emb_product_name_676', 'emb_product_name_584', 'emb_product_name_573', 'emb_ingredients_text_227', 'emb_ingredients_text_217', 'emb_product_name_586', 'emb_countries_en_438', 'emb_countries_en_152', 'emb_product_name_231', 'emb_product_name_400', 'emb_countries_en_551', 'emb_ingredients_text_578', 'emb_countries_en_702', 'emb_ingredients_text_621', 'emb_countries_en_98', 'emb_ingredients_text_604', 'emb_product_name_355', 'emb_countries_en_241', 'emb_product_name_755', 'emb_ingredients_text_207', 'emb_countries_en_308', 'emb_product_name_753', 'emb_ingredients_text_549', 'emb_countries_en_66', 'emb_ingredients_text_598', 'emb_product_name_359', 'emb_countries_en_67', 'emb_product_name_733', 'emb_ingredients_text_318', 'emb_countries_en_767', 'emb_product_name_704', 'emb_ingredients_text_680', 'emb_countries_en_687', 'emb_countries_en_123', 'emb_countries_en_669', 'emb_product_name_332', 'emb_countries_en_211', 'emb_countries_en_159', 'emb_product_name_710', 'emb_product_name_19', 'emb_product_name_326', 'emb_ingredients_text_31', 'emb_ingredients_text_146', 'emb_countries_en_499', 'emb_countries_en_637', 'emb_ingredients_text_419', 'emb_ingredients_text_540', 'emb_product_name_687', 'emb_countries_en_505', 'emb_product_name_565', 'emb_countries_en_433', 'emb_product_name_75', 'emb_product_name_664', 'emb_countries_en_52', 'emb_ingredients_text_481', 'emb_ingredients_text_422', 'emb_countries_en_496', 'emb_countries_en_501', 'emb_ingredients_text_707', 'emb_product_name_653', 'emb_product_name_354', 'emb_ingredients_text_156', 'emb_ingredients_text_752', 'emb_countries_en_279', 'emb_product_name_496', 'emb_product_name_375', 'emb_countries_en_40', 'emb_countries_en_325', 'emb_countries_en_609', 'emb_product_name_711', 'emb_ingredients_text_603', 'emb_countries_en_197', 'emb_product_name_377', 'emb_product_name_235', 'emb_countries_e ...
# Cat index: [2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321]
# ---------- Training fold Nº 3 ----------
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 497084
# [LightGBM] [Info] Number of data points in the train set: 81622, number of used features: 2322
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 9.171253
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 6.73679	valid_1's rmse: 6.78169
# [100]	training's rmse: 6.32076	valid_1's rmse: 6.40293
# [150]	training's rmse: 6.09532	valid_1's rmse: 6.20922
# [200]	training's rmse: 5.93748	valid_1's rmse: 6.09446
# [250]	training's rmse: 5.80764	valid_1's rmse: 6.00132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	training's rmse: 5.69721	valid_1's rmse: 5.928
# [350]	training's rmse: 5.60006	valid_1's rmse: 5.87067
# [400]	training's rmse: 5.51372	valid_1's rmse: 5.81982
# [450]	training's rmse: 5.43462	valid_1's rmse: 5.77924
# [500]	training's rmse: 5.36101	valid_1's rmse: 5.74147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	training's rmse: 5.29367	valid_1's rmse: 5.71045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	training's rmse: 5.22851	valid_1's rmse: 5.68469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [650]	training's rmse: 5.16815	valid_1's rmse: 5.65702
# [700]	training's rmse: 5.11019	valid_1's rmse: 5.63166
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	training's rmse: 5.05694	valid_1's rmse: 5.60968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's rmse: 5.00454	valid_1's rmse: 5.5936
# [850]	training's rmse: 4.9532	valid_1's rmse: 5.57554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [900]	training's rmse: 4.90437	valid_1's rmse: 5.55978
# [950]	training's rmse: 4.85658	valid_1's rmse: 5.54453
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	training's rmse: 4.80967	valid_1's rmse: 5.53005
# [1050]	training's rmse: 4.76424	valid_1's rmse: 5.5163
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1100]	training's rmse: 4.72077	valid_1's rmse: 5.50244
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1150]	training's rmse: 4.67828	valid_1's rmse: 5.49091
# [1200]	training's rmse: 4.63503	valid_1's rmse: 5.47751
# [1250]	training's rmse: 4.59407	valid_1's rmse: 5.46598
# [1300]	training's rmse: 4.55312	valid_1's rmse: 5.45504
# [1350]	training's rmse: 4.5128	valid_1's rmse: 5.44621
# [1400]	training's rmse: 4.47422	valid_1's rmse: 5.43527
# [1450]	training's rmse: 4.4368	valid_1's rmse: 5.42696
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1500]	training's rmse: 4.40042	valid_1's rmse: 5.41756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1550]	training's rmse: 4.3647	valid_1's rmse: 5.40895
# [1600]	training's rmse: 4.33024	valid_1's rmse: 5.40118
# [1650]	training's rmse: 4.29551	valid_1's rmse: 5.393
# [1700]	training's rmse: 4.26129	valid_1's rmse: 5.3844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1750]	training's rmse: 4.22832	valid_1's rmse: 5.37841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	training's rmse: 4.1959	valid_1's rmse: 5.3715
# [1850]	training's rmse: 4.16441	valid_1's rmse: 5.36544
# [1900]	training's rmse: 4.13271	valid_1's rmse: 5.36004
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1950]	training's rmse: 4.10169	valid_1's rmse: 5.35397
# [2000]	training's rmse: 4.07101	valid_1's rmse: 5.34976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2050]	training's rmse: 4.04086	valid_1's rmse: 5.34537
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2100]	training's rmse: 4.01226	valid_1's rmse: 5.3403
# [2150]	training's rmse: 3.98191	valid_1's rmse: 5.33414
# [2200]	training's rmse: 3.9534	valid_1's rmse: 5.33068
# [2250]	training's rmse: 3.92531	valid_1's rmse: 5.32433
# [2300]	training's rmse: 3.89801	valid_1's rmse: 5.3192
# [2350]	training's rmse: 3.87032	valid_1's rmse: 5.31574
# [2400]	training's rmse: 3.84238	valid_1's rmse: 5.31122
# [2450]	training's rmse: 3.81563	valid_1's rmse: 5.30776
# [2500]	training's rmse: 3.78889	valid_1's rmse: 5.30357
# [2550]	training's rmse: 3.76286	valid_1's rmse: 5.3005
# [2600]	training's rmse: 3.73625	valid_1's rmse: 5.2968
# [2650]	training's rmse: 3.71016	valid_1's rmse: 5.29197
# [2700]	training's rmse: 3.68472	valid_1's rmse: 5.28867
# [2750]	training's rmse: 3.66027	valid_1's rmse: 5.28528
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2800]	training's rmse: 3.63528	valid_1's rmse: 5.28284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2850]	training's rmse: 3.61047	valid_1's rmse: 5.27946
# [2900]	training's rmse: 3.58578	valid_1's rmse: 5.27411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2950]	training's rmse: 3.56112	valid_1's rmse: 5.27113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3000]	training's rmse: 3.53737	valid_1's rmse: 5.26942
# [3050]	training's rmse: 3.51271	valid_1's rmse: 5.26441
# [3100]	training's rmse: 3.48941	valid_1's rmse: 5.26151
# [3150]	training's rmse: 3.46616	valid_1's rmse: 5.25969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3200]	training's rmse: 3.44387	valid_1's rmse: 5.25655
# [3250]	training's rmse: 3.42172	valid_1's rmse: 5.2543
# [3300]	training's rmse: 3.39924	valid_1's rmse: 5.25232
# [3350]	training's rmse: 3.37753	valid_1's rmse: 5.24942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3400]	training's rmse: 3.35587	valid_1's rmse: 5.24655
# [3450]	training's rmse: 3.33434	valid_1's rmse: 5.24351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3500]	training's rmse: 3.31272	valid_1's rmse: 5.24153
# [3550]	training's rmse: 3.2917	valid_1's rmse: 5.23991
# [3600]	training's rmse: 3.27095	valid_1's rmse: 5.23857
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# Cat index: [2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321]
# ---------- Training fold Nº 5 ----------
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 495776
# [LightGBM] [Info] Number of data points in the train set: 81623, number of used features: 2322
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 9.170246
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 6.73085	valid_1's rmse: 6.7972
# [100]	training's rmse: 6.31549	valid_1's rmse: 6.43203
# [150]	training's rmse: 6.0899	valid_1's rmse: 6.25521
# [200]	training's rmse: 5.92949	valid_1's rmse: 6.13825
# [250]	training's rmse: 5.79925	valid_1's rmse: 6.05134
# [300]	training's rmse: 5.68657	valid_1's rmse: 5.97698
# [350]	training's rmse: 5.58863	valid_1's rmse: 5.91801
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	training's rmse: 5.50493	valid_1's rmse: 5.87441
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	training's rmse: 5.42755	valid_1's rmse: 5.83237
# [500]	training's rmse: 5.35435	valid_1's rmse: 5.79592
# [550]	training's rmse: 5.28644	valid_1's rmse: 5.76374
# [600]	training's rmse: 5.22006	valid_1's rmse: 5.73284
# [650]	training's rmse: 5.15795	valid_1's rmse: 5.70559
# [700]	training's rmse: 5.10029	valid_1's rmse: 5.68495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	training's rmse: 5.04548	valid_1's rmse: 5.66164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's rmse: 4.99213	valid_1's rmse: 5.64254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	training's rmse: 4.94111	valid_1's rmse: 5.62123
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [900]	training's rmse: 4.89358	valid_1's rmse: 5.60725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	training's rmse: 4.84595	valid_1's rmse: 5.59013
# [1000]	training's rmse: 4.79909	valid_1's rmse: 5.57458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1050]	training's rmse: 4.7534	valid_1's rmse: 5.55904
# [1100]	training's rmse: 4.70958	valid_1's rmse: 5.54722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1150]	training's rmse: 4.66678	valid_1's rmse: 5.5345
# [1200]	training's rmse: 4.6255	valid_1's rmse: 5.5225
# [1250]	training's rmse: 4.58366	valid_1's rmse: 5.51111
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1300]	training's rmse: 4.54242	valid_1's rmse: 5.50002
# [1350]	training's rmse: 4.50392	valid_1's rmse: 5.49153
# [1400]	training's rmse: 4.46548	valid_1's rmse: 5.48195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1450]	training's rmse: 4.42896	valid_1's rmse: 5.47203
# [1500]	training's rmse: 4.39312	valid_1's rmse: 5.46457
# [1550]	training's rmse: 4.35884	valid_1's rmse: 5.45666
# [1600]	training's rmse: 4.32345	valid_1's rmse: 5.44844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1650]	training's rmse: 4.28966	valid_1's rmse: 5.44066
# [1700]	training's rmse: 4.25639	valid_1's rmse: 5.43311
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1750]	training's rmse: 4.22366	valid_1's rmse: 5.4253
# [1800]	training's rmse: 4.1904	valid_1's rmse: 5.41835
# [1850]	training's rmse: 4.15719	valid_1's rmse: 5.41175
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	training's rmse: 4.12586	valid_1's rmse: 5.40341
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1950]	training's rmse: 4.09463	valid_1's rmse: 5.398
# [2000]	training's rmse: 4.06438	valid_1's rmse: 5.39151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2050]	training's rmse: 4.03566	valid_1's rmse: 5.38696
# [2100]	training's rmse: 4.00645	valid_1's rmse: 5.38091
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2150]	training's rmse: 3.97697	valid_1's rmse: 5.3756
# [2200]	training's rmse: 3.9484	valid_1's rmse: 5.37106
# [2250]	training's rmse: 3.92036	valid_1's rmse: 5.36507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2300]	training's rmse: 3.89243	valid_1's rmse: 5.36018
# [2350]	training's rmse: 3.86366	valid_1's rmse: 5.35538
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2400]	training's rmse: 3.83642	valid_1's rmse: 5.35116
# [2450]	training's rmse: 3.80905	valid_1's rmse: 5.34564
# [2500]	training's rmse: 3.78269	valid_1's rmse: 5.34155
# [2550]	training's rmse: 3.75634	valid_1's rmse: 5.33729
# [2600]	training's rmse: 3.72933	valid_1's rmse: 5.33468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2650]	training's rmse: 3.70329	valid_1's rmse: 5.33074
# [2700]	training's rmse: 3.67801	valid_1's rmse: 5.32506
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2750]	training's rmse: 3.6532	valid_1's rmse: 5.32204
# [2800]	training's rmse: 3.62771	valid_1's rmse: 5.3184
# [2850]	training's rmse: 3.60379	valid_1's rmse: 5.3139
# [2900]	training's rmse: 3.57979	valid_1's rmse: 5.30926
# [2950]	training's rmse: 3.55579	valid_1's rmse: 5.30595
# [3000]	training's rmse: 3.53124	valid_1's rmse: 5.3026
# [3050]	training's rmse: 3.50748	valid_1's rmse: 5.29838
# [3100]	training's rmse: 3.48361	valid_1's rmse: 5.29424
# [3150]	training's rmse: 3.46094	valid_1's rmse: 5.29009
# [3200]	training's rmse: 3.43794	valid_1's rmse: 5.2885
# [3250]	training's rmse: 3.41573	valid_1's rmse: 5.28573
# [3300]	training's rmse: 3.39399	valid_1's rmse: 5.28394
# [3350]	training's rmse: 3.37253	valid_1's rmse: 5.2819
# [3400]	training's rmse: 3.35205	valid_1's rmse: 5.27804
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3450]	training's rmse: 3.33165	valid_1's rmse: 5.27511
# [3500]	training's rmse: 3.31081	valid_1's rmse: 5.27321
# [3550]	training's rmse: 3.28991	valid_1's rmse: 5.27116
# [3600]	training's rmse: 3.26848	valid_1's rmse: 5.26922
# [3650]	training's rmse: 3.24752	valid_1's rmse: 5.26639
# [3700]	training's rmse: 3.22641	valid_1's rmse: 5.26351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3750]	training's rmse: 3.20684	valid_1's rmse: 5.26121
# [3800]	training's rmse: 3.18693	valid_1's rmse: 5.25817
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3850]	training's rmse: 3.1674	valid_1's rmse: 5.25647
# [3900]	training's rmse: 3.14723	valid_1's rmse: 5.25312
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3950]	training's rmse: 3.12786	valid_1's rmse: 5.25165
# [4000]	training's rmse: 3.10837	valid_1's rmse: 5.25026
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4050]	training's rmse: 3.08914	valid_1's rmse: 5.24975
# [4100]	training's rmse: 3.06973	valid_1's rmse: 5.24798
# [4150]	training's rmse: 3.05175	valid_1's rmse: 5.24599
# [4200]	training's rmse: 3.03306	valid_1's rmse: 5.24396
# [4250]	training's rmse: 3.01489	valid_1's rmse: 5.2429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4300]	training's rmse: 2.9969	valid_1's rmse: 5.24214
# [4350]	training's rmse: 2.97875	valid_1's rmse: 5.23969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4400]	training's rmse: 2.96092	valid_1's rmse: 5.23799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4450]	training's rmse: 2.94263	valid_1's rmse: 5.2362
# [4500]	training's rmse: 2.92537	valid_1's rmse: 5.23421
# [4550]	training's rmse: 2.9089	valid_1's rmse: 5.23255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4600]	training's rmse: 2.89261	valid_1's rmse: 5.2303
# [4650]	training's rmse: 2.87581	valid_1's rmse: 5.22843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4700]	training's rmse: 2.85898	valid_1's rmse: 5.22695
# [4750]	training's rmse: 2.84211	valid_1's rmse: 5.22473
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4800]	training's rmse: 2.82556	valid_1's rmse: 5.22398
# [4850]	training's rmse: 2.80972	valid_1's rmse: 5.22367
# [4900]	training's rmse: 2.79394	valid_1's rmse: 5.22189
# [4950]	training's rmse: 2.77804	valid_1's rmse: 5.21995
# [5000]	training's rmse: 2.76282	valid_1's rmse: 5.21858
# [5050]	training's rmse: 2.74778	valid_1's rmse: 5.21762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5100]	training's rmse: 2.7321	valid_1's rmse: 5.21686
# [5150]	training's rmse: 2.71664	valid_1's rmse: 5.21521
# [5200]	training's rmse: 2.70158	valid_1's rmse: 5.21519
# [5250]	training's rmse: 2.68744	valid_1's rmse: 5.21407
# [5300]	training's rmse: 2.6727	valid_1's rmse: 5.21195
# [5350]	training's rmse: 2.65807	valid_1's rmse: 5.21085
# [5400]	training's rmse: 2.64292	valid_1's rmse: 5.20986
# [5450]	training's rmse: 2.62837	valid_1's rmse: 5.20898
# [5500]	training's rmse: 2.61375	valid_1's rmse: 5.20795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5550]	training's rmse: 2.59951	valid_1's rmse: 5.20683
# [5600]	training's rmse: 2.58555	valid_1's rmse: 5.20553
# [5650]	training's rmse: 2.57074	valid_1's rmse: 5.20438
# [5700]	training's rmse: 2.55698	valid_1's rmse: 5.20326
# [5750]	training's rmse: 2.54271	valid_1's rmse: 5.2019
# [5800]	training's rmse: 2.52884	valid_1's rmse: 5.20044
# [5850]	training's rmse: 2.51448	valid_1's rmse: 5.19912
# [5900]	training's rmse: 2.50132	valid_1's rmse: 5.19725
# [5950]	training's rmse: 2.48806	valid_1's rmse: 5.19637
# [6000]	training's rmse: 2.47441	valid_1's rmse: 5.19575
# [6050]	training's rmse: 2.46089	valid_1's rmse: 5.19465
# [6100]	training's rmse: 2.44755	valid_1's rmse: 5.19469
# [6150]	training's rmse: 2.43471	valid_1's rmse: 5.1939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6200]	training's rmse: 2.42207	valid_1's rmse: 5.19349
# [6250]	training's rmse: 2.40938	valid_1's rmse: 5.1921
# [6300]	training's rmse: 2.39673	valid_1's rmse: 5.19127
# [6350]	training's rmse: 2.38384	valid_1's rmse: 5.18962
# [6400]	training's rmse: 2.37187	valid_1's rmse: 5.18853
# [6450]	training's rmse: 2.3596	valid_1's rmse: 5.18724
# [6500]	training's rmse: 2.34685	valid_1's rmse: 5.18614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6550]	training's rmse: 2.33442	valid_1's rmse: 5.18481
# [6600]	training's rmse: 2.32267	valid_1's rmse: 5.18393
# [6650]	training's rmse: 2.31086	valid_1's rmse: 5.1829
# [6700]	training's rmse: 2.29906	valid_1's rmse: 5.1825
# [6750]	training's rmse: 2.28748	valid_1's rmse: 5.18129
# [6800]	training's rmse: 2.27572	valid_1's rmse: 5.18009
# [6850]	training's rmse: 2.26411	valid_1's rmse: 5.17954
# [6900]	training's rmse: 2.2523	valid_1's rmse: 5.17836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6950]	training's rmse: 2.24071	valid_1's rmse: 5.17748
# [7000]	training's rmse: 2.22906	valid_1's rmse: 5.17648
# [7050]	training's rmse: 2.2178	valid_1's rmse: 5.17599
# [7100]	training's rmse: 2.20653	valid_1's rmse: 5.17517
# [7150]	training's rmse: 2.19541	valid_1's rmse: 5.17519
# [7200]	training's rmse: 2.18417	valid_1's rmse: 5.17475
# [7250]	training's rmse: 2.1736	valid_1's rmse: 5.17409
# [7300]	training's rmse: 2.16299	valid_1's rmse: 5.17346
# [7350]	training's rmse: 2.15246	valid_1's rmse: 5.1733
# [7400]	training's rmse: 2.14154	valid_1's rmse: 5.17302
# [7450]	training's rmse: 2.13097	valid_1's rmse: 5.17231
# [7500]	training's rmse: 2.12065	valid_1's rmse: 5.17191
# [7550]	training's rmse: 2.10993	valid_1's rmse: 5.17139
# [7600]	training's rmse: 2.09993	valid_1's rmse: 5.17019
# [7650]	training's rmse: 2.08977	valid_1's rmse: 5.1694
# [7700]	training's rmse: 2.07974	valid_1's rmse: 5.1688
# [7750]	training's rmse: 2.06965	valid_1's rmse: 5.16804
# [7800]	training's rmse: 2.0594	valid_1's rmse: 5.16755
# [7850]	training's rmse: 2.04956	valid_1's rmse: 5.16694
# [7900]	training's rmse: 2.03965	valid_1's rmse: 5.16655
# [7950]	training's rmse: 2.03001	valid_1's rmse: 5.16565
# [8000]	training's rmse: 2.02077	valid_1's rmse: 5.16537
# Did not meet early stopping. Best iteration is:
# [8000]	training's rmse: 2.02077	valid_1's rmse: 5.16537
# Train RMSE: 2.020773578916982        Valida RMSE: 5.165371898441832
# OOF RMSE: 5.162615389166297

# %% [markdown]
# ## Evaluando

# %%
df_test      = pd.read_csv(os.path.join(DATA_PATH,'test_preprocessed.csv'))
df_test['target'] = -1

COLUMN_NAME  = 'product_name' 

test_dataset = BNPParibasText(df_test,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = Roberta_Model(pretrained_model=PRETRAINED)
test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_test = get_embedding(test_loader, model, 'cuda')
df_test[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_test.shape[1])]] = emb_sentence_test


COLUMN_NAME  = 'ingredients_text' 

test_dataset = BNPParibasText(df_test,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = Roberta_Model(pretrained_model=PRETRAINED)
test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_test = get_embedding(test_loader, model, 'cuda')
df_test[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_test.shape[1])]] = emb_sentence_test

COLUMN_NAME  = 'countries_en' 

test_dataset = BNPParibasText(df_test,MAX_LENGTH,tokenizer,COLUMN_NAME)
model         = Roberta_Model(pretrained_model=PRETRAINED)
test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size  = 32,
        pin_memory  = True,
        num_workers = 72
    )
emb_sentence_test = get_embedding(test_loader, model, 'cuda')
df_test[[f'emb_{COLUMN_NAME}_{i}' for i in range(emb_sentence_test.shape[1])]] = emb_sentence_test

df_test = apply_label_encoder(df_test,dict_le,drop_original = True, missing_new_cat = True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=798.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=798.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=798.0), HTML(value='')))
# Mode: Missing as new category
# Applying Label Encoding:  label_states_en_brands
# Applying Label Encoding:  label_states_en_categories
# Applying Label Encoding:  label_states_en_characteristics
# Applying Label Encoding:  label_states_en_expiration date
# Applying Label Encoding:  label_states_en_general_complete
# Applying Label Encoding:  label_states_en_ingredients
# Applying Label Encoding:  label_pnns_groups_1
# Applying Label Encoding:  label_pnns_groups_2
# Applying Label Encoding:  label_states_en_packaging
# Applying Label Encoding:  label_states_en_packaging-code-
# Applying Label Encoding:  label_states_en_photo_upload
# Applying Label Encoding:  label_states_en_photo_validate
# Applying Label Encoding:  label_states_en_product name
# Applying Label Encoding:  label_states_en_quantity

# %%
probs = 0
for i in models:
    probs = probs + (i.predict(df_test[feature_list]))
    print('fin_predict')
y_test_pred = probs/5.0
print(f'Real: ',math.sqrt(mean_squared_error(y_test_pred,df_test['Target'].values)))
# Out:
# fin_predict
# fin_predict
# fin_predict
# fin_predict
# fin_predict
# Real:  5.0183674573216654

# %%
y_submission['target'] = y_test_pred
y_submission.head()

# %%
#Enviar los resultados
#apiquery.submit_api(y_submission,
#       competition_name='food',
#        subname='test_v2', # Pueden cambiar esto sin problemas, poner el nombre que quieran.
#        holdout_key='None',
#        update_ldb=True,
#        username="Insight ML - DD" # Poner el nombre de su equipo como un string. 
                                  # El mejor de los resultados dentro de sus envios es el que aparecera en la tabla de posiciones.
#)
# Out:
# requests number 1
# 200
# {'Date': 'Tue, 18 May 2021 20:58:56 GMT', 'Content-Type': 'application/json', 'Content-Length': '495', 'Connection': 'keep-alive', 'X-Request-ID': '9VDYQEXOTIL4RSGH', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'POST', 'Access-Control-Allow-Headers': 'authorization,content-type'}
# {'competition_name': 'food',
#  'file_path': 'none',
#  'message': 'Submission validated.',
#  'name': 'Insight ML - DD',
#  'result_csv_file': 'test_v2',
#  'score': 5.748294411988524,
#  'score2': None,
#  'score3': None,
#  'sub_name': 'test_v2',
#  'sub_uid': '8ff2732f-f618-4572-912d-bfd4d0799d1d',
#  'submission_time': '2021/05/18, 20:58:56'}
